# %% [markdown]
# # Preprocess
# ## Number of words, number of sentences
# ## Average sentence length, average word length

# %%
import nltk
from nltk.tokenize import RegexpTokenizer, word_tokenize, sent_tokenize

nltk.download('punkt')

tokenizer_regex = RegexpTokenizer(r'\w+')


def preprocess_text(text):
    # remove punctuation for tokenized text
    tokens_without_punctuation = tokenizer_regex.tokenize(text)
    return ' '.join(tokens_without_punctuation)

#count words
def count_words(text):
    words = word_tokenize(text)
    return len(words)

#count sentences
def count_sentences(text):
    sentences = sent_tokenize(text)
    return len(sentences)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Find averae word length
def average_word_length(text):
    words = word_tokenize(text)
    total_characters = sum(len(word) for word in words)
    total_words = len(words)
    return (total_characters / total_words)

# %% [markdown]
# ## Allan Poe

# %%
# Allan Poe
file_path_Poe = 'Allan Poe - Full Corpus.txt'

with open(file_path_Poe, 'r') as file:
    text_Poe = file.read()

preprocessed_text_Poe = preprocess_text(text_Poe)

num_words_after_preprocess_Poe = count_words(preprocessed_text_Poe)

print("Number of words after preprocessing:", num_words_after_preprocess_Poe)
# Out:
# Number of words after preprocessing: 199831

# %%
num_sentences_Poe = count_sentences(text_Poe)
print("Number of sentences:", num_sentences_Poe)
# Out:
# Number of sentences: 7571

# %%
average_sentence_length_Poe = num_words_after_preprocess_Poe / num_sentences_Poe
print("Average sentence length:", average_sentence_length_Poe)
# Out:
# Average sentence length: 26.39426760005283

# %%
average_word_length_Poe = average_word_length(preprocessed_text_Poe)
print("Average word length:", average_word_length_Poe)
# Out:
# Average word length: 4.470207325189786

# %%
# Split the text by whitespace to get individual words
words_Poe = text_Poe.split()

# Count the number of words
num_words_Poe = len(words_Poe)

print("Number of words in the Allan Poe corpus:", num_words_Poe)
# Out:
# Number of words in the Allan Poe corpus: 196261

# %%
# Calculate the number of words in each subset
subset_size = num_words_Poe // 5

# Create 5 subsets (a list of subsets which each subset is list of words)
subsets_Poe = []
for i in range(5):
    subset_start = i * subset_size
    subset_end = (i + 1) * subset_size
    subset = words_Poe[subset_start:subset_end]
    subsets_Poe.append(subset)

# Print the size of each subset
for i, subset in enumerate(subsets_Poe):
    print(f"Subset {i + 1} size:", len(subset))
# Out:
# Subset 1 size: 39252
# Subset 2 size: 39252
# Subset 3 size: 39252
# Subset 4 size: 39252
# Subset 5 size: 39252

# %%
# Function to calculate average word length in a subset
def average_word_length(subset):
    total_length = sum(len(word) for word in subset)
    return total_length / len(subset)

# Calculate and print average word length for each subset
for i, subset in enumerate(subsets_Poe):
    avg_length = average_word_length(subset)
    print(f"Average word length in Subset {i + 1}: {avg_length:.3f}")
# Out:
# Average word length in Subset 1: 4.746
# Average word length in Subset 2: 4.757
# Average word length in Subset 3: 4.648
# Average word length in Subset 4: 4.655
# Average word length in Subset 5: 4.801

# %%
# number of sentences in each subset
import re

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences

# Calculate the number of sentences in each subset
for i, subset in enumerate(subsets_Poe):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    print(f"Number of sentences in Subset {i + 1}: {len(subset_sentences)}")
# Out:
# Number of sentences in Subset 1: 1661
# Number of sentences in Subset 2: 1809
# Number of sentences in Subset 3: 1556
# Number of sentences in Subset 4: 1352
# Number of sentences in Subset 5: 1467

# %%
#average sentence length in each subset
# Function to calculate average sentence length in a subset
def average_sentence_length(subset_sentences):
    total_words = sum(len(sentence.split()) for sentence in subset_sentences)
    return total_words / len(subset_sentences)

# Calculate and print average sentence length for each subset
for i, subset in enumerate(subsets_Poe):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    avg_length = average_sentence_length(subset_sentences)
    print(f"Average sentence length in Subset {i + 1}: {avg_length:.3f} words")
# Out:
# Average sentence length in Subset 1: 23.632 words
# Average sentence length in Subset 2: 21.698 words
# Average sentence length in Subset 3: 25.226 words
# Average sentence length in Subset 4: 29.033 words
# Average sentence length in Subset 5: 26.757 words

# %% [markdown]
# ## Sheridan Le Fanu

# %%
#Sheridan Le Fanu
file_path_Fanu = 'Full Corpus - Sheridan Le Fanu.txt'

with open(file_path_Fanu, 'r') as file:
    text_Fanu = file.read()

preprocessed_text_Fanu = preprocess_text(text_Fanu)

num_words_after_preprocess_Faun = count_words(preprocessed_text_Fanu)

print("Number of words after preprocessing:", num_words_after_preprocess_Faun)
# Out:
# Number of words after preprocessing: 152056

# %%
num_sentences_Fanu = count_sentences(text_Fanu)
print("Number of sentences:", num_sentences_Fanu)
# Out:
# Number of sentences: 6285

# %%
average_sentence_length_Fanu = num_words_after_preprocess_Faun / num_sentences_Fanu
print("Average sentence length:", average_sentence_length_Fanu)
# Out:
# Average sentence length: 24.193476531424025

# %%
average_word_length_Fanu = average_word_length(preprocessed_text_Fanu)
print("Average word length:", average_word_length_Fanu)
# Out:
# Average word length: 1.0

# %%
# Split the text by whitespace to get individual words
words_Fanu = text_Fanu.split()

# Count the number of words
num_words_Fanu = len(words_Fanu)

print("Number of words in the Sheridan Le Fanu corpus:", num_words_Fanu)
# Out:
# Number of words in the Sheridan Le Fanu corpus: 148482

# %%
# Calculate the number of words in each subset
subset_size = num_words_Fanu // 5

# Create 5 subsets (a list of subsets which each subset is list of words)
subsets_Fanu = []
for i in range(5):
    subset_start = i * subset_size
    subset_end = (i + 1) * subset_size
    subset = words_Fanu[subset_start:subset_end]
    subsets_Fanu.append(subset)

# Print the size of each subset
for i, subset in enumerate(subsets_Fanu):
    print(f"Subset {i + 1} size:", len(subset))
# Out:
# Subset 1 size: 29696
# Subset 2 size: 29696
# Subset 3 size: 29696
# Subset 4 size: 29696
# Subset 5 size: 29696

# %%
# Calculate and print average word length for each subset
for i, subset in enumerate(subsets_Fanu):
    avg_length = average_word_length(subset)
    print(f"Average word length in Subset {i + 1}: {avg_length:.3f}")
# Out:
# Average word length in Subset 1: 4.654
# Average word length in Subset 2: 4.462
# Average word length in Subset 3: 4.515
# Average word length in Subset 4: 4.574
# Average word length in Subset 5: 4.507

# %%
# Calculate the number of sentences in each subset
for i, subset in enumerate(subsets_Fanu):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    print(f"Number of sentences in Subset {i + 1}: {len(subset_sentences)}")
# Out:
# Number of sentences in Subset 1: 951
# Number of sentences in Subset 2: 1245
# Number of sentences in Subset 3: 1144
# Number of sentences in Subset 4: 1014
# Number of sentences in Subset 5: 1134

# %%
# Calculate and print average sentence length for each subset
for i, subset in enumerate(subsets_Fanu):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    avg_length = average_sentence_length(subset_sentences)
    print(f"Average sentence length in Subset {i + 1}: {avg_length:.3f} words")
# Out:
# Average sentence length in Subset 1: 31.226 words
# Average sentence length in Subset 2: 23.852 words
# Average sentence length in Subset 3: 25.958 words
# Average sentence length in Subset 4: 29.286 words
# Average sentence length in Subset 5: 26.187 words

# %% [markdown]
# ## Gothic corpus

# %%
# Gothic corpus
file_path_Gothic = 'Full Gothic corpus.txt'

with open(file_path_Gothic, 'r') as file:
    text_Gothic = file.read()

preprocessed_text_Gothic = preprocess_text(text_Gothic)

num_words_after_preprocess_Gothic = count_words(preprocessed_text_Gothic)

print("Number of words after preprocessing:", num_words_after_preprocess_Gothic)
# Out:
# Number of words after preprocessing: 3005036

# %%
num_sentences_Gothic = count_sentences(text_Gothic)
print("Number of sentences:", num_sentences_Gothic)
# Out:
# Number of sentences: 120849

# %%
average_sentence_length_Gothic = num_words_after_preprocess_Gothic / num_sentences_Gothic
print("Average sentence length:", average_sentence_length_Gothic)
# Out:
# Average sentence length: 24.866039437645327

# %%
average_word_length_Gothic = average_word_length(preprocessed_text_Gothic)
print("Average word length:", average_word_length_Gothic)
# Out:
# Average word length: 1.0

# %%
# Split the text by whitespace to get individual words
words_Gothic = text_Gothic.split()

# Count the number of words
num_words_Gothic = len(words_Gothic)

print("Number of words in the Gothic corpus:", num_words_Gothic)
# Out:
# Number of words in the Gothic corpus: 2943122

# %%
#subset for the comparison with Allan Poe

# Calculate the number of words in each subset
subset_size = 39252

# Create 5 subsets (a list of subsets which each subset is list of words)
subsets_Gothic_vs_Poe = []
for i in range(25):
    subset_start = i * subset_size
    subset_end = (i + 1) * subset_size
    subset = words_Gothic[subset_start:subset_end]
    subsets_Gothic_vs_Poe.append(subset)

# Print the size of each subset
for i, subset in enumerate(subsets_Gothic_vs_Poe):
    print(f"Subset {i + 1} size:", len(subset))
# Out:
# Subset 1 size: 39252
# Subset 2 size: 39252
# Subset 3 size: 39252
# Subset 4 size: 39252
# Subset 5 size: 39252
# Subset 6 size: 39252
# Subset 7 size: 39252
# Subset 8 size: 39252
# Subset 9 size: 39252
# Subset 10 size: 39252
# Subset 11 size: 39252
# Subset 12 size: 39252
# Subset 13 size: 39252
# Subset 14 size: 39252
# Subset 15 size: 39252
# Subset 16 size: 39252
# Subset 17 size: 39252
# Subset 18 size: 39252
# Subset 19 size: 39252
# Subset 20 size: 39252
# Subset 21 size: 39252
# Subset 22 size: 39252
# Subset 23 size: 39252
# Subset 24 size: 39252
# Subset 25 size: 39252

# %%
# Calculate and print average word length for each subset
for i, subset in enumerate(subsets_Gothic_vs_Poe):
    avg_length = average_word_length(subset)
    print(f"Average word length in Subset {i + 1}: {avg_length:.3f}")
# Out:
# Average word length in Subset 1: 4.598
# Average word length in Subset 2: 4.538
# Average word length in Subset 3: 4.517
# Average word length in Subset 4: 4.654
# Average word length in Subset 5: 4.651
# Average word length in Subset 6: 4.635
# Average word length in Subset 7: 4.682
# Average word length in Subset 8: 4.638
# Average word length in Subset 9: 4.516
# Average word length in Subset 10: 4.456
# Average word length in Subset 11: 4.501
# Average word length in Subset 12: 4.580
# Average word length in Subset 13: 4.468
# Average word length in Subset 14: 4.444
# Average word length in Subset 15: 4.460
# Average word length in Subset 16: 4.407
# Average word length in Subset 17: 4.571
# Average word length in Subset 18: 4.500
# Average word length in Subset 19: 4.475
# Average word length in Subset 20: 4.499
# Average word length in Subset 21: 4.486
# Average word length in Subset 22: 4.468
# Average word length in Subset 23: 4.562
# Average word length in Subset 24: 4.450
# Average word length in Subset 25: 4.560

# %%
# Calculate the number of sentences in each subset
for i, subset in enumerate(subsets_Gothic_vs_Poe):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    print(f"Number of sentences in Subset {i + 1}: {len(subset_sentences)}")
# Out:
# Number of sentences in Subset 1: 1838
# Number of sentences in Subset 2: 1941
# Number of sentences in Subset 3: 1941
# Number of sentences in Subset 4: 1672
# Number of sentences in Subset 5: 1754
# Number of sentences in Subset 6: 1759
# Number of sentences in Subset 7: 1614
# Number of sentences in Subset 8: 2036
# Number of sentences in Subset 9: 1389
# Number of sentences in Subset 10: 1339
# Number of sentences in Subset 11: 1286
# Number of sentences in Subset 12: 1223
# Number of sentences in Subset 13: 1263
# Number of sentences in Subset 14: 1218
# Number of sentences in Subset 15: 1199
# Number of sentences in Subset 16: 1001
# Number of sentences in Subset 17: 1672
# Number of sentences in Subset 18: 2011
# Number of sentences in Subset 19: 1892
# Number of sentences in Subset 20: 2143
# Number of sentences in Subset 21: 1947
# Number of sentences in Subset 22: 1926
# Number of sentences in Subset 23: 1740
# Number of sentences in Subset 24: 1598
# Number of sentences in Subset 25: 1261

# %%
# Calculate and print average sentence length for each subset
for i, subset in enumerate(subsets_Gothic_vs_Poe):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    avg_length = average_sentence_length(subset_sentences)
    print(f"Average sentence length in Subset {i + 1}: {avg_length:.3f} words")
# Out:
# Average sentence length in Subset 1: 21.356 words
# Average sentence length in Subset 2: 20.223 words
# Average sentence length in Subset 3: 20.223 words
# Average sentence length in Subset 4: 23.476 words
# Average sentence length in Subset 5: 22.379 words
# Average sentence length in Subset 6: 22.315 words
# Average sentence length in Subset 7: 24.320 words
# Average sentence length in Subset 8: 19.279 words
# Average sentence length in Subset 9: 28.259 words
# Average sentence length in Subset 10: 29.314 words
# Average sentence length in Subset 11: 30.523 words
# Average sentence length in Subset 12: 32.095 words
# Average sentence length in Subset 13: 31.078 words
# Average sentence length in Subset 14: 32.227 words
# Average sentence length in Subset 15: 32.737 words
# Average sentence length in Subset 16: 39.213 words
# Average sentence length in Subset 17: 23.476 words
# Average sentence length in Subset 18: 19.519 words
# Average sentence length in Subset 19: 20.746 words
# Average sentence length in Subset 20: 18.316 words
# Average sentence length in Subset 21: 20.160 words
# Average sentence length in Subset 22: 20.380 words
# Average sentence length in Subset 23: 22.559 words
# Average sentence length in Subset 24: 24.563 words
# Average sentence length in Subset 25: 31.128 words

# %%
#subset for the comparison with Fanu
# Calculate the number of words in each subset
subset_size = 29696

# Create 5 subsets (a list of subsets which each subset is list of words)
subsets_Gothic_vs_Fanu = []
for i in range(25):
    subset_start = i * subset_size
    subset_end = (i + 1) * subset_size
    subset = words_Gothic[subset_start:subset_end]
    subsets_Gothic_vs_Fanu.append(subset)

# Print the size of each subset
for i, subset in enumerate(subsets_Gothic_vs_Fanu):
    print(f"Subset {i + 1} size:", len(subset))
# Out:
# Subset 1 size: 29696
# Subset 2 size: 29696
# Subset 3 size: 29696
# Subset 4 size: 29696
# Subset 5 size: 29696
# Subset 6 size: 29696
# Subset 7 size: 29696
# Subset 8 size: 29696
# Subset 9 size: 29696
# Subset 10 size: 29696
# Subset 11 size: 29696
# Subset 12 size: 29696
# Subset 13 size: 29696
# Subset 14 size: 29696
# Subset 15 size: 29696
# Subset 16 size: 29696
# Subset 17 size: 29696
# Subset 18 size: 29696
# Subset 19 size: 29696
# Subset 20 size: 29696
# Subset 21 size: 29696
# Subset 22 size: 29696
# Subset 23 size: 29696
# Subset 24 size: 29696
# Subset 25 size: 29696

# %%
# Calculate and print average word length for each subset
for i, subset in enumerate(subsets_Gothic_vs_Fanu):
    avg_length = average_word_length(subset)
    print(f"Average word length in Subset {i + 1}: {avg_length:.3f}")
# Out:
# Average word length in Subset 1: 4.591
# Average word length in Subset 2: 4.544
# Average word length in Subset 3: 4.537
# Average word length in Subset 4: 4.538
# Average word length in Subset 5: 4.645
# Average word length in Subset 6: 4.666
# Average word length in Subset 7: 4.650
# Average word length in Subset 8: 4.633
# Average word length in Subset 9: 4.672
# Average word length in Subset 10: 4.665
# Average word length in Subset 11: 4.562
# Average word length in Subset 12: 4.530
# Average word length in Subset 13: 4.467
# Average word length in Subset 14: 4.435
# Average word length in Subset 15: 4.587
# Average word length in Subset 16: 4.555
# Average word length in Subset 17: 4.460
# Average word length in Subset 18: 4.465
# Average word length in Subset 19: 4.444
# Average word length in Subset 20: 4.445
# Average word length in Subset 21: 4.403
# Average word length in Subset 22: 4.565
# Average word length in Subset 23: 4.520
# Average word length in Subset 24: 4.503
# Average word length in Subset 25: 4.492

# %%
# Calculate the number of sentences in each subset
for i, subset in enumerate(subsets_Gothic_vs_Fanu):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    print(f"Number of sentences in Subset {i + 1}: {len(subset_sentences)}")
# Out:
# Number of sentences in Subset 1: 1308
# Number of sentences in Subset 2: 1567
# Number of sentences in Subset 3: 1399
# Number of sentences in Subset 4: 1500
# Number of sentences in Subset 5: 1282
# Number of sentences in Subset 6: 1334
# Number of sentences in Subset 7: 1278
# Number of sentences in Subset 8: 1305
# Number of sentences in Subset 9: 1240
# Number of sentences in Subset 10: 1425
# Number of sentences in Subset 11: 1413
# Number of sentences in Subset 12: 1008
# Number of sentences in Subset 13: 1043
# Number of sentences in Subset 14: 967
# Number of sentences in Subset 15: 1009
# Number of sentences in Subset 16: 877
# Number of sentences in Subset 17: 973
# Number of sentences in Subset 18: 921
# Number of sentences in Subset 19: 867
# Number of sentences in Subset 20: 899
# Number of sentences in Subset 21: 767
# Number of sentences in Subset 22: 1124
# Number of sentences in Subset 23: 1469
# Number of sentences in Subset 24: 1492
# Number of sentences in Subset 25: 1414

# %%
# Calculate and print average sentence length for each subset
for i, subset in enumerate(subsets_Gothic_vs_Fanu):
    # Join subset words back into a string
    subset_text = ' '.join(subset)
    # Split subset text into sentences
    subset_sentences = split_into_sentences(subset_text)
    avg_length = average_sentence_length(subset_sentences)
    print(f"Average sentence length in Subset {i + 1}: {avg_length:.3f} words")
# Out:
# Average sentence length in Subset 1: 22.703 words
# Average sentence length in Subset 2: 18.951 words
# Average sentence length in Subset 3: 21.227 words
# Average sentence length in Subset 4: 19.797 words
# Average sentence length in Subset 5: 23.164 words
# Average sentence length in Subset 6: 22.261 words
# Average sentence length in Subset 7: 23.236 words
# Average sentence length in Subset 8: 22.756 words
# Average sentence length in Subset 9: 23.948 words
# Average sentence length in Subset 10: 20.839 words
# Average sentence length in Subset 11: 21.016 words
# Average sentence length in Subset 12: 29.460 words
# Average sentence length in Subset 13: 28.472 words
# Average sentence length in Subset 14: 30.709 words
# Average sentence length in Subset 15: 29.431 words
# Average sentence length in Subset 16: 33.861 words
# Average sentence length in Subset 17: 30.520 words
# Average sentence length in Subset 18: 32.243 words
# Average sentence length in Subset 19: 34.251 words
# Average sentence length in Subset 20: 33.032 words
# Average sentence length in Subset 21: 38.717 words
# Average sentence length in Subset 22: 26.420 words
# Average sentence length in Subset 23: 20.215 words
# Average sentence length in Subset 24: 19.903 words
# Average sentence length in Subset 25: 21.001 words

# %% [markdown]
# # finding number of samples required

# %% [markdown]
# # Poe

# %%
words = preprocessed_text_Poe.split()
pilot_poe = ' '.join(words[:1000])

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
verb_count = Counter(tag for word, tag in tagged_words if tag.startswith('VB'))

# Calculate the total number of verbs
total_verbs = sum(verb_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_verbs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(verb_count.values()))
variance = ((total_verbs*((1-mean_score)**2))+((total_words-total_verbs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of verbs in the entire corpus:", mean_score)
print("Standard deviation of verb frequency:", std_deviation)
# Out:
# Mean score of verbs in the entire corpus: 0.15
# Standard deviation of verb frequency: 0.3572500911513216

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.1575
# CI min: 0.1425
# CI: 0.015000000000000013

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 8716.343009676326

# %%
8716.343009676326 < 199831
# Out:
# True

# %%
#nouns
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
noun_count = Counter(tag for word, tag in tagged_words if tag.startswith('NN'))

# Calculate the total number of verbs
total_nouns = sum(noun_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_nouns / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(noun_count.values()))
variance = ((total_nouns*((1-mean_score)**2))+((total_words-total_nouns)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of nouns in the entire corpus:", mean_score)
print("Standard deviation of noun frequency:", std_deviation)
# Out:
# Mean score of nouns in the entire corpus: 0.251
# Standard deviation of noun frequency: 0.43380547159664457

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.26355
# CI min: 0.23845
# CI: 0.02510000000000001

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 4590.021734882289

# %%
4590.021734882289 < 199831
# Out:
# True

# %%
#adj
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
adj_count = Counter(tag for word, tag in tagged_words if tag.startswith('JJ'))

# Calculate the total number of verbs
total_adjs = sum(adj_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_adjs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(noun_count.values()))
variance = ((total_adjs*((1-mean_score)**2))+((total_words-total_adjs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of adjs in the entire corpus:", mean_score)
print("Standard deviation of adj frequency:", std_deviation)
# Out:
# Mean score of adjs in the entire corpus: 0.086
# Standard deviation of adj frequency: 0.2805043362992499

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.09029999999999999
# CI min: 0.0817
# CI: 0.008599999999999997

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 16347.614591335538

# %%
16347.614591335538 < 199831
# Out:
# True

# %%
#adv
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
adv_count = Counter(tag for word, tag in tagged_words if tag.startswith('RB'))

# Calculate the total number of verbs
total_advs = sum(adv_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_advs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(adv_count.values()))
variance = ((total_advs*((1-mean_score)**2))+((total_words-total_advs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of advs in the entire corpus:", mean_score)
print("Standard deviation of adv frequency:", std_deviation)
# Out:
# Mean score of advs in the entire corpus: 0.073
# Standard deviation of adv frequency: 0.2602666685127751

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.07665
# CI min: 0.06935
# CI: 0.007300000000000001

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 19532.755769468095

# %%
19532.755769468095 < 199831
# Out:
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = preprocessed_text_Poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
verb_count = Counter(tag for word, tag in tagged_words if tag.startswith('VB'))

# Calculate the mean score
total_words = len(words)
mean_score = (verb_count['VB'] / total_words) * 1000 if 'VB' in verb_count else 0

# Calculate the standard deviation for 1000 words
std_deviation_1000 = np.sqrt(variance * (1000 / total_words))

print("Mean score of verbs per 1000 words:", mean_score)
print("Standard deviation of verb frequency per 1000 words:", std_deviation_1000)
# Out:
# Mean score of verbs per 1000 words: 29.89526149596409
# Standard deviation of verb frequency per 1000 words: 460.64053711217315

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 31.390024570762293
# CI min: 28.400498421165885
# CI: 2.989526149596408

# %%
t =   1.282
n = (std_deviation_1000**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 156083.01169825267

# %%
156083.01169825267 < 199831
# Out:
# True

# %%
# noun
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = preprocessed_text_Poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
nouns_count = Counter(tag for word, tag in tagged_words if tag.startswith('NN'))

# Calculate the mean score
total_words = len(words)
mean_score = (nouns_count['NN'] / total_words) * 1000 if 'NN' in nouns_count else 0

# Calculate the standard deviation for 1000 words
std_deviation_1000 = np.sqrt(variance * (1000 / total_words))

print("Mean score of nouns per 1000 words:", mean_score)
print("Standard deviation of noun frequency per 1000 words:", std_deviation_1000)
# Out:
# Mean score of nouns per 1000 words: 159.60486611186454
# Standard deviation of noun frequency per 1000 words: 460.64053711217315

# %%
nouns_count
# Out:
# Counter({'NNP': 5229, 'NN': 31894, 'NNS': 7827, 'NNPS': 31})

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 167.58510941745777
# CI min: 151.6246228062713
# CI: 15.960486611186468

# %%
t =  3.291
n = (std_deviation_1000**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 36086.75302766323

# %%
36086.75302766323 < 199831
# Out:
# True

# %%
# adj
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = preprocessed_text_Poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
adjs_count = Counter(tag for word, tag in tagged_words if tag.startswith('JJ'))

# Calculate the mean score
total_words = len(words)
mean_score = (adjs_count['JJ'] / total_words) * 1000 if 'JJ' in adjs_count else 0

# Calculate the standard deviation for 1000 words
std_deviation_1000 = np.sqrt(variance * (1000 / total_words))

print("Mean score of nouns per 1000 words:", mean_score)
print("Standard deviation of noun frequency per 1000 words:", std_deviation_1000)
# Out:
# Mean score of nouns per 1000 words: 70.51958905274958
# Standard deviation of noun frequency per 1000 words: 460.64053711217315

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 74.04556850538705
# CI min: 66.99360960011211
# CI: 7.051958905274944

# %%
t =  3.291
n = (std_deviation_1000**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 184850.45254368294

# %%
184850.45254368294 < 199831
# Out:
# True

# %%
# adv
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = preprocessed_text_Poe

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
advs_count = Counter(tag for word, tag in tagged_words if tag.startswith('RB'))

# Calculate the mean score
total_words = len(words)
mean_score = (advs_count['RB'] / total_words) * 1000 if 'RB' in advs_count else 0

# Calculate the standard deviation for 1000 words
std_deviation_1000 = np.sqrt(variance * (1000 / total_words))

print("Mean score of nouns per 1000 words:", mean_score)
print("Standard deviation of noun frequency per 1000 words:", std_deviation_1000)
# Out:
# Mean score of nouns per 1000 words: 60.716305277959876
# Standard deviation of noun frequency per 1000 words: 460.64053711217315

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 63.75212054185787
# CI min: 57.68049001406188
# CI: 6.071630527795989

# %%
t =  2.576
n = (std_deviation_1000**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 152779.5915911607

# %%
152779.5915911607 < 199831
# Out:
# True

# %% [markdown]
# # Fanu

# %%
words = preprocessed_text_Fanu.split()
pilot_Fanu = ' '.join(words[:1000])

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Fanu

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
verb_count = Counter(tag for word, tag in tagged_words if tag.startswith('VB'))

# Calculate the total number of verbs
total_verbs = sum(verb_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_verbs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(verb_count.values()))
variance = ((total_verbs*((1-mean_score)**2))+((total_words-total_verbs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of verbs in the entire corpus:", mean_score)
print("Standard deviation of verb frequency:", std_deviation)
# Out:
# Mean score of verbs in the entire corpus: 0.158
# Standard deviation of verb frequency: 0.3649235113954281

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.1659
# CI min: 0.1501
# CI: 0.01579999999999998

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 8197.126747000182

# %%
8197.126747000182 < 152056
# Out:
# True

# %%
#nouns
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Fanu

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
noun_count = Counter(tag for word, tag in tagged_words if tag.startswith('NN'))

# Calculate the total number of verbs
total_nouns = sum(noun_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_nouns / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(noun_count.values()))
variance = ((total_nouns*((1-mean_score)**2))+((total_words-total_nouns)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of nouns in the entire corpus:", mean_score)
print("Standard deviation of noun frequency:", std_deviation)
# Out:
# Mean score of nouns in the entire corpus: 0.231
# Standard deviation of noun frequency: 0.42168331341993703

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.24255000000000002
# CI min: 0.21945
# CI: 0.02310000000000001

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 5120.6018139351445

# %%
5120.6018139351445 < 152056
# Out:
# True

# %%
#adj
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Fanu

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
adj_count = Counter(tag for word, tag in tagged_words if tag.startswith('JJ'))

# Calculate the total number of verbs
total_adjs = sum(adj_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_adjs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(noun_count.values()))
variance = ((total_adjs*((1-mean_score)**2))+((total_words-total_adjs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of adjs in the entire corpus:", mean_score)
print("Standard deviation of adj frequency:", std_deviation)
# Out:
# Mean score of adjs in the entire corpus: 0.107
# Standard deviation of adj frequency: 0.3092679204939411

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.11235
# CI min: 0.10164999999999999
# CI: 0.010700000000000015

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 12837.318814141208

# %%
12837.318814141208 < 152056
# Out:
# True

# %%
#adv
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Fanu

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
adv_count = Counter(tag for word, tag in tagged_words if tag.startswith('RB'))

# Calculate the total number of verbs
total_advs = sum(adv_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_advs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(adv_count.values()))
variance = ((total_advs*((1-mean_score)**2))+((total_words-total_advs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of advs in the entire corpus:", mean_score)
print("Standard deviation of adv frequency:", std_deviation)
# Out:
# Mean score of advs in the entire corpus: 0.062
# Standard deviation of adv frequency: 0.24127621974453722

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.0651
# CI min: 0.0589
# CI: 0.006200000000000004

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 23271.14727630853

# %%
23271.14727630853 < 152056
# Out:
# True

# %% [markdown]
# # Gothic

# %%
words = preprocessed_text_Gothic.split()
pilot_Gothic = ' '.join(words[:1000])

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Gothic

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
verb_count = Counter(tag for word, tag in tagged_words if tag.startswith('VB'))

# Calculate the total number of verbs
total_verbs = sum(verb_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_verbs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(verb_count.values()))
variance = ((total_verbs*((1-mean_score)**2))+((total_words-total_verbs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of verbs in the entire corpus:", mean_score)
print("Standard deviation of verb frequency:", std_deviation)
# Out:
# Mean score of verbs in the entire corpus: 0.164
# Standard deviation of verb frequency: 0.370460849809047

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.17220000000000002
# CI min: 0.1558
# CI: 0.016400000000000026

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 7840.957054615566

# %%
7840.957054615566 < 3005036
# Out:
# True

# %%
#nouns
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Gothic

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
noun_count = Counter(tag for word, tag in tagged_words if tag.startswith('NN'))

# Calculate the total number of verbs
total_nouns = sum(noun_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_nouns / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(noun_count.values()))
variance = ((total_nouns*((1-mean_score)**2))+((total_words-total_nouns)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of nouns in the entire corpus:", mean_score)
print("Standard deviation of noun frequency:", std_deviation)
# Out:
# Mean score of nouns in the entire corpus: 0.27
# Standard deviation of noun frequency: 0.44418160396092193

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.28350000000000003
# CI min: 0.2565
# CI: 0.027000000000000024

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 4158.778037296549

# %%
4158.778037296549 < 3005036
# Out:
# True

# %%
#adj
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Gothic

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
adj_count = Counter(tag for word, tag in tagged_words if tag.startswith('JJ'))

# Calculate the total number of verbs
total_adjs = sum(adj_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_adjs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(noun_count.values()))
variance = ((total_adjs*((1-mean_score)**2))+((total_words-total_adjs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of adjs in the entire corpus:", mean_score)
print("Standard deviation of adj frequency:", std_deviation)
# Out:
# Mean score of adjs in the entire corpus: 0.08
# Standard deviation of adj frequency: 0.27142894774447635

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.084
# CI min: 0.076
# CI: 0.008000000000000007

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 17689.049049049016

# %%
17689.049049049016 < 3005036
# Out:
# True

# %%
#adv
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from collections import Counter
import numpy as np

# Assuming you have your preprocessed_text_Poe stored as a string
corpus = pilot_Gothic

# Tokenize the text into words
words = word_tokenize(corpus)

# Tag each word with its part of speech
tagged_words = pos_tag(words)

# Count occurrences of verbs
adv_count = Counter(tag for word, tag in tagged_words if tag.startswith('RB'))

# Calculate the total number of verbs
total_advs = sum(adv_count.values())

# Calculate the total number of words
total_words = len(words)

# Calculate the mean score
mean_score = total_advs / total_words if total_words > 0 else 0

# Calculate the standard deviation
verb_frequencies = np.array(list(adv_count.values()))
variance = ((total_advs*((1-mean_score)**2))+((total_words-total_advs)*((0-mean_score)**2)))/(total_words-1)
std_deviation = np.sqrt(variance)

print("Mean score of advs in the entire corpus:", mean_score)
print("Standard deviation of adv frequency:", std_deviation)
# Out:
# Mean score of advs in the entire corpus: 0.05
# Standard deviation of adv frequency: 0.21805400144814482

# %%
CI_Max = mean_score + (5/100*mean_score)
CI_Min = mean_score - (5/100*mean_score)
CI = CI_Max - CI_Min
print("CI max:", CI_Max)
print("CI min:", CI_Min)
print("CI:", CI)
# Out:
# CI max: 0.052500000000000005
# CI min: 0.0475
# CI: 0.0050000000000000044

# %%
t = 1.96
n = (std_deviation**2)/((0.5*CI)/t)**2
print("required sample size:", n)
# Out:
# required sample size: 29225.38538538533

# %%
29225.38538538533 < 3005036
# Out:
# True

# %% [markdown]
# ## POS Frequency classes

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from collections import Counter
import pandas as pd
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def pos_frequency(text):
    #tokenize into words
    words = word_tokenize(text)
    # Tag each word with its part of speech
    tagged_words = pos_tag(words)
    # POS classes
    pos_classes = [tag[1] for tag in tagged_words]
    # Count the frequency of each POS class
    pos_freq = Counter(pos_classes)
    #total number of POS tags
    total_pos_tags = sum(pos_freq.values())
    #relative frequency of each POS class
    relative_freq = {pos_class: freq / total_pos_tags for pos_class, freq in pos_freq.items()}
    return pos_freq, relative_freq
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Allan Poe

# %%
pos_freq_Poe, relative_freq_Poe = pos_frequency(preprocessed_text_Poe)

POS_Poe = pd.DataFrame({"POS Class": list(pos_freq_Poe.keys()),
                   "Raw Frequency": list(pos_freq_Poe.values()),
                   "Relative Frequency": list(relative_freq_Poe.values())})

POS_Poe = POS_Poe.sort_values(by='Relative Frequency', ascending=False)

# %%
POS_Poe
# Out:
#    POS Class  Raw Frequency  Relative Frequency
# 4         NN          31894            0.159605
# 8         IN          30575            0.153004
# 2         DT          24809            0.124150
# 10        JJ          14092            0.070520
# 1        VBD          12328            0.061692
# 12        RB          12133            0.060716
# 7        PRP          12019            0.060146
# 5         CC           8003            0.040049
# 9        NNS           7827            0.039168
# 13       VBN           6559            0.032823
# 21        VB           5974            0.029895
# 3        NNP           5229            0.026167
# 14      PRP$           4909            0.024566
# 15        TO           4839            0.024215
# 17       VBG           3874            0.019386
# 23        MD           2272            0.011370
# 11       VBP           2204            0.011029
# 18       VBZ           1967            0.009843
# 19       WDT           1732            0.008667
# 22        CD           1638            0.008197
# 6        WRB            809            0.004048
# 28        RP            772            0.003863
# 0         WP            732            0.003663
# 24       JJR            531            0.002657
# 27        EX            505            0.002527
# 16       JJS            466            0.002332
# 25       RBR            420            0.002102
# 20       RBS            271            0.001356
# 26       PDT            245            0.001226
# 29       WP$             89            0.000445
# 30        FW             71            0.000355
# 31      NNPS             31            0.000155
# 34        UH              7            0.000035
# 33         $              3            0.000015
# 32       POS              2            0.000010

# %%
# Filter out rows where POS Class is not "NOUN"
filtered_df = POS_Poe[POS_Poe['POS Class'] != 'NN']

# Sum the values in the Raw Frequency column of the filtered DataFrame
sum_except_noun = filtered_df['Raw Frequency'].sum()

print("Sum of Raw Frequency except NOUN:", sum_except_noun)
# Out:
# Sum of Raw Frequency except NOUN: 167937

# %%
#spacey version
import spacy
from collections import Counter
import pandas as pd

# Load the English language model in SpaCy
nlp = spacy.load("en_core_web_sm")

# Increase the max_length limit
nlp.max_length = 1500000  # or any value that suits your text length

def pos_frequency_spacy(text):
    # Process the text with SpaCy
    doc = nlp(text)
    # Get POS tags and count their frequencies
    pos_freq = Counter(token.pos_ for token in doc)
    # Calculate total number of POS tags
    total_pos_tags = sum(pos_freq.values())
    # Calculate relative frequency of each POS class
    relative_freq = {pos: freq / total_pos_tags for pos, freq in pos_freq.items()}
    return pos_freq, relative_freq

# Example text
pos_freq, relative_freq = pos_frequency_spacy(preprocessed_text_Poe)

# Create a DataFrame to store the results
POS_df = pd.DataFrame({"POS Class": list(pos_freq.keys()),
                       "Raw Frequency": list(pos_freq.values()),
                       "Relative Frequency": list(relative_freq.values())})

# Sort the DataFrame by relative frequency in descending order
POS_df = POS_df.sort_values(by='Relative Frequency', ascending=False)

# %%
POS_df
# Out:
#    POS Class  Raw Frequency  Relative Frequency
# 1       NOUN          38550            0.192167
# 7        ADP          27952            0.139337
# 2        DET          24074            0.120006
# 4       VERB          23264            0.115968
# 0       PRON          21731            0.108326
# 11       ADJ          14759            0.073572
# 12       ADV          12427            0.061947
# 8        AUX          11953            0.059584
# 5      CCONJ           8091            0.040333
# 6      SCONJ           5837            0.029097
# 3      PROPN           5089            0.025368
# 9       PART           4426            0.022063
# 14       NUM           1912            0.009531
# 10     PUNCT            274            0.001366
# 15      INTJ            193            0.000962
# 13         X             75            0.000374

# %%
# Filter out rows where POS Class is not "NOUN"
filtered_df = POS_df[POS_df['POS Class'] != 'NOUN']

# Sum the values in the Raw Frequency column of the filtered DataFrame
sum_except_noun = filtered_df['Raw Frequency'].sum()

print("Sum of Raw Frequency except NOUN:", sum_except_noun)
# Out:
# Sum of Raw Frequency except NOUN: 162057

# %% [markdown]
# ## Sheridan Le Fanu

# %%
pos_freq_Fanu, relative_freq_Fanu = pos_frequency(preprocessed_text_Fanu)

POS_Fanu = pd.DataFrame({"POS Class": list(pos_freq_Fanu.keys()),
                   "Raw Frequency": list(pos_freq_Fanu.values()),
                   "Relative Frequency": list(relative_freq_Fanu.values())})

POS_Fanu = POS_Fanu.sort_values(by='Relative Frequency', ascending=False)

# %%
POS_Fanu
# Out:
#    POS Class  Raw Frequency  Relative Frequency
# 0         NN          24101            0.158501
# 1         IN          19136            0.125848
# 5         DT          16228            0.106724
# 2        PRP          11827            0.077781
# 23       VBD          11188            0.073578
# 14        JJ          11000            0.072342
# 4         RB           8567            0.056341
# 9         CC           7945            0.052250
# 12       NNP           5648            0.037144
# 8         VB           4901            0.032232
# 11      PRP$           4707            0.030956
# 15       NNS           4561            0.029996
# 17       VBN           3861            0.025392
# 18        TO           3325            0.021867
# 20       VBG           2817            0.018526
# 6        VBP           2506            0.016481
# 3        VBZ           1851            0.012173
# 7         MD           1632            0.010733
# 10       WDT           1348            0.008865
# 21        CD            861            0.005662
# 16        WP            786            0.005169
# 29        RP            710            0.004669
# 19       WRB            696            0.004577
# 13        EX            474            0.003117
# 27       JJR            396            0.002604
# 24       RBR            336            0.002210
# 25       JJS            256            0.001684
# 28       PDT            226            0.001486
# 22       RBS             63            0.000414
# 26       WP$             60            0.000395
# 30        FW             19            0.000125
# 31      NNPS             14            0.000092
# 34        UH              6            0.000039
# 33        ''              3            0.000020
# 32       POS              1            0.000007

# %% [markdown]
# ## Gothic corpus

# %%
pos_freq_Gothic, relative_freq_Gothic = pos_frequency(preprocessed_text_Gothic)

POS_Gothic = pd.DataFrame({"POS Class": list(pos_freq_Gothic.keys()),
                   "Raw Frequency": list(pos_freq_Gothic.values()),
                   "Relative Frequency": list(relative_freq_Gothic.values())})

POS_Gothic = POS_Gothic.sort_values(by='Relative Frequency', ascending=False)

# %%
POS_Gothic
# Out:
#    POS Class  Raw Frequency  Relative Frequency
# 7         NN         425028            0.141439
# 5         IN         373937            0.124437
# 6         DT         288298            0.095938
# 1        PRP         286779            0.095433
# 16       VBD         210191            0.069946
# 10        JJ         185413            0.061701
# 3         RB         173611            0.057773
# 15        CC         128019            0.042601
# 12        VB         125237            0.041676
# 14       NNP         124532            0.041441
# 18       NNS          95361            0.031734
# 9       PRP$          95188            0.031676
# 8         TO          86280            0.028712
# 4        VBN          82531            0.027464
# 2        VBP          64273            0.021388
# 20       VBG          51055            0.016990
# 11        MD          48187            0.016035
# 13       VBZ          38707            0.012881
# 21       WDT          22527            0.007496
# 22        WP          18960            0.006309
# 17       WRB          17459            0.005810
# 0         CD          15257            0.005077
# 23        RP          12148            0.004043
# 28        EX           7488            0.002492
# 26       JJR           7483            0.002490
# 24       JJS           5305            0.001765
# 19       RBR           5290            0.001760
# 30       PDT           4830            0.001607
# 25       RBS           2028            0.000675
# 29       WP$           1368            0.000455
# 27        FW           1180            0.000393
# 31      NNPS            572            0.000190
# 32        UH            443            0.000147
# 33       POS             56            0.000019
# 34        ''              9            0.000003
# 35         $              6            0.000002

# %% [markdown]
# # Preposition/Subordinating conjunction

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')

def IN_finder(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    IN = [word for word, tag in tagged_words if tag.startswith('IN')]
    return IN

def IN_counter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    IN = [word for word, tag in tagged_words if tag.startswith('IN')]
    return len(IN)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Poe

# %%
n_IN_Poe = IN_counter(preprocessed_text_Poe)
print('Number of IN:', n_IN_Poe)
# Out:
# Number of IN: 30575

# %%
rel_freq_IN_Poe = rel_frequency(30575, 199831)
print("realative frequency of IN:", rel_freq_IN_Poe)
# Out:
# realative frequency of IN: 0.15300428862388718

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
import re

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences

# Function to find prepositions in text
def IN_finder(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)
    IN = [word for word, tag in tagged_words if tag.startswith('IN')]
    return IN

# Read the Poe corpus text from file
file_path_Poe = 'Allan Poe - Full Corpus.txt'
with open(file_path_Poe, 'r') as file:
    text_Poe = file.read()

# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    prepositions = IN_finder(subset_text)
    print(f"Number of prepositions in Subset {i + 1}: {len(prepositions)}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# 1568
# Number of prepositions in Subset 1: 5580
# Number of prepositions in Subset 2: 5301
# Number of prepositions in Subset 3: 5501
# Number of prepositions in Subset 4: 7196
# Number of prepositions in Subset 5: 6518

# %% [markdown]
# # Sheridan Le Fanu

# %%
n_IN_Fanu = IN_counter(preprocessed_text_Fanu)
print('Number of IN:', n_IN_Fanu)
# Out:
# Number of IN: 19136

# %%
rel_freq_IN_Fanu = rel_frequency(19136, 152056)
print("realative frequency of IN:", rel_freq_IN_Fanu)
# Out:
# realative frequency of IN: 0.12584837165254906

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    prepositions = IN_finder(subset_text)
    print(f"Number of prepositions in Subset {i + 1}: {len(prepositions)}")
# Out:
# 1097
# Number of prepositions in Subset 1: 4512
# Number of prepositions in Subset 2: 2966
# Number of prepositions in Subset 3: 3490
# Number of prepositions in Subset 4: 4091
# Number of prepositions in Subset 5: 3801

# %% [markdown]
# # Gothic corpus

# %%
n_IN_Gothic = IN_counter(preprocessed_text_Gothic)
print('Number of IN:', n_IN_Gothic)
# Out:
# Number of IN: 373937

# %%
rel_freq_IN_Gothic = rel_frequency(373937, 3005036)
print("realative frequency of IN:", rel_freq_IN_Gothic)
# Out:
# realative frequency of IN: 0.12443677879399781

# %%
# Gothic vs Poe

sentences = split_into_sentences(text_Gothic)
subset_size = 1568


# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    prepositions = IN_finder(subset_text)
    print(f"Number of prepositions in Subset {i + 1}: {len(prepositions)}")
# Out:
# Number of prepositions in Subset 1: 3845
# Number of prepositions in Subset 2: 3437
# Number of prepositions in Subset 3: 3342
# Number of prepositions in Subset 4: 3535
# Number of prepositions in Subset 5: 4425
# Number of prepositions in Subset 6: 3992
# Number of prepositions in Subset 7: 3937
# Number of prepositions in Subset 8: 4171
# Number of prepositions in Subset 9: 3272
# Number of prepositions in Subset 10: 4955
# Number of prepositions in Subset 11: 5121
# Number of prepositions in Subset 12: 5655
# Number of prepositions in Subset 13: 6399
# Number of prepositions in Subset 14: 6004
# Number of prepositions in Subset 15: 6426
# Number of prepositions in Subset 16: 6959
# Number of prepositions in Subset 17: 4174
# Number of prepositions in Subset 18: 3925
# Number of prepositions in Subset 19: 4361
# Number of prepositions in Subset 20: 3806
# Number of prepositions in Subset 21: 3550
# Number of prepositions in Subset 22: 4573
# Number of prepositions in Subset 23: 4421
# Number of prepositions in Subset 24: 4867
# Number of prepositions in Subset 25: 5213

# %%
# Gothic vs Fanu

sentences = split_into_sentences(text_Gothic)
subset_size = 1097


# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    prepositions = IN_finder(subset_text)
    print(f"Number of prepositions in Subset {i + 1}: {len(prepositions)}")
# Out:
# Number of prepositions in Subset 1: 2871
# Number of prepositions in Subset 2: 2190
# Number of prepositions in Subset 3: 2624
# Number of prepositions in Subset 4: 2439
# Number of prepositions in Subset 5: 2201
# Number of prepositions in Subset 6: 2629
# Number of prepositions in Subset 7: 3240
# Number of prepositions in Subset 8: 2614
# Number of prepositions in Subset 9: 2792
# Number of prepositions in Subset 10: 2889
# Number of prepositions in Subset 11: 2921
# Number of prepositions in Subset 12: 2571
# Number of prepositions in Subset 13: 2192
# Number of prepositions in Subset 14: 3527
# Number of prepositions in Subset 15: 3549
# Number of prepositions in Subset 16: 3887
# Number of prepositions in Subset 17: 3988
# Number of prepositions in Subset 18: 4766
# Number of prepositions in Subset 19: 3971
# Number of prepositions in Subset 20: 4142
# Number of prepositions in Subset 21: 4680
# Number of prepositions in Subset 22: 4382
# Number of prepositions in Subset 23: 4804
# Number of prepositions in Subset 24: 3013
# Number of prepositions in Subset 25: 2697

# %% [markdown]
# # Adj

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')

def adjectives_finder(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    adjectives = [word for word, tag in tagged_words if tag.startswith('JJ')]
    return adjectives

def adjectives_counter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    adjectives = [word for word, tag in tagged_words if tag.startswith('JJ')]
    return len(adjectives)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Allan Poe

# %%
n_adj_Poe = adjectives_counter(preprocessed_text_Poe)
print('Number of adjectives:', n_adj_Poe)
# Out:
# Number of adjectives: 15089

# %%
# move it up
def rel_frequency (n_POS, n_words):
    return n_POS/n_words

# %%
rel_freq_adj_Poe = rel_frequency(15089, 199831)
print("realative frequency of adjective:", rel_freq_adj_Poe)
# Out:
# realative frequency of adjective: 0.07550880494017445

# %%
def adjectives_counter_spacy(text):
    # Split the text into smaller chunks
    chunk_size = 100000  # Adjust the chunk size as needed
    chunks = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]
    
    adjectives = []
    for chunk in chunks:
        # Process each chunk with spaCy
        doc = nlp(chunk)
        # Extract adjectives from the chunk
        adjectives.extend([token.text for token in doc if token.pos_ == 'ADJ'])
    
    return len(adjectives)

# %%
#spacey mode
adjectives_counter_spacy(preprocessed_text_Poe)
# Out:
# 14761

# %%
rel_freq_adj_Poe = rel_frequency(14761, 199831)
print("realative frequency of adjective:", rel_freq_adj_Poe)
# Out:
# realative frequency of adjective: 0.07386741796818312

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_finder(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1568
# Number of adjectives in Subset 1: 2621
# Number of adjectives in Subset 2: 3025
# Number of adjectives in Subset 3: 2971
# Number of adjectives in Subset 4: 3296
# Number of adjectives in Subset 5: 3627

# %% [markdown]
# # Sheridan Le Fanu

# %%
n_adj_Fanu = adjectives_counter(preprocessed_text_Fanu)
print('Number of adjectives:', n_adj_Fanu)
# Out:
# Number of adjectives: 11652

# %%
rel_freq_adj_Fanu = rel_frequency(11652, 152056)
print("realative frequency of adjective:", rel_freq_adj_Fanu)
# Out:
# realative frequency of adjective: 0.0766296627558268

# %%
#spacey mode
adjectives_counter_spacy(preprocessed_text_Fanu)
# Out:
# 11438

# %%
rel_freq_adj_Fanu = rel_frequency(11438, 152056)
print("realative frequency of adjective:", rel_freq_adj_Fanu)
# Out:
# realative frequency of adjective: 0.07522228652601673

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_finder(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1097
# Number of adjectives in Subset 1: 2749
# Number of adjectives in Subset 2: 1767
# Number of adjectives in Subset 3: 1954
# Number of adjectives in Subset 4: 2586
# Number of adjectives in Subset 5: 2373

# %% [markdown]
# # Gothic corpus

# %%
n_adj_Gothic = adjectives_counter(preprocessed_text_Gothic)
print('Number of adjectives:', n_adj_Gothic)
# Out:
# Number of adjectives: 198201

# %%
rel_freq_adj_Gothic = rel_frequency(198201, 3005036)
print("realative frequency of adjective:", rel_freq_adj_Gothic)
# Out:
# realative frequency of adjective: 0.06595628138897504

# %%
#spacey mode
adjectives_counter_spacy(preprocessed_text_Gothic)
# Out:
# 190307

# %%
rel_freq_adj_Gothicothic = rel_frequency(190307, 3005036)
print("realative frequency of adjective:", rel_freq_adj_Gothic)
# Out:
# realative frequency of adjective: 0.06595628138897504

# %%
# Gothic vs Poe

sentences = split_into_sentences(text_Gothic)
subset_size = 1568


# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_finder(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of adjectives in Subset 1: 2637
# Number of adjectives in Subset 2: 2322
# Number of adjectives in Subset 3: 2541
# Number of adjectives in Subset 4: 2542
# Number of adjectives in Subset 5: 3427
# Number of adjectives in Subset 6: 3190
# Number of adjectives in Subset 7: 3029
# Number of adjectives in Subset 8: 3411
# Number of adjectives in Subset 9: 2473
# Number of adjectives in Subset 10: 2574
# Number of adjectives in Subset 11: 2807
# Number of adjectives in Subset 12: 3081
# Number of adjectives in Subset 13: 3158
# Number of adjectives in Subset 14: 2963
# Number of adjectives in Subset 15: 3043
# Number of adjectives in Subset 16: 3433
# Number of adjectives in Subset 17: 2550
# Number of adjectives in Subset 18: 2183
# Number of adjectives in Subset 19: 2545
# Number of adjectives in Subset 20: 2060
# Number of adjectives in Subset 21: 1972
# Number of adjectives in Subset 22: 2318
# Number of adjectives in Subset 23: 2179
# Number of adjectives in Subset 24: 2509
# Number of adjectives in Subset 25: 3061

# %%
# Gothic vs Poe

sentences = split_into_sentences(text_Gothic)
subset_size = 1097


# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_finder(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of adjectives in Subset 1: 1933
# Number of adjectives in Subset 2: 1542
# Number of adjectives in Subset 3: 1765
# Number of adjectives in Subset 4: 1871
# Number of adjectives in Subset 5: 1565
# Number of adjectives in Subset 6: 1971
# Number of adjectives in Subset 7: 2477
# Number of adjectives in Subset 8: 2091
# Number of adjectives in Subset 9: 2246
# Number of adjectives in Subset 10: 2211
# Number of adjectives in Subset 11: 2364
# Number of adjectives in Subset 12: 2042
# Number of adjectives in Subset 13: 1670
# Number of adjectives in Subset 14: 1798
# Number of adjectives in Subset 15: 1939
# Number of adjectives in Subset 16: 2068
# Number of adjectives in Subset 17: 2162
# Number of adjectives in Subset 18: 2373
# Number of adjectives in Subset 19: 2003
# Number of adjectives in Subset 20: 2031
# Number of adjectives in Subset 21: 2183
# Number of adjectives in Subset 22: 2164
# Number of adjectives in Subset 23: 2446
# Number of adjectives in Subset 24: 1833
# Number of adjectives in Subset 25: 1525

# %% [markdown]
# # Adj -ly

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')

def adjectives_counter_with_ly_filter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    adjectives_ly = [word for word, tag in tagged_words if tag.startswith('JJ') and word.endswith('ly')]
    return len(adjectives_ly)

def adjectives_with_ly_filter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    adjectives_ly = [word for word, tag in tagged_words if tag.startswith('JJ') and word.endswith('ly')]
    return (adjectives_ly)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Allan Poe

# %%
count_adjectives_ly_Poe = adjectives_counter_with_ly_filter(preprocessed_text_Poe)
print("Number of adjectives ending with '-ly':", count_adjectives_ly_Poe)
# Out:
# Number of adjectives ending with '-ly': 196

# %%
rel_freq_adj_ly_Poe = rel_frequency(196, 199831)
print("realative frequency of adjectives end with -ly:", rel_freq_adj_ly_Poe)
# Out:
# realative frequency of adjectives end with -ly: 0.0009808288003362842

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_with_ly_filter(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1568
# Number of adjectives in Subset 1: 19
# Number of adjectives in Subset 2: 42
# Number of adjectives in Subset 3: 31
# Number of adjectives in Subset 4: 44
# Number of adjectives in Subset 5: 39

# %% [markdown]
# # Sheridan Le Fanu

# %%
count_adjectives_ly_Fanu = adjectives_counter_with_ly_filter(preprocessed_text_Fanu)
print("Number of adjectives ending with '-ly':", count_adjectives_ly_Fanu)
# Out:
# Number of adjectives ending with '-ly': 198

# %%
rel_freq_adj_ly_Fanu = rel_frequency(198, 152056)
print("realative frequency of adjective end with -ly:", rel_freq_adj_ly_Fanu)
# Out:
# realative frequency of adjective end with -ly: 0.0013021518387962329

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_with_ly_filter(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1097
# Number of adjectives in Subset 1: 43
# Number of adjectives in Subset 2: 41
# Number of adjectives in Subset 3: 30
# Number of adjectives in Subset 4: 33
# Number of adjectives in Subset 5: 56

# %% [markdown]
# # Gothic corpus

# %%
count_adjectives_ly_Gothic = adjectives_counter_with_ly_filter(preprocessed_text_Gothic)
print("Number of adjectives ending with '-ly':", count_adjectives_ly_Gothic)
# Out:
# Number of adjectives ending with '-ly': 3224

# %%
rel_freq_adj_ly_Gothic = rel_frequency(3224, 3005036)
print("realative frequency of adjective end with -ly:", rel_freq_adj_ly_Gothic)
# Out:
# realative frequency of adjective end with -ly: 0.0010728656828071278

# %%
# Gothic vs Poe

sentences = split_into_sentences(text_Gothic)
subset_size = 1568


# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_with_ly_filter(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of adjectives in Subset 1: 28
# Number of adjectives in Subset 2: 35
# Number of adjectives in Subset 3: 32
# Number of adjectives in Subset 4: 27
# Number of adjectives in Subset 5: 35
# Number of adjectives in Subset 6: 30
# Number of adjectives in Subset 7: 36
# Number of adjectives in Subset 8: 37
# Number of adjectives in Subset 9: 21
# Number of adjectives in Subset 10: 53
# Number of adjectives in Subset 11: 32
# Number of adjectives in Subset 12: 68
# Number of adjectives in Subset 13: 51
# Number of adjectives in Subset 14: 61
# Number of adjectives in Subset 15: 40
# Number of adjectives in Subset 16: 45
# Number of adjectives in Subset 17: 40
# Number of adjectives in Subset 18: 39
# Number of adjectives in Subset 19: 49
# Number of adjectives in Subset 20: 34
# Number of adjectives in Subset 21: 35
# Number of adjectives in Subset 22: 52
# Number of adjectives in Subset 23: 37
# Number of adjectives in Subset 24: 48
# Number of adjectives in Subset 25: 38

# %%
# Gothic vs Fanu

sentences = split_into_sentences(text_Gothic)
subset_size = 1097


# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adjectives_with_ly_filter(subset_text)
    print(f"Number of adjectives in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of adjectives in Subset 1: 25
# Number of adjectives in Subset 2: 10
# Number of adjectives in Subset 3: 30
# Number of adjectives in Subset 4: 26
# Number of adjectives in Subset 5: 19
# Number of adjectives in Subset 6: 21
# Number of adjectives in Subset 7: 24
# Number of adjectives in Subset 8: 15
# Number of adjectives in Subset 9: 29
# Number of adjectives in Subset 10: 24
# Number of adjectives in Subset 11: 24
# Number of adjectives in Subset 12: 21
# Number of adjectives in Subset 13: 14
# Number of adjectives in Subset 14: 41
# Number of adjectives in Subset 15: 30
# Number of adjectives in Subset 16: 22
# Number of adjectives in Subset 17: 47
# Number of adjectives in Subset 18: 50
# Number of adjectives in Subset 19: 36
# Number of adjectives in Subset 20: 38
# Number of adjectives in Subset 21: 27
# Number of adjectives in Subset 22: 27
# Number of adjectives in Subset 23: 35
# Number of adjectives in Subset 24: 32
# Number of adjectives in Subset 25: 23

# %% [markdown]
# # Adjective before noun

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def count_adj_before_noun(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)
    count = 0
    total_nouns = 0
    for i in range(1, len(tagged_words)):
        if tagged_words[i][1] in ['NN', 'NNS', 'NNP', 'NNPS']:
            total_nouns += 1
            if tagged_words[i - 1][1] == 'JJ':
                count += 1
    if total_nouns == 0:
        return 0
    else:
        #return (count / total_nouns), count  # Return relative frequency
        print("Total number of adjectives before nouns:", count)
        print("Relative frequency of adjectives before nouns:", (count / total_nouns))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def count_adj_before_noun2(text):
    words = word_tokenize(text)
    tagged_words = pos_tag(words)
    count = 0
    total_nouns = 0
    for i in range(1, len(tagged_words)):
        if tagged_words[i][1] in ['NN', 'NNS', 'NNP', 'NNPS']:
            total_nouns += 1
            if tagged_words[i - 1][1] == 'JJ':
                count += 1
    if total_nouns == 0:
        return 0
    else:
        return count
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Allan Poe

# %%
count_adj_before_noun(preprocessed_text_Poe)
# Out:
# Total number of adjectives before nouns: 8934
# Relative frequency of adjectives before nouns: 0.19861719392632446

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of adjectives before nouns in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives_count = count_adj_before_noun2(subset_text)
    print(f"Number of adjectives before nouns in Subset {i + 1}: {adjectives_count}")
# Out:
# 1568
# Number of adjectives before nouns in Subset 1: 1531
# Number of adjectives before nouns in Subset 2: 1792
# Number of adjectives before nouns in Subset 3: 1725
# Number of adjectives before nouns in Subset 4: 1878
# Number of adjectives before nouns in Subset 5: 2220

# %% [markdown]
# # Sheridan Le Fanu

# %%
count_adj_before_noun(preprocessed_text_Fanu)
# Out:
# Total number of adjectives before nouns: 6796
# Relative frequency of adjectives before nouns: 0.19800134020918916

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of adjectives before nouns in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives_count = count_adj_before_noun2(subset_text)
    print(f"Number of adjectives before nouns in Subset {i + 1}: {adjectives_count}")
# Out:
# 1097
# Number of adjectives before nouns in Subset 1: 1625
# Number of adjectives before nouns in Subset 2: 977
# Number of adjectives before nouns in Subset 3: 1117
# Number of adjectives before nouns in Subset 4: 1375
# Number of adjectives before nouns in Subset 5: 1418

# %% [markdown]
# # Gothic corpus

# %%
count_adj_before_noun(preprocessed_text_Gothic)
# Out:
# Total number of adjectives before nouns: 112205
# Relative frequency of adjectives before nouns: 0.17382837614040741

# %%
#Gothic vs Poe
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find the number of adjectives before nouns in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives_count = count_adj_before_noun2(subset_text)
    print(f"Number of adjectives before nouns in Subset {i + 1}: {adjectives_count}")
# Out:
# Number of adjectives before nouns in Subset 1: 1488
# Number of adjectives before nouns in Subset 2: 1319
# Number of adjectives before nouns in Subset 3: 1378
# Number of adjectives before nouns in Subset 4: 1450
# Number of adjectives before nouns in Subset 5: 1877
# Number of adjectives before nouns in Subset 6: 1729
# Number of adjectives before nouns in Subset 7: 1693
# Number of adjectives before nouns in Subset 8: 1857
# Number of adjectives before nouns in Subset 9: 1374
# Number of adjectives before nouns in Subset 10: 1355
# Number of adjectives before nouns in Subset 11: 1410
# Number of adjectives before nouns in Subset 12: 1494
# Number of adjectives before nouns in Subset 13: 1589
# Number of adjectives before nouns in Subset 14: 1427
# Number of adjectives before nouns in Subset 15: 1435
# Number of adjectives before nouns in Subset 16: 1757
# Number of adjectives before nouns in Subset 17: 1474
# Number of adjectives before nouns in Subset 18: 1273
# Number of adjectives before nouns in Subset 19: 1500
# Number of adjectives before nouns in Subset 20: 1171
# Number of adjectives before nouns in Subset 21: 1115
# Number of adjectives before nouns in Subset 22: 1377
# Number of adjectives before nouns in Subset 23: 1316
# Number of adjectives before nouns in Subset 24: 1587
# Number of adjectives before nouns in Subset 25: 1732

# %%
#Gothic vs Fanu
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find the number of adjectives before nouns in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives_count = count_adj_before_noun2(subset_text)
    print(f"Number of adjectives before nouns in Subset {i + 1}: {adjectives_count}")
# Out:
# Number of adjectives before nouns in Subset 1: 1108
# Number of adjectives before nouns in Subset 2: 859
# Number of adjectives before nouns in Subset 3: 1000
# Number of adjectives before nouns in Subset 4: 994
# Number of adjectives before nouns in Subset 5: 902
# Number of adjectives before nouns in Subset 6: 1107
# Number of adjectives before nouns in Subset 7: 1352
# Number of adjectives before nouns in Subset 8: 1128
# Number of adjectives before nouns in Subset 9: 1258
# Number of adjectives before nouns in Subset 10: 1214
# Number of adjectives before nouns in Subset 11: 1271
# Number of adjectives before nouns in Subset 12: 1139
# Number of adjectives before nouns in Subset 13: 920
# Number of adjectives before nouns in Subset 14: 951
# Number of adjectives before nouns in Subset 15: 994
# Number of adjectives before nouns in Subset 16: 1015
# Number of adjectives before nouns in Subset 17: 1069
# Number of adjectives before nouns in Subset 18: 1228
# Number of adjectives before nouns in Subset 19: 936
# Number of adjectives before nouns in Subset 20: 985
# Number of adjectives before nouns in Subset 21: 1034
# Number of adjectives before nouns in Subset 22: 985
# Number of adjectives before nouns in Subset 23: 1346
# Number of adjectives before nouns in Subset 24: 1067
# Number of adjectives before nouns in Subset 25: 886

# %% [markdown]
# # Noun

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')

def noun_finder(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    nouns = [word for word, tag in tagged_words if tag.startswith('NN')]
    return nouns

def noun_counter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    nouns = [word for word, tag in tagged_words if tag.startswith('NN')]
    return len(nouns)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Poe

# %%
n_nouns_Poe = noun_counter(preprocessed_text_Poe)
print('Number of nouns:', n_nouns_Poe)
# Out:
# Number of nouns: 44981

# %%
rel_freq_noun_Poe = rel_frequency(44981, 199831)
print("realative frequency of verb:", rel_freq_noun_Poe)
# Out:
# realative frequency of verb: 0.22509520544860406

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = noun_finder(subset_text)
    print(f"Number of nouns in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1568
# Number of adjectives in Subset 1: 9045
# Number of adjectives in Subset 2: 8679
# Number of adjectives in Subset 3: 7960
# Number of adjectives in Subset 4: 9811
# Number of adjectives in Subset 5: 10421

# %% [markdown]
# # Le Fanu

# %%
n_nouns_Fanu = noun_counter(preprocessed_text_Fanu)
print('Number of nouns:', n_nouns_Fanu)
# Out:
# Number of verbs: 34324

# %%
rel_freq_nouns_Fanu = rel_frequency(34324, 152056)
print("realative frequency of nouns:", rel_freq_nouns_Fanu)
# Out:
# realative frequency of nouns: 0.22573262482243384

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = noun_finder(subset_text)
    print(f"Number of nouns in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1097
# Number of adjectives in Subset 1: 7820
# Number of adjectives in Subset 2: 5917
# Number of adjectives in Subset 3: 6400
# Number of adjectives in Subset 4: 6376
# Number of adjectives in Subset 5: 6756

# %% [markdown]
# # Gothic corpus

# %%
n_nouns_Gothic = noun_counter(preprocessed_text_Gothic)
print('Number of nouns:', n_nouns_Gothic)
# Out:
# Number of nouns: 645493

# %%
rel_freq_nouns_Gothic = rel_frequency(645493, 3005036)
print("realative frequency of nouns:", rel_freq_nouns_Gothic)
# Out:
# realative frequency of nouns: 0.2148037494392746

# %%
# Gothic vs Poe
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = noun_finder(subset_text)
    print(f"Number of nouns in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of nouns in Subset 1: 8749
# Number of nouns in Subset 2: 7489
# Number of nouns in Subset 3: 7772
# Number of nouns in Subset 4: 7921
# Number of nouns in Subset 5: 9659
# Number of nouns in Subset 6: 8807
# Number of nouns in Subset 7: 9157
# Number of nouns in Subset 8: 9657
# Number of nouns in Subset 9: 7778
# Number of nouns in Subset 10: 8284
# Number of nouns in Subset 11: 9323
# Number of nouns in Subset 12: 9585
# Number of nouns in Subset 13: 10368
# Number of nouns in Subset 14: 9378
# Number of nouns in Subset 15: 9950
# Number of nouns in Subset 16: 11056
# Number of nouns in Subset 17: 7525
# Number of nouns in Subset 18: 7597
# Number of nouns in Subset 19: 8106
# Number of nouns in Subset 20: 7411
# Number of nouns in Subset 21: 6958
# Number of nouns in Subset 22: 8394
# Number of nouns in Subset 23: 7469
# Number of nouns in Subset 24: 8658
# Number of nouns in Subset 25: 8124

# %%
# Gothic vs Fanu
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = noun_finder(subset_text)
    print(f"Number of nouns in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of nouns in Subset 1: 6462
# Number of nouns in Subset 2: 5119
# Number of nouns in Subset 3: 5560
# Number of nouns in Subset 4: 5618
# Number of nouns in Subset 5: 5056
# Number of nouns in Subset 6: 5750
# Number of nouns in Subset 7: 7013
# Number of nouns in Subset 8: 5988
# Number of nouns in Subset 9: 6314
# Number of nouns in Subset 10: 6630
# Number of nouns in Subset 11: 6652
# Number of nouns in Subset 12: 6172
# Number of nouns in Subset 13: 5295
# Number of nouns in Subset 14: 5787
# Number of nouns in Subset 15: 6444
# Number of nouns in Subset 16: 6614
# Number of nouns in Subset 17: 6705
# Number of nouns in Subset 18: 7486
# Number of nouns in Subset 19: 6603
# Number of nouns in Subset 20: 6528
# Number of nouns in Subset 21: 7233
# Number of nouns in Subset 22: 6740
# Number of nouns in Subset 23: 7821
# Number of nouns in Subset 24: 5479
# Number of nouns in Subset 25: 5226

# %% [markdown]
# # Verb

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')

def verbs_finder(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    verbs = [word for word, tag in tagged_words if tag.startswith('VB')]
    return verbs

def verbs_counter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    verbs = [word for word, tag in tagged_words if tag.startswith('VB')]
    return len(verbs)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def verbs_counter_spacy(text):
    # Split the text into smaller chunks
    chunk_size = 100000  # Adjust the chunk size as needed
    chunks = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]
    
    adjectives = []
    for chunk in chunks:
        # Process each chunk with spaCy
        doc = nlp(chunk)
        # Extract adjectives from the chunk
        adjectives.extend([token.text for token in doc if token.pos_ == 'ADJ'])
    
    return len(adjectives)

# %% [markdown]
# # Allan Poe

# %%
n_verbs_Poe = verbs_counter(preprocessed_text_Poe)
print('Number of verbs:', n_verbs_Poe)
# Out:
# Number of adjectives: 32906

# %%
rel_freq_verb_Poe = rel_frequency(32906, 199831)
print("realative frequency of verb:", rel_freq_verb_Poe)
# Out:
# realative frequency of verb: 0.16466914542788658

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = verbs_finder(subset_text)
    print(f"Number of verbs in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1568
# Number of verbs in Subset 1: 6472
# Number of verbs in Subset 2: 5861
# Number of verbs in Subset 3: 6118
# Number of verbs in Subset 4: 7552
# Number of verbs in Subset 5: 6601

# %% [markdown]
# # Sheridan Le Fanu

# %%
n_verbs_Fanu = verbs_counter(preprocessed_text_Fanu)
print('Number of verbs:', n_verbs_Fanu)
# Out:
# Number of adjectives: 27124

# %%
rel_freq_verb_Fanu = rel_frequency(27124, 152056)
print("realative frequency of verb:", rel_freq_verb_Fanu)
# Out:
# realative frequency of verb: 0.1783816488662072

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = verbs_finder(subset_text)
    print(f"Number of verbs in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1097
# Number of verbs in Subset 1: 5808
# Number of verbs in Subset 2: 4605
# Number of verbs in Subset 3: 5069
# Number of verbs in Subset 4: 5996
# Number of verbs in Subset 5: 4869

# %% [markdown]
# # Gothic corpus

# %%
n_verbs_Gothic = verbs_counter(preprocessed_text_Gothic)
print('Number of verbs:', n_verbs_Gothic)
# Out:
# Number of verbs: 571994

# %%
rel_freq_verb_Gothic = rel_frequency(571994, 3005036)
print("realative frequency of verb:", rel_freq_verb_Gothic)
# Out:
# realative frequency of verb: 0.19034514062393929

# %%
# Poe vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = verbs_finder(subset_text)
    print(f"Number of verbs in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of verbs in Subset 1: 7429
# Number of verbs in Subset 2: 6866
# Number of verbs in Subset 3: 7280
# Number of verbs in Subset 4: 7028
# Number of verbs in Subset 5: 7048
# Number of verbs in Subset 6: 6501
# Number of verbs in Subset 7: 6839
# Number of verbs in Subset 8: 7219
# Number of verbs in Subset 9: 5891
# Number of verbs in Subset 10: 7838
# Number of verbs in Subset 11: 8716
# Number of verbs in Subset 12: 9250
# Number of verbs in Subset 13: 9666
# Number of verbs in Subset 14: 9909
# Number of verbs in Subset 15: 10452
# Number of verbs in Subset 16: 10915
# Number of verbs in Subset 17: 5650
# Number of verbs in Subset 18: 6065
# Number of verbs in Subset 19: 6107
# Number of verbs in Subset 20: 5941
# Number of verbs in Subset 21: 5333
# Number of verbs in Subset 22: 6457
# Number of verbs in Subset 23: 6045
# Number of verbs in Subset 24: 6498
# Number of verbs in Subset 25: 7459

# %%
# Fanu vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = verbs_finder(subset_text)
    print(f"Number of verbs in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of verbs in Subset 1: 5429
# Number of verbs in Subset 2: 4596
# Number of verbs in Subset 3: 5004
# Number of verbs in Subset 4: 5289
# Number of verbs in Subset 5: 4864
# Number of verbs in Subset 6: 4711
# Number of verbs in Subset 7: 5146
# Number of verbs in Subset 8: 4477
# Number of verbs in Subset 9: 4518
# Number of verbs in Subset 10: 4934
# Number of verbs in Subset 11: 5022
# Number of verbs in Subset 12: 4655
# Number of verbs in Subset 13: 3912
# Number of verbs in Subset 14: 5460
# Number of verbs in Subset 15: 5824
# Number of verbs in Subset 16: 6719
# Number of verbs in Subset 17: 6338
# Number of verbs in Subset 18: 6985
# Number of verbs in Subset 19: 6643
# Number of verbs in Subset 20: 6827
# Number of verbs in Subset 21: 7499
# Number of verbs in Subset 22: 7724
# Number of verbs in Subset 23: 6817
# Number of verbs in Subset 24: 3912
# Number of verbs in Subset 25: 4175

# %% [markdown]
# # juxtapose verbs

# %%
import spacy

def count_juxtaposed_verbs(text):
    # Load the English model
    nlp = spacy.load("en_core_web_sm")

    # Initialize set for verbs
    verbs_set = set()

    # List of conjunctions, punctuation marks, and space to consider
    conj_punct_space = ['and', 'or', ',']

    # Split text into chunks of maximum length allowed by SpaCy
    max_length = 1000000
    chunks = [text[i:i+max_length] for i in range(0, len(text), max_length)]

    # Process each chunk with SpaCy and count juxtaposed verbs
    for chunk in chunks:
        doc = nlp(chunk)
        tagged_words = [(token.text, token.pos_) for token in doc]
        for i in range(len(tagged_words) - 2):
            if tagged_words[i][1] == 'VERB':
                if tagged_words[i + 1][0] in conj_punct_space:
                    if tagged_words[i + 2][1] == 'VERB':
                        verbs_set.update([tagged_words[i][0], tagged_words[i + 2][0]])

    return len(verbs_set)

# %% [markdown]
# # Allan Poe

# %%
count_juxtaposed_verbs(preprocessed_text_Poe)
# Out:
# 450

# %%
rel_freq_juxtaposed_verbs_Poe = rel_frequency(450, 32906)
print("realative frequency of juxtaposed verb:", rel_freq_juxtaposed_verbs_Poe)
# Out:
# realative frequency of juxtaposed verb: 0.0136753175712636

# %%
import spacy
import re

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences

# Function to count juxtaposed verbs in a subset of text
def count_juxtaposed_verbs_subset(subset_text):
    # Load the English model
    nlp = spacy.load("en_core_web_sm")

    # Initialize set for verbs
    verbs_set = set()

    # List of conjunctions, punctuation marks, and space to consider
    conj_punct_space = ['and', 'or', ',']

    # Process the subset with SpaCy and count juxtaposed verbs
    doc = nlp(subset_text)
    tagged_words = [(token.text, token.pos_) for token in doc]
    for i in range(len(tagged_words) - 2):
        if tagged_words[i][1] == 'VERB':
            if tagged_words[i + 1][0] in conj_punct_space:
                if tagged_words[i + 2][1] == 'VERB':
                    verbs_set.update([tagged_words[i][0], tagged_words[i + 2][0]])

    return len(verbs_set)


# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5

# Find the number of juxtaposed verbs in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    verbs_count_subset = count_juxtaposed_verbs_subset(subset_text)
    print(f"Number of Juxtaposed Verbs in Subset {i + 1}: {verbs_count_subset}")
# Out:
# Number of Juxtaposed Verbs in Subset 1: 77
# Number of Juxtaposed Verbs in Subset 2: 128
# Number of Juxtaposed Verbs in Subset 3: 102
# Number of Juxtaposed Verbs in Subset 4: 87
# Number of Juxtaposed Verbs in Subset 5: 105

# %% [markdown]
# # Sheridan Le Fanu

# %%
count_juxtaposed_verbs(preprocessed_text_Fanu)
# Out:
# 492

# %%
rel_freq_juxtaposed_verbs_Fanu = rel_frequency(492, 27124)
print("realative frequency of juxtaposed verb:", rel_freq_juxtaposed_verbs_Fanu)
# Out:
# realative frequency of juxtaposed verb: 0.018138917563781155

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5

# Find the number of juxtaposed verbs in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    verbs_count_subset = count_juxtaposed_verbs_subset(subset_text)
    print(f"Number of Juxtaposed Verbs in Subset {i + 1}: {verbs_count_subset}")
# Out:
# Number of Juxtaposed Verbs in Subset 1: 124
# Number of Juxtaposed Verbs in Subset 2: 82
# Number of Juxtaposed Verbs in Subset 3: 98
# Number of Juxtaposed Verbs in Subset 4: 147
# Number of Juxtaposed Verbs in Subset 5: 125

# %% [markdown]
# # Gothic corpus

# %%
count_juxtaposed_verbs(preprocessed_text_Gothic)
# Out:
# 3373

# %%
rel_freq_juxtaposed_verbs_Gothic = rel_frequency(3373, 571994)
print("realative frequency of juxtaposed verb:", rel_freq_juxtaposed_verbs_Gothic)
# Out:
# realative frequency of juxtaposed verb: 0.005896915002604922

# %%
#Poe Vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find the number of juxtaposed verbs in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    verbs_count_subset = count_juxtaposed_verbs_subset(subset_text)
    print(f"Number of Juxtaposed Verbs in Subset {i + 1}: {verbs_count_subset}")
# Out:
# Number of Juxtaposed Verbs in Subset 1: 162
# Number of Juxtaposed Verbs in Subset 2: 133
# Number of Juxtaposed Verbs in Subset 3: 147
# Number of Juxtaposed Verbs in Subset 4: 163
# Number of Juxtaposed Verbs in Subset 5: 162
# Number of Juxtaposed Verbs in Subset 6: 144
# Number of Juxtaposed Verbs in Subset 7: 181
# Number of Juxtaposed Verbs in Subset 8: 199
# Number of Juxtaposed Verbs in Subset 9: 144
# Number of Juxtaposed Verbs in Subset 10: 102
# Number of Juxtaposed Verbs in Subset 11: 89
# Number of Juxtaposed Verbs in Subset 12: 96
# Number of Juxtaposed Verbs in Subset 13: 94
# Number of Juxtaposed Verbs in Subset 14: 104
# Number of Juxtaposed Verbs in Subset 15: 136
# Number of Juxtaposed Verbs in Subset 16: 134
# Number of Juxtaposed Verbs in Subset 17: 95
# Number of Juxtaposed Verbs in Subset 18: 106
# Number of Juxtaposed Verbs in Subset 19: 98
# Number of Juxtaposed Verbs in Subset 20: 82
# Number of Juxtaposed Verbs in Subset 21: 81
# Number of Juxtaposed Verbs in Subset 22: 81
# Number of Juxtaposed Verbs in Subset 23: 85
# Number of Juxtaposed Verbs in Subset 24: 107
# Number of Juxtaposed Verbs in Subset 25: 126

# %%
#Fanu Vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find the number of juxtaposed verbs in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    verbs_count_subset = count_juxtaposed_verbs_subset(subset_text)
    print(f"Number of Juxtaposed Verbs in Subset {i + 1}: {verbs_count_subset}")
# Out:
# Number of Juxtaposed Verbs in Subset 1: 136
# Number of Juxtaposed Verbs in Subset 2: 93
# Number of Juxtaposed Verbs in Subset 3: 102
# Number of Juxtaposed Verbs in Subset 4: 112
# Number of Juxtaposed Verbs in Subset 5: 112
# Number of Juxtaposed Verbs in Subset 6: 118
# Number of Juxtaposed Verbs in Subset 7: 122
# Number of Juxtaposed Verbs in Subset 8: 119
# Number of Juxtaposed Verbs in Subset 9: 89
# Number of Juxtaposed Verbs in Subset 10: 146
# Number of Juxtaposed Verbs in Subset 11: 125
# Number of Juxtaposed Verbs in Subset 12: 143
# Number of Juxtaposed Verbs in Subset 13: 99
# Number of Juxtaposed Verbs in Subset 14: 76
# Number of Juxtaposed Verbs in Subset 15: 49
# Number of Juxtaposed Verbs in Subset 16: 83
# Number of Juxtaposed Verbs in Subset 17: 57
# Number of Juxtaposed Verbs in Subset 18: 76
# Number of Juxtaposed Verbs in Subset 19: 74
# Number of Juxtaposed Verbs in Subset 20: 72
# Number of Juxtaposed Verbs in Subset 21: 94
# Number of Juxtaposed Verbs in Subset 22: 101
# Number of Juxtaposed Verbs in Subset 23: 91
# Number of Juxtaposed Verbs in Subset 24: 63
# Number of Juxtaposed Verbs in Subset 25: 90

# %% [markdown]
# # Adverb

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')

def adverbs_finder(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    adjectives = [word for word, tag in tagged_words if tag.startswith('RB')]
    return adjectives

def adverbs_counter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    adjectives = [word for word, tag in tagged_words if tag.startswith('RB')]
    return len(adjectives)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Allan Poe

# %%
n_adv_Poe = adverbs_counter(preprocessed_text_Poe)
print('Number of adverbs:', n_adv_Poe)
# Out:
# Number of verbs: 12824

# %%
rel_freq_adv_Poe = rel_frequency(12824, 199831)
print("realative frequency of adverbs:", rel_freq_adv_Poe)
# Out:
# realative frequency of verb: 0.0641742272220026

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adverbs_finder(subset_text)
    print(f"Number of adverb in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1568
# Number of adverb in Subset 1: 2264
# Number of adverb in Subset 2: 2276
# Number of adverb in Subset 3: 2496
# Number of adverb in Subset 4: 3001
# Number of adverb in Subset 5: 2734

# %% [markdown]
# # Sheridan Le Fanu

# %%
n_adv_Fanu = adverbs_counter(preprocessed_text_Fanu)
print('Number of adverbs:', n_adv_Fanu)
# Out:
# Number of verbs: 8966

# %%
rel_freq_adv_Fanu = rel_frequency(8966, 152056)
print("realative frequency of adverbs:", rel_freq_adv_Fanu)
# Out:
# realative frequency of adverbs: 0.05896511811437891

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adverbs_finder(subset_text)
    print(f"Number of adverb in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1097
# Number of adverb in Subset 1: 2161
# Number of adverb in Subset 2: 1588
# Number of adverb in Subset 3: 1794
# Number of adverb in Subset 4: 2155
# Number of adverb in Subset 5: 1597

# %% [markdown]
# # Gothic corpus

# %%
n_adv_Gothic = adverbs_counter(preprocessed_text_Gothic)
print('Number of adverbs:', n_adv_Gothic)
# Out:
# Number of adverbs: 180929

# %%
rel_freq_adverb_Gothic = rel_frequency(180929, 3005036)
print("realative frequency of adverb:", rel_freq_adverb_Gothic)
# Out:
# realative frequency of adverb: 0.06020859650267085

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adverbs_finder(subset_text)
    print(f"Number of adverb in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of adverb in Subset 1: 2077
# Number of adverb in Subset 2: 1841
# Number of adverb in Subset 3: 2031
# Number of adverb in Subset 4: 2123
# Number of adverb in Subset 5: 2407
# Number of adverb in Subset 6: 2313
# Number of adverb in Subset 7: 2356
# Number of adverb in Subset 8: 2363
# Number of adverb in Subset 9: 1866
# Number of adverb in Subset 10: 2881
# Number of adverb in Subset 11: 3250
# Number of adverb in Subset 12: 3451
# Number of adverb in Subset 13: 3404
# Number of adverb in Subset 14: 3840
# Number of adverb in Subset 15: 3761
# Number of adverb in Subset 16: 3870
# Number of adverb in Subset 17: 1815
# Number of adverb in Subset 18: 1829
# Number of adverb in Subset 19: 2028
# Number of adverb in Subset 20: 1732
# Number of adverb in Subset 21: 1572
# Number of adverb in Subset 22: 1828
# Number of adverb in Subset 23: 1711
# Number of adverb in Subset 24: 1736
# Number of adverb in Subset 25: 2725

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = adverbs_finder(subset_text)
    print(f"Number of adverb in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of adverb in Subset 1: 1499
# Number of adverb in Subset 2: 1230
# Number of adverb in Subset 3: 1366
# Number of adverb in Subset 4: 1534
# Number of adverb in Subset 5: 1336
# Number of adverb in Subset 6: 1577
# Number of adverb in Subset 7: 1744
# Number of adverb in Subset 8: 1498
# Number of adverb in Subset 9: 1625
# Number of adverb in Subset 10: 1733
# Number of adverb in Subset 11: 1675
# Number of adverb in Subset 12: 1430
# Number of adverb in Subset 13: 1258
# Number of adverb in Subset 14: 2046
# Number of adverb in Subset 15: 2163
# Number of adverb in Subset 16: 2524
# Number of adverb in Subset 17: 2367
# Number of adverb in Subset 18: 2505
# Number of adverb in Subset 19: 2328
# Number of adverb in Subset 20: 2705
# Number of adverb in Subset 21: 2719
# Number of adverb in Subset 22: 2810
# Number of adverb in Subset 23: 2342
# Number of adverb in Subset 24: 1277
# Number of adverb in Subset 25: 1259

# %%
#Kruskal–Wallis test
from scipy.stats import kruskal
from nltk.tag import pos_tag


# Count adjectives before nouns for each corpus
Adv_Poe = [adverbs_counter(text) for text in preprocessed_text_Poe]
Adv_Gothic = [adverbs_counter(text) for text in preprocessed_text_Gothic]
Adv_Fanu = [adverbs_counter(text) for text in preprocessed_text_Fanu]

# Perform Kruskal-Wallis H test
statistic, p_value = kruskal(Adv_Poe, Adv_Gothic, Adv_Fanu)

# Print the results
print("Kruskal-Wallis H statistic:", statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a statistically significant difference in the number of adjectives before nouns among the three corpora.")
else:
    print("Fail to reject the null hypothesis. There is no statistically significant difference in the number of adjectives before nouns among the three corpora.")
# Out:
# Kruskal-Wallis H statistic: 0.0
# p-value: 1.0
# Fail to reject the null hypothesis. There is no statistically significant difference in the number of adjectives before nouns among the three corpora.

# %% [markdown]
# # Content words (Noun, Verb, Adj, Adv)

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('averaged_perceptron_tagger')

def ContenW_finder(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    Content_words = [word for word, tag in tagged_words if tag.startswith(('NN', 'JJ', 'RB', 'VB'))]
    return Content_words

def ContenW_counter(text):
    words = word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    Content_words = [word for word, tag in tagged_words if tag.startswith(('NN', 'JJ', 'RB', 'VB'))]
    return len(Content_words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/students/arazz002/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Allan Poe

# %%
n_ContenW_Poe = ContenW_counter(preprocessed_text_Poe)
print('Number of content words:', n_ContenW_Poe)
# Out:
# Number of content words: 105800

# %%
rel_freq_ContenW_Poe = rel_frequency(105800, 199831)
print("realative frequency of content words:", rel_freq_ContenW_Poe)
# Out:
# realative frequency of content words: 0.5294473830386677

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = ContenW_finder(subset_text)
    print(f"Number of content words in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1568
# Number of content words in Subset 1: 20402
# Number of content words in Subset 2: 19841
# Number of content words in Subset 3: 19545
# Number of content words in Subset 4: 23660
# Number of content words in Subset 5: 23383

# %% [markdown]
# # Sheridan Le Fanu

# %%
n_ContenW_Fanu = ContenW_counter(preprocessed_text_Fanu)
print('Number of content words:', n_ContenW_Fanu)
# Out:
# Number of content words: 82066

# %%
rel_freq_ContenW_Fanu = rel_frequency(82066, 152056)
print("realative frequency of content words:", rel_freq_ContenW_Fanu)
# Out:
# realative frequency of content words: 0.5397090545588468

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the number of prepositions in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = ContenW_finder(subset_text)
    print(f"Number of content words in Subset {i + 1}: {len(adjectives)}")
# Out:
# 1097
# Number of content words in Subset 1: 18538
# Number of content words in Subset 2: 13877
# Number of content words in Subset 3: 15217
# Number of content words in Subset 4: 17113
# Number of content words in Subset 5: 15595

# %% [markdown]
# # Gothic corpus

# %%
n_ContenW_Gothic = ContenW_counter(preprocessed_text_Gothic)
print('Number of content words:', n_ContenW_Gothic)
# Out:
# Number of content words: 1596617

# %%
rel_freq_ContenW_Gothic = rel_frequency(1596617, 3005036)
print("realative frequency of content words:", rel_freq_ContenW_Gothic)
# Out:
# realative frequency of content words: 0.5313137679548597

# %%
#Poe vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = ContenW_finder(subset_text)
    print(f"Number of content words in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of content words in Subset 1: 20892
# Number of content words in Subset 2: 18518
# Number of content words in Subset 3: 19624
# Number of content words in Subset 4: 19614
# Number of content words in Subset 5: 22541
# Number of content words in Subset 6: 20811
# Number of content words in Subset 7: 21381
# Number of content words in Subset 8: 22650
# Number of content words in Subset 9: 18008
# Number of content words in Subset 10: 21577
# Number of content words in Subset 11: 24096
# Number of content words in Subset 12: 25367
# Number of content words in Subset 13: 26596
# Number of content words in Subset 14: 26090
# Number of content words in Subset 15: 27206
# Number of content words in Subset 16: 29274
# Number of content words in Subset 17: 17540
# Number of content words in Subset 18: 17674
# Number of content words in Subset 19: 18786
# Number of content words in Subset 20: 17144
# Number of content words in Subset 21: 15835
# Number of content words in Subset 22: 18997
# Number of content words in Subset 23: 17404
# Number of content words in Subset 24: 19401
# Number of content words in Subset 25: 21369

# %%
#Fanu vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find the number of prepositions in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    adjectives = ContenW_finder(subset_text)
    print(f"Number of content words in Subset {i + 1}: {len(adjectives)}")
# Out:
# Number of content words in Subset 1: 15323
# Number of content words in Subset 2: 12487
# Number of content words in Subset 3: 13695
# Number of content words in Subset 4: 14312
# Number of content words in Subset 5: 12821
# Number of content words in Subset 6: 14009
# Number of content words in Subset 7: 16380
# Number of content words in Subset 8: 14054
# Number of content words in Subset 9: 14703
# Number of content words in Subset 10: 15508
# Number of content words in Subset 11: 15713
# Number of content words in Subset 12: 14299
# Number of content words in Subset 13: 12135
# Number of content words in Subset 14: 15091
# Number of content words in Subset 15: 16370
# Number of content words in Subset 16: 17925
# Number of content words in Subset 17: 17572
# Number of content words in Subset 18: 19349
# Number of content words in Subset 19: 17577
# Number of content words in Subset 20: 18091
# Number of content words in Subset 21: 19634
# Number of content words in Subset 22: 19438
# Number of content words in Subset 23: 19426
# Number of content words in Subset 24: 12501
# Number of content words in Subset 25: 12185

# %% [markdown]
# # POV

# %%
# Define a function to count the frequency of points of view (POV) in the corpus
def count_pov_frequency(text):
    pov_list = ['first-person', 'second-person', 'third-person']
    pov_frequency = {pov: 0 for pov in pov_list}
    
    # Define keywords for identifying each point of view
    first_person_keywords = ['I', 'me', 'my', 'mine', 'we', 'us', 'our', 'ours']
    second_person_keywords = ['you', 'your', 'yours']
    third_person_keywords = ['he', 'him', 'his', 'she', 'her', 'hers', 'it', 'its', 'they', 'them', 'their', 'theirs']

    # Tokenize the text into words
    words = word_tokenize(text)

    # Count the frequency of each point of view
    for word in words:
        if word.lower() in first_person_keywords:
            pov_frequency['first-person'] += 1
        elif word.lower() in second_person_keywords:
            pov_frequency['second-person'] += 1
        elif word.lower() in third_person_keywords:
            pov_frequency['third-person'] += 1

    return pov_frequency

# %% [markdown]
# # Allan Poe

# %%
pov_frequency_Poe = count_pov_frequency(preprocessed_text_Poe)

print("Frequency of first-person POV:", pov_frequency_Poe['first-person']/(pov_frequency_Poe['first-person']+pov_frequency_Poe['second-person']+pov_frequency_Poe['third-person']))
print("Frequency of second-person POV:", pov_frequency_Poe['second-person']/(pov_frequency_Poe['first-person']+pov_frequency_Poe['second-person']+pov_frequency_Poe['third-person']))
print("Frequency of third-person POV:", pov_frequency_Poe['third-person']/(pov_frequency_Poe['first-person']+pov_frequency_Poe['second-person']+pov_frequency_Poe['third-person']))
# Out:
# Frequency of first-person POV: 0.3474550441938433
# Frequency of second-person POV: 0.03093569033831149
# Frequency of third-person POV: 0.6216092654678451

# %%
# Define the function to count the frequency of points of view (POV) in a subset
def count_pov_frequency_subset(subset_text):
    pov_list = ['first-person', 'second-person', 'third-person']
    pov_frequency = {pov: 0 for pov in pov_list}
    
    # Define keywords for identifying each point of view
    first_person_keywords = ['I', 'me', 'my', 'mine', 'we', 'us', 'our', 'ours']
    second_person_keywords = ['you', 'your', 'yours']
    third_person_keywords = ['he', 'him', 'his', 'she', 'her', 'hers', 'it', 'its', 'they', 'them', 'their', 'theirs']

    # Tokenize the subset text into words
    words = word_tokenize(subset_text)

    # Count the frequency of each point of view
    for word in words:
        if word.lower() in first_person_keywords:
            pov_frequency['first-person'] += 1
        elif word.lower() in second_person_keywords:
            pov_frequency['second-person'] += 1
        elif word.lower() in third_person_keywords:
            pov_frequency['third-person'] += 1

    return pov_frequency

# Split the text into sentences (assuming you have already defined the function split_into_sentences)
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find the occurrence of each POV in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pov_frequency_subset = count_pov_frequency_subset(subset_text)
    print(f"Point of View Frequency in Subset {i + 1}: {pov_frequency_subset}")
# Out:
# 1568
# Point of View Frequency in Subset 1: {'first-person': 458, 'second-person': 156, 'third-person': 1524}
# Point of View Frequency in Subset 2: {'first-person': 793, 'second-person': 125, 'third-person': 1430}
# Point of View Frequency in Subset 3: {'first-person': 1068, 'second-person': 46, 'third-person': 1485}
# Point of View Frequency in Subset 4: {'first-person': 1369, 'second-person': 2, 'third-person': 1776}
# Point of View Frequency in Subset 5: {'first-person': 812, 'second-person': 65, 'third-person': 1790}

# %% [markdown]
# # Sheridan Le Fanu

# %%
pov_frequency_Fanu = count_pov_frequency(preprocessed_text_Fanu)

print("Frequency of first-person POV:", pov_frequency_Fanu['first-person']/(pov_frequency_Fanu['first-person']+pov_frequency_Fanu['second-person']+pov_frequency_Fanu['third-person']))
print("Frequency of second-person POV:", pov_frequency_Fanu['second-person']/(pov_frequency_Fanu['first-person']+pov_frequency_Fanu['second-person']+pov_frequency_Fanu['third-person']))
print("Frequency of third-person POV:", pov_frequency_Fanu['third-person']/(pov_frequency_Fanu['first-person']+pov_frequency_Fanu['second-person']+pov_frequency_Fanu['third-person']))
# Out:
# Frequency of first-person POV: 0.1494061413673233
# Frequency of second-person POV: 0.09639339513325608
# Frequency of third-person POV: 0.7542004634994206

# %%
# Split the text into sentences (assuming you have already defined the function split_into_sentences)
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find the occurrence of each POV in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pov_frequency_subset = count_pov_frequency_subset(subset_text)
    print(f"Point of View Frequency in Subset {i + 1}: {pov_frequency_subset}")
# Out:
# 1097
# Point of View Frequency in Subset 1: {'first-person': 464, 'second-person': 199, 'third-person': 2185}
# Point of View Frequency in Subset 2: {'first-person': 217, 'second-person': 392, 'third-person': 1732}
# Point of View Frequency in Subset 3: {'first-person': 199, 'second-person': 306, 'third-person': 2244}
# Point of View Frequency in Subset 4: {'first-person': 934, 'second-person': 310, 'third-person': 2088}
# Point of View Frequency in Subset 5: {'first-person': 245, 'second-person': 110, 'third-person': 2149}

# %% [markdown]
# # Gothic corpus

# %%
pov_frequency_Gothic = count_pov_frequency(preprocessed_text_Gothic)

print("Frequency of first-person POV:", pov_frequency_Gothic['first-person']/(pov_frequency_Gothic['first-person']+pov_frequency_Gothic['second-person']+pov_frequency_Gothic['third-person']))
print("Frequency of second-person POV:", pov_frequency_Gothic['second-person']/(pov_frequency_Gothic['first-person']+pov_frequency_Gothic['second-person']+pov_frequency_Gothic['third-person']))
print("Frequency of third-person POV:", pov_frequency_Gothic['third-person']/(pov_frequency_Gothic['first-person']+pov_frequency_Gothic['second-person']+pov_frequency_Gothic['third-person']))
# Out:
# Frequency of first-person POV: 0.22246757200737388
# Frequency of second-person POV: 0.14130474785291058
# Frequency of third-person POV: 0.6362276801397155

# %%
#Poe vs Gothic
# Split the text into sentences (assuming you have already defined the function split_into_sentences)
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find the occurrence of each POV in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pov_frequency_subset = count_pov_frequency_subset(subset_text)
    print(f"Point of View Frequency in Subset {i + 1}: {pov_frequency_subset}")
# Out:
# Point of View Frequency in Subset 1: {'first-person': 785, 'second-person': 517, 'third-person': 2604}
# Point of View Frequency in Subset 2: {'first-person': 770, 'second-person': 614, 'third-person': 2440}
# Point of View Frequency in Subset 3: {'first-person': 783, 'second-person': 782, 'third-person': 2700}
# Point of View Frequency in Subset 4: {'first-person': 680, 'second-person': 492, 'third-person': 2785}
# Point of View Frequency in Subset 5: {'first-person': 775, 'second-person': 224, 'third-person': 2229}
# Point of View Frequency in Subset 6: {'first-person': 762, 'second-person': 481, 'third-person': 2066}
# Point of View Frequency in Subset 7: {'first-person': 807, 'second-person': 422, 'third-person': 2251}
# Point of View Frequency in Subset 8: {'first-person': 877, 'second-person': 420, 'third-person': 2408}
# Point of View Frequency in Subset 9: {'first-person': 692, 'second-person': 305, 'third-person': 2031}
# Point of View Frequency in Subset 10: {'first-person': 658, 'second-person': 573, 'third-person': 2695}
# Point of View Frequency in Subset 11: {'first-person': 902, 'second-person': 1308, 'third-person': 2573}
# Point of View Frequency in Subset 12: {'first-person': 845, 'second-person': 1047, 'third-person': 2849}
# Point of View Frequency in Subset 13: {'first-person': 616, 'second-person': 772, 'third-person': 2862}
# Point of View Frequency in Subset 14: {'first-person': 819, 'second-person': 1061, 'third-person': 3042}
# Point of View Frequency in Subset 15: {'first-person': 870, 'second-person': 1035, 'third-person': 3500}
# Point of View Frequency in Subset 16: {'first-person': 1047, 'second-person': 950, 'third-person': 3183}
# Point of View Frequency in Subset 17: {'first-person': 1037, 'second-person': 475, 'third-person': 1652}
# Point of View Frequency in Subset 18: {'first-person': 1006, 'second-person': 379, 'third-person': 2142}
# Point of View Frequency in Subset 19: {'first-person': 987, 'second-person': 358, 'third-person': 2084}
# Point of View Frequency in Subset 20: {'first-person': 1071, 'second-person': 578, 'third-person': 1699}
# Point of View Frequency in Subset 21: {'first-person': 818, 'second-person': 292, 'third-person': 1612}
# Point of View Frequency in Subset 22: {'first-person': 714, 'second-person': 352, 'third-person': 2118}
# Point of View Frequency in Subset 23: {'first-person': 1152, 'second-person': 295, 'third-person': 1755}
# Point of View Frequency in Subset 24: {'first-person': 915, 'second-person': 222, 'third-person': 2490}
# Point of View Frequency in Subset 25: {'first-person': 1259, 'second-person': 414, 'third-person': 2337}

# %%
#Fanu vs Gothic
# Split the text into sentences (assuming you have already defined the function split_into_sentences)
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find the occurrence of each POV in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pov_frequency_subset = count_pov_frequency_subset(subset_text)
    print(f"Point of View Frequency in Subset {i + 1}: {pov_frequency_subset}")
# Out:
# Point of View Frequency in Subset 1: {'first-person': 593, 'second-person': 362, 'third-person': 1874}
# Point of View Frequency in Subset 2: {'first-person': 452, 'second-person': 433, 'third-person': 1653}
# Point of View Frequency in Subset 3: {'first-person': 568, 'second-person': 378, 'third-person': 1830}
# Point of View Frequency in Subset 4: {'first-person': 586, 'second-person': 543, 'third-person': 1930}
# Point of View Frequency in Subset 5: {'first-person': 528, 'second-person': 474, 'third-person': 1883}
# Point of View Frequency in Subset 6: {'first-person': 500, 'second-person': 260, 'third-person': 1690}
# Point of View Frequency in Subset 7: {'first-person': 505, 'second-person': 160, 'third-person': 1722}
# Point of View Frequency in Subset 8: {'first-person': 568, 'second-person': 317, 'third-person': 1284}
# Point of View Frequency in Subset 9: {'first-person': 528, 'second-person': 307, 'third-person': 1453}
# Point of View Frequency in Subset 10: {'first-person': 532, 'second-person': 297, 'third-person': 1751}
# Point of View Frequency in Subset 11: {'first-person': 625, 'second-person': 314, 'third-person': 1656}
# Point of View Frequency in Subset 12: {'first-person': 498, 'second-person': 262, 'third-person': 1710}
# Point of View Frequency in Subset 13: {'first-person': 519, 'second-person': 166, 'third-person': 1246}
# Point of View Frequency in Subset 14: {'first-person': 436, 'second-person': 376, 'third-person': 1809}
# Point of View Frequency in Subset 15: {'first-person': 548, 'second-person': 754, 'third-person': 1818}
# Point of View Frequency in Subset 16: {'first-person': 701, 'second-person': 918, 'third-person': 2157}
# Point of View Frequency in Subset 17: {'first-person': 574, 'second-person': 745, 'third-person': 1888}
# Point of View Frequency in Subset 18: {'first-person': 467, 'second-person': 591, 'third-person': 2086}
# Point of View Frequency in Subset 19: {'first-person': 449, 'second-person': 602, 'third-person': 1978}
# Point of View Frequency in Subset 20: {'first-person': 580, 'second-person': 736, 'third-person': 2081}
# Point of View Frequency in Subset 21: {'first-person': 639, 'second-person': 816, 'third-person': 2398}
# Point of View Frequency in Subset 22: {'first-person': 689, 'second-person': 630, 'third-person': 2506}
# Point of View Frequency in Subset 23: {'first-person': 725, 'second-person': 589, 'third-person': 1946}
# Point of View Frequency in Subset 24: {'first-person': 749, 'second-person': 332, 'third-person': 1106}
# Point of View Frequency in Subset 25: {'first-person': 637, 'second-person': 316, 'third-person': 1419}

# %% [markdown]
# # Sentence Structure

# %%
import string 
from collections import Counter

# Define a function to split the corpus into sentences using relative punctuation marks
def split_into_sentences(text):
    sentences = []
    current_sentence = ""
    for char in text:
        current_sentence += char
        if char in ['.', ',', ':', ';', '?', '!']:
            sentences.append(current_sentence.strip())
            current_sentence = ""
    if current_sentence:
        sentences.append(current_sentence.strip())
    return sentences

# Define a function to remove punctuation marks from a sentence
def remove_punctuation(sentence):
    return ''.join([char for char in sentence if char not in string.punctuation])

# Define a function to count sentence structures in the corpus
def count_sentence_structures(text):
    # Split the corpus into sentences using relative punctuation marks
    sentences = split_into_sentences(text)
    
    # Initialize a Counter to store the frequency of each sentence structure
    structure_counter = Counter()
    
    for sentence in sentences:
        # Remove punctuation marks from the sentence
        sentence = remove_punctuation(sentence)
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract the POS tags only
        tags = [tag for _, tag in tagged_words]
        # Convert the tags list into a string to represent the sentence structure
        structure = ' '.join(tags)
        # Increment the frequency count for this sentence structure
        structure_counter[structure] += 1
    
    return structure_counter

# %% [markdown]
# # Allan Poe

# %%
# Allan Poe
import pandas as pd


structure_frequency_Poe = count_sentence_structures(text_Poe)

# Calculate the total number of combinations in the corpus
total_combinations = sum(structure_frequency_Poe.values())

# Create a DataFrame from the structure_frequency dictionary
Allen_Poe = pd.DataFrame(list(structure_frequency_Poe.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each combination
Allen_Poe['Relative Frequency'] = Allen_Poe['Frequency'] / total_combinations

# Filter out instances with frequency equal to 1
Allen_Poe = Allen_Poe[Allen_Poe['Frequency'] > 1]

# Sort the DataFrame by frequency in descending order
Allen_Poe = Allen_Poe.sort_values(by='Relative Frequency', ascending=False)

# %%
Allen_Poe.head(20)
# Out:
#               Structure  Frequency  Relative Frequency
# 28                   RB        823            0.030585
# 32                   NN        540            0.020068
# 80                   CC        411            0.015274
# 24                IN NN        248            0.009216
# 43             IN DT NN        234            0.008696
# 34                DT NN        209            0.007767
# 306         IN DT JJ NN        147            0.005463
# 148             PRP VBD        142            0.005277
# 152                 NNS        131            0.004868
# 719                  IN        122            0.004534
# 259          NN PRP VBD         94            0.003493
# 303               IN JJ         83            0.003084
# 1255                            80            0.002973
# 422             PRP VBP         80            0.002973
# 2             IN JJ NNS         70            0.002601
# 677            DT JJ NN         69            0.002564
# 475   IN DT NN IN DT NN         66            0.002453
# 641                  JJ         64            0.002378
# 739               CC RB         62            0.002304
# 390                 VBN         62            0.002304

# %%
# Define a function to count sentence structures in the corpus
def count_sentence_structures2(text):
    # Split the corpus into sentences using relative punctuation marks
    sentences = split_into_sentences(text)
    
    # Initialize a Counter to store the frequency of each sentence structure
    structure_counter = Counter()
    
    for sentence in sentences:
        # Remove punctuation marks from the sentence
        #sentence = remove_punctuation(sentence)
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract the POS tags only
        tags = [tag for _, tag in tagged_words]
        # Convert the tags list into a string to represent the sentence structure
        structure = ' '.join(tags)
        # Increment the frequency count for this sentence structure
        structure_counter[structure] += 1
    
    return structure_counter

# %%
# with punct
# Allan Poe
import pandas as pd


structure_frequency_Poe = count_sentence_structures2(text_Poe)

# Calculate the total number of combinations in the corpus
total_combinations = sum(structure_frequency_Poe.values())

# Create a DataFrame from the structure_frequency dictionary
Allen_Poe2 = pd.DataFrame(list(structure_frequency_Poe.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each combination
Allen_Poe2['Relative Frequency'] = Allen_Poe2['Frequency'] / total_combinations

# Filter out instances with frequency equal to 1
Allen_Poe2 = Allen_Poe2[Allen_Poe2['Frequency'] > 1]

# Sort the DataFrame by frequency in descending order
Allen_Poe2 = Allen_Poe2.sort_values(by='Relative Frequency', ascending=False)

# %%
Allen_Poe2.head(20)
# Out:
#          Structure  Frequency  Relative Frequency
# 29            RB ,        812            0.030176
# 80            CC ,        410            0.015237
# 114           NN ,        262            0.009737
# 25         IN NN ,        247            0.009179
# 44      IN DT NN ,        204            0.007581
# 35         DT NN ,        196            0.007284
# 313  IN DT JJ NN ,        138            0.005128
# 149      PRP VBD ,        131            0.004868
# 256          NNP ,        126            0.004682
# 33            NN .        117            0.004348
# 176          NNP .        110            0.004088
# 153          NNS ,        105            0.003902
# 730           IN ,         84            0.003122
# 310        IN JJ ,         74            0.002750
# 430      PRP VBP ,         71            0.002639
# 2      IN JJ NNS ,         69            0.002564
# 264   NN PRP VBD ,         64            0.002378
# 198        CC NN ,         63            0.002341
# 514     DT JJ NN ,         63            0.002341
# 750        CC RB ,         62            0.002304

# %%
# using sentence tokenizer, it is empty because no 2 sentences are identically the same
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

# Define a function to count sentence structures in the corpus
def count_sentence_structures(text):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # Initialize a Counter to store the frequency of each sentence structure
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract the POS tags only
        tags = [tag for _, tag in tagged_words]
        # Convert the tags list into a string to represent the sentence structure
        structure = ' '.join(tags)
        # Increment the frequency count for this sentence structure
        structure_counter[structure] += 1
    
    return structure_counter


# Calculate sentence structures frequency
structure_frequency_Poe = count_sentence_structures(text_Poe)

# Calculate the total number of combinations in the corpus
total_combinations = sum(structure_frequency_Poe.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_Poe = pd.DataFrame(list(structure_frequency_Poe.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each combination
df_structure_frequency_Poe['Relative Frequency'] = df_structure_frequency_Poe['Frequency'] / total_combinations

# Filter out instances with frequency equal to 1
df_structure_frequency_Poe = df_structure_frequency_Poe[df_structure_frequency_Poe['Frequency'] > 1]

# Sort the DataFrame by frequency in descending order
df_structure_frequency_Poe = df_structure_frequency_Poe.sort_values(by='Relative Frequency', ascending=False)

# Display the DataFrame
print(df_structure_frequency_Poe)
# Out:
#                                               Structure  Frequency  \
# 4676                                           NNP CD .         23
# 1448                                               NN .         23
# 570                                                UH .         11
# 2412                                               IN .          9
# 1746                                           JJ NNP .          8
# 2104                                              NNP .          6
# 2413                                          JJ . NN .          6
# 3010                                 PRP VBD DT JJ NN .          4
# 1986                                       PRP VBD RB .          4
# 844                                     PRP VBD IN NN .          4
# 1644                                     DT NN VBD JJ .          4
# 2507                                              PRP .          4
# 1449                                          NN . NN .          4
# 2440                             PRP VBD PRP IN DT NN .          3
# 2247  CC DT NN VBD IN DT NN : CC DT NN VBD CC PRP VB...          3
# 2246  CC PRP VBP RB IN PRP$ JJ CC VBD DT NNS IN DT NN .          3
# 2516                                       PRP VBD NN .          3
# 2766                                            IN NN .          3
# 55                                     PRP$ NN VBD JJ .          3
# 262                                  DT NN VBD RB VBN .          3
# 3348                                      PRP VBD PRP .          3
# 135                                     PRP VBD JJ NN .          3
# 5713                                           CC NNP .          3
# 212                                  NNP DT NNS IN NN .          3
# 213                         DT JJ NN VBD IN IN DT NNP .          3
# 2643                                     PRP MD RB VB .          2
# 6274              WP VBD DT NNS IN DT MD , IN PRP$ NN .          2
# 2901                               DT NN VBD JJ CC NN .          2
# 4154                           DT VBD IN DT NN IN NNP .          2
# 3175                                     EX VBD DT NN .          2
# 3033                          PRP VBD CC VBD IN DT NN .          2
# 3042                          PRP VBD VBN IN DT JJ NN .          2
# 3689                                     NN EX VBD NN .          2
# 3565                          PRP VBD RB VBN IN DT NN .          2
# 3174                                    DT NNS VBD JJ .          2
# 3331                                         DT JJ NN .          2
# 2684                                        CC DT NNP .          2
# 2379                                     DT NN VBD NN .          2
# 2636                                PRP VBP VBN IN NN .          2
# 1312                         PRP VBD VBN VBN IN DT NN .          2
# 125                                   DT NN VBD RB JJ .          2
# 147                                   DT JJ NN VBD JJ .          2
# 819                  DT NN VBD VBN RB CC IN DT IN PRP .          2
# 820   DT NN IN DT NN VBD JJ , CC DT NNS IN PRP VBD V...          2
# 1207                                            DT NN .          2
# 1220                                        VB PRP VB .          2
# 1324                                         IN DT NN .          2
# 2585                                       RB PRP VBP .          2
# 1968                              PRP VBD RB IN DT NN .          2
# 2222                         CC EX VBZ DT NN IN DT NN .          2
# 2312                           PRP VBD DT NN IN JJ NN .          2
# 58                                  PRP VBD IN PRP RB .          2
# 2386                                               JJ .          2
# 2494                                    PRP VBD DT NN .          2
# 6275  IN NNP VBZ CC DT JJ MD VBG DT NNS IN NN IN PRP...          2
#
#       Relative Frequency
# 4676            0.003038
# 1448            0.003038
# 570             0.001453
# 2412            0.001189
# 1746            0.001057
# 2104            0.000792
# 2413            0.000792
# 3010            0.000528
# 1986            0.000528
# 844             0.000528
# 1644            0.000528
# 2507            0.000528
# 1449            0.000528
# 2440            0.000396
# 2247            0.000396
# 2246            0.000396
# 2516            0.000396
# 2766            0.000396
# 55              0.000396
# 262             0.000396
# 3348            0.000396
# 135             0.000396
# 5713            0.000396
# 212             0.000396
# 213             0.000396
# 2643            0.000264
# 6274            0.000264
# 2901            0.000264
# 4154            0.000264
# 3175            0.000264
# 3033            0.000264
# 3042            0.000264
# 3689            0.000264
# 3565            0.000264
# 3174            0.000264
# 3331            0.000264
# 2684            0.000264
# 2379            0.000264
# 2636            0.000264
# 1312            0.000264
# 125             0.000264
# 147             0.000264
# 819             0.000264
# 820             0.000264
# 1207            0.000264
# 1220            0.000264
# 1324            0.000264
# 2585            0.000264
# 1968            0.000264
# 2222            0.000264
# 2312            0.000264
# 58              0.000264
# 2386            0.000264
# 2494            0.000264
# 6275            0.000264

# %%
df_structure_frequency_Poe
# Out:
#                                               Structure  Frequency  \
# 4676                                           NNP CD .         23
# 1448                                               NN .         23
# 570                                                UH .         11
# 2412                                               IN .          9
# 1746                                           JJ NNP .          8
# 2104                                              NNP .          6
# 2413                                          JJ . NN .          6
# 3010                                 PRP VBD DT JJ NN .          4
# 1986                                       PRP VBD RB .          4
# 844                                     PRP VBD IN NN .          4
# 1644                                     DT NN VBD JJ .          4
# 2507                                              PRP .          4
# 1449                                          NN . NN .          4
# 2440                             PRP VBD PRP IN DT NN .          3
# 2247  CC DT NN VBD IN DT NN : CC DT NN VBD CC PRP VB...          3
# 2246  CC PRP VBP RB IN PRP$ JJ CC VBD DT NNS IN DT NN .          3
# 2516                                       PRP VBD NN .          3
# 2766                                            IN NN .          3
# 55                                     PRP$ NN VBD JJ .          3
# 262                                  DT NN VBD RB VBN .          3
# 3348                                      PRP VBD PRP .          3
# 135                                     PRP VBD JJ NN .          3
# 5713                                           CC NNP .          3
# 212                                  NNP DT NNS IN NN .          3
# 213                         DT JJ NN VBD IN IN DT NNP .          3
# 2643                                     PRP MD RB VB .          2
# 6274              WP VBD DT NNS IN DT MD , IN PRP$ NN .          2
# 2901                               DT NN VBD JJ CC NN .          2
# 4154                           DT VBD IN DT NN IN NNP .          2
# 3175                                     EX VBD DT NN .          2
# 3033                          PRP VBD CC VBD IN DT NN .          2
# 3042                          PRP VBD VBN IN DT JJ NN .          2
# 3689                                     NN EX VBD NN .          2
# 3565                          PRP VBD RB VBN IN DT NN .          2
# 3174                                    DT NNS VBD JJ .          2
# 3331                                         DT JJ NN .          2
# 2684                                        CC DT NNP .          2
# 2379                                     DT NN VBD NN .          2
# 2636                                PRP VBP VBN IN NN .          2
# 1312                         PRP VBD VBN VBN IN DT NN .          2
# 125                                   DT NN VBD RB JJ .          2
# 147                                   DT JJ NN VBD JJ .          2
# 819                  DT NN VBD VBN RB CC IN DT IN PRP .          2
# 820   DT NN IN DT NN VBD JJ , CC DT NNS IN PRP VBD V...          2
# 1207                                            DT NN .          2
# 1220                                        VB PRP VB .          2
# 1324                                         IN DT NN .          2
# 2585                                       RB PRP VBP .          2
# 1968                              PRP VBD RB IN DT NN .          2
# 2222                         CC EX VBZ DT NN IN DT NN .          2
# 2312                           PRP VBD DT NN IN JJ NN .          2
# 58                                  PRP VBD IN PRP RB .          2
# 2386                                               JJ .          2
# 2494                                    PRP VBD DT NN .          2
# 6275  IN NNP VBZ CC DT JJ MD VBG DT NNS IN NN IN PRP...          2
#
#       Relative Frequency
# 4676            0.003038
# 1448            0.003038
# 570             0.001453
# 2412            0.001189
# 1746            0.001057
# 2104            0.000792
# 2413            0.000792
# 3010            0.000528
# 1986            0.000528
# 844             0.000528
# 1644            0.000528
# 2507            0.000528
# 1449            0.000528
# 2440            0.000396
# 2247            0.000396
# 2246            0.000396
# 2516            0.000396
# 2766            0.000396
# 55              0.000396
# 262             0.000396
# 3348            0.000396
# 135             0.000396
# 5713            0.000396
# 212             0.000396
# 213             0.000396
# 2643            0.000264
# 6274            0.000264
# 2901            0.000264
# 4154            0.000264
# 3175            0.000264
# 3033            0.000264
# 3042            0.000264
# 3689            0.000264
# 3565            0.000264
# 3174            0.000264
# 3331            0.000264
# 2684            0.000264
# 2379            0.000264
# 2636            0.000264
# 1312            0.000264
# 125             0.000264
# 147             0.000264
# 819             0.000264
# 820             0.000264
# 1207            0.000264
# 1220            0.000264
# 1324            0.000264
# 2585            0.000264
# 1968            0.000264
# 2222            0.000264
# 2312            0.000264
# 58              0.000264
# 2386            0.000264
# 2494            0.000264
# 6275            0.000264

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams

# Define a function to count sentence structures using 3-grams of POS tags
def count_sentence_structures_3grams(text):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # Initialize a Counter to store the frequency of each 3-gram of POS tags
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract POS tags only
        tags = [tag for _, tag in tagged_words]
        # Generate 3-grams of POS tags
        pos_3grams = ngrams(tags, 3)
        # Increment the frequency count for each 3-gram
        structure_counter.update(pos_3grams)
    
    return structure_counter


# Calculate sentence structures frequency using 3-grams
structure_frequency_3grams = count_sentence_structures_3grams(text_Poe)

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_3grams = pd.DataFrame(list(structure_frequency_3grams.items()), columns=['Structure', 'Frequency'])

# Sort the DataFrame by frequency in descending order
df_structure_frequency_3grams = df_structure_frequency_3grams.sort_values(by='Frequency', ascending=False)

# Display the DataFrame
print(df_structure_frequency_3grams)
# Out:
#            Structure  Frequency
# 185     (IN, DT, NN)       7468
# 68      (DT, NN, IN)       4968
# 69      (NN, IN, DT)       4261
# 73      (DT, JJ, NN)       3531
# 34      (IN, DT, JJ)       2771
# ...              ...        ...
# 6002   (JJ, WDT, RB)          1
# 6004   (RP, NNS, DT)          1
# 6006   (WDT, NN, WP)          1
# 6007   (RB, VBD, MD)          1
# 8738  (VBZ, NN, RBR)          1
#
# [8739 rows x 2 columns]

# %%
df_structure_frequency_3grams
# Out:
#            Structure  Frequency
# 185     (IN, DT, NN)       7468
# 68      (DT, NN, IN)       4968
# 69      (NN, IN, DT)       4261
# 73      (DT, JJ, NN)       3531
# 34      (IN, DT, JJ)       2771
# ...              ...        ...
# 6002   (JJ, WDT, RB)          1
# 6004   (RP, NNS, DT)          1
# 6006   (WDT, NN, WP)          1
# 6007   (RB, VBD, MD)          1
# 8738  (VBZ, NN, RBR)          1
#
# [8739 rows x 2 columns]

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams

# Define a function to count sentence structures using 3-grams of POS tags
def count_sentence_structures_3grams(text):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # Initialize a Counter to store the frequency of each 3-gram of POS tags
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract POS tags only
        tags = [tag for _, tag in tagged_words]
        # Generate 3-grams of POS tags
        pos_3grams = ngrams(tags, 3)
        # Increment the frequency count for each 3-gram
        structure_counter.update(pos_3grams)
    
    return structure_counter


# Calculate sentence structures frequency using 3-grams
structure_frequency_3grams = count_sentence_structures_3grams(text_Poe)

# Calculate the total number of 3-grams in the corpus
total_3grams = sum(structure_frequency_3grams.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_3grams = pd.DataFrame(list(structure_frequency_3grams.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_3grams['Relative Frequency'] = df_structure_frequency_3grams['Frequency'] / total_3grams

# Sort the DataFrame by frequency in descending order
df_structure_frequency_3grams = df_structure_frequency_3grams.sort_values(by='Frequency', ascending=False)

# Display the DataFrame
print(df_structure_frequency_3grams)
# Out:
#            Structure  Frequency  Relative Frequency
# 185     (IN, DT, NN)       7468            0.035338
# 68      (DT, NN, IN)       4968            0.023508
# 69      (NN, IN, DT)       4261            0.020163
# 73      (DT, JJ, NN)       3531            0.016708
# 34      (IN, DT, JJ)       2771            0.013112
# ...              ...        ...                 ...
# 6002   (JJ, WDT, RB)          1            0.000005
# 6004   (RP, NNS, DT)          1            0.000005
# 6006   (WDT, NN, WP)          1            0.000005
# 6007   (RB, VBD, MD)          1            0.000005
# 8738  (VBZ, NN, RBR)          1            0.000005
#
# [8739 rows x 3 columns]

# %%
df_structure_frequency_3grams
# Out:
#            Structure  Frequency  Relative Frequency
# 185     (IN, DT, NN)       7468            0.035338
# 68      (DT, NN, IN)       4968            0.023508
# 69      (NN, IN, DT)       4261            0.020163
# 73      (DT, JJ, NN)       3531            0.016708
# 34      (IN, DT, JJ)       2771            0.013112
# ...              ...        ...                 ...
# 6002   (JJ, WDT, RB)          1            0.000005
# 6004   (RP, NNS, DT)          1            0.000005
# 6006   (WDT, NN, WP)          1            0.000005
# 6007   (RB, VBD, MD)          1            0.000005
# 8738  (VBZ, NN, RBR)          1            0.000005
#
# [8739 rows x 3 columns]

# %%
df_structure_frequency_3grams.head(25).to_csv('Poe_structure_frequency_3grams.csv', index=False)

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams
import re

# Define a function to count sentence structures using 3-grams of POS tags for a subset
def count_sentence_structures_3grams_subset(subset_text):
    # Tokenize the subset into sentences
    sentences = sent_tokenize(subset_text)
    
    # Initialize a Counter to store the frequency of each 3-gram of POS tags
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract POS tags only
        tags = [tag for _, tag in tagged_words]
        # Generate 3-grams of POS tags
        pos_3grams = ngrams(tags, 3)
        # Increment the frequency count for each 3-gram
        structure_counter.update(pos_3grams)
    
    return structure_counter

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences


# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find sentence structures frequency using 3-grams in each subset
# Find sentence structures frequency using 3-grams in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_3grams_subset = count_sentence_structures_3grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_3grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# 1568
# Subset 1:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1510
# Structure: ('DT', 'NN', 'IN'), Frequency: 1020
# Structure: ('NN', 'IN', 'DT'), Frequency: 903
# Structure: ('DT', 'JJ', 'NN'), Frequency: 630
# Structure: ('IN', 'DT', 'JJ'), Frequency: 487
#
# Subset 2:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1274
# Structure: ('DT', 'NN', 'IN'), Frequency: 841
# Structure: ('NN', 'IN', 'DT'), Frequency: 767
# Structure: ('DT', 'JJ', 'NN'), Frequency: 646
# Structure: ('IN', 'DT', 'JJ'), Frequency: 542
#
# Subset 3:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1262
# Structure: ('DT', 'NN', 'IN'), Frequency: 860
# Structure: ('NN', 'IN', 'DT'), Frequency: 677
# Structure: ('DT', 'JJ', 'NN'), Frequency: 627
# Structure: ('IN', 'DT', 'JJ'), Frequency: 503
#
# Subset 4:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1820
# Structure: ('DT', 'NN', 'IN'), Frequency: 1152
# Structure: ('NN', 'IN', 'DT'), Frequency: 913
# Structure: ('DT', 'JJ', 'NN'), Frequency: 810
# Structure: ('DT', 'NN', ','), Frequency: 602
#
# Subset 5:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1601
# Structure: ('DT', 'NN', 'IN'), Frequency: 1094
# Structure: ('NN', 'IN', 'DT'), Frequency: 1001
# Structure: ('DT', 'JJ', 'NN'), Frequency: 816
# Structure: ('IN', 'DT', 'JJ'), Frequency: 671

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams

# Define a function to count sentence structures using 4-grams of POS tags
def count_sentence_structures_4grams(text):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # Initialize a Counter to store the frequency of each 4-gram of POS tags
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract POS tags only
        tags = [tag for _, tag in tagged_words]
        # Generate 4-grams of POS tags
        pos_4grams = ngrams(tags, 4)
        # Increment the frequency count for each 3-gram
        structure_counter.update(pos_4grams)
    
    return structure_counter


# Calculate sentence structures frequency using 3-grams
structure_frequency_4grams = count_sentence_structures_4grams(text_Poe)

# Calculate the total number of 3-grams in the corpus
total_4grams = sum(structure_frequency_4grams.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_4grams = pd.DataFrame(list(structure_frequency_4grams.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_4grams['Relative Frequency'] = df_structure_frequency_4grams['Frequency'] / total_4grams

# Sort the DataFrame by frequency in descending order
df_structure_frequency_4grams = df_structure_frequency_4grams.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_4grams
# Out:
#                 Structure  Frequency  Relative Frequency
# 434      (NN, IN, DT, NN)       2634            0.012923
# 212      (IN, DT, NN, IN)       2460            0.012070
# 69       (DT, NN, IN, DT)       2242            0.011000
# 73       (IN, DT, JJ, NN)       1833            0.008993
# 272       (IN, DT, NN, ,)       1517            0.007443
# ...                   ...        ...                 ...
# 8394   (WP, VBZ, NNP, NN)          1            0.000005
# 20986   (JJ, VBD, RB, TO)          1            0.000005
# 20987    (,, DT, RB, NNS)          1            0.000005
# 20988   (DT, RB, NNS, TO)          1            0.000005
# 33464  (RBR, TO, VB, VBN)          1            0.000005
#
# [33465 rows x 3 columns]

# %%
df_structure_frequency_4grams.head(25).to_csv('Poe_structure_frequency_4grams.csv', index=False)

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams
import re

# Define a function to count sentence structures using 3-grams of POS tags for a subset
def count_sentence_structures_4grams_subset(subset_text):
    # Tokenize the subset into sentences
    sentences = sent_tokenize(subset_text)
    
    # Initialize a Counter to store the frequency of each 3-gram of POS tags
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract POS tags only
        tags = [tag for _, tag in tagged_words]
        # Generate 3-grams of POS tags
        pos_4grams = ngrams(tags, 4)
        # Increment the frequency count for each 3-gram
        structure_counter.update(pos_4grams)
    
    return structure_counter

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences


# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find sentence structures frequency using 4-grams in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_4grams_subset = count_sentence_structures_4grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_4grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# 1568
# Subset 1:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 558
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 522
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 509
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 330
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 259
#
# Subset 2:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 450
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 398
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 389
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 328
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 259
#
# Subset 3:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 430
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 393
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 348
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 335
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 247
#
# Subset 4:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 616
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 615
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 479
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 406
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 402
#
# Subset 5:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 581
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 544
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 504
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 438
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 350

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams

# Define a function to count sentence structures using 4-grams of POS tags
def count_sentence_structures_5grams(text):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # Initialize a Counter to store the frequency of each 4-gram of POS tags
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract POS tags only
        tags = [tag for _, tag in tagged_words]
        # Generate 5-grams of POS tags
        pos_5grams = ngrams(tags, 5)
        # Increment the frequency count for each 3-gram
        structure_counter.update(pos_5grams)
    
    return structure_counter


# Calculate sentence structures frequency using 3-grams
structure_frequency_5grams = count_sentence_structures_5grams(text_Poe)

# Calculate the total number of 3-grams in the corpus
total_5grams = sum(structure_frequency_5grams.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_5grams = pd.DataFrame(list(structure_frequency_5grams.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_5grams['Relative Frequency'] = df_structure_frequency_5grams['Frequency'] / total_5grams

# Sort the DataFrame by frequency in descending order
df_structure_frequency_5grams = df_structure_frequency_5grams.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_5grams
# Out:
#                     Structure  Frequency  Relative Frequency
# 589      (DT, NN, IN, DT, NN)       1406            0.007160
# 692      (IN, DT, NN, IN, DT)       1151            0.005862
# 691      (NN, IN, DT, NN, IN)        672            0.003422
# 855       (NN, IN, DT, NN, ,)        629            0.003203
# 275      (IN, DT, JJ, NN, IN)        613            0.003122
# ...                       ...        ...                 ...
# 34615  ((, WDT, VBZ, RB, NNP)          1            0.000005
# 34616  (WDT, VBZ, RB, NNP, ,)          1            0.000005
# 34617    (VBZ, RB, NNP, ,, ))          1            0.000005
# 34618     (RB, NNP, ,, ), IN)          1            0.000005
# 74223    (RB, RB, RB, DT, JJ)          1            0.000005
#
# [74224 rows x 3 columns]

# %%
df_structure_frequency_5grams.head(25).to_csv('Poe_structure_frequency_5grams.csv', index=False)

# %%
from collections import Counter
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams
import re

# Define a function to count sentence structures using 5-grams of POS tags for a subset
def count_sentence_structures_5grams_subset(subset_text):
    # Tokenize the subset into sentences
    sentences = sent_tokenize(subset_text)
    
    # Initialize a Counter to store the frequency of each 3-gram of POS tags
    structure_counter = Counter()
    
    for sentence in sentences:
        # Perform POS tagging on the sentence
        tagged_words = nltk.pos_tag(word_tokenize(sentence))
        # Extract POS tags only
        tags = [tag for _, tag in tagged_words]
        # Generate 3-grams of POS tags
        pos_5grams = ngrams(tags, 5)
        # Increment the frequency count for each 3-gram
        structure_counter.update(pos_5grams)
    
    return structure_counter

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences


# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find sentence structures frequency using 4-grams in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_5grams_subset = count_sentence_structures_5grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_5grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# 1568
# Subset 1:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 329
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 282
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 163
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 114
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 107
#
# Subset 2:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 232
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 183
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 115
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 110
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 110
#
# Subset 3:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 214
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 181
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 118
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 103
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 101
#
# Subset 4:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 332
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 264
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 171
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 157
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 139
#
# Subset 5:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 299
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 241
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 154
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 152
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 149

# %% [markdown]
# # Sheridan Le Fanu

# %%
# Sheridan Le Fanu
import pandas as pd


structure_frequency_Fanu = count_sentence_structures(text_Fanu)

# Calculate the total number of combinations in the corpus
total_combinations_Fanu = sum(structure_frequency_Fanu.values())

# Create a DataFrame from the structure_frequency dictionary
Le_Fanu = pd.DataFrame(list(structure_frequency_Fanu.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each combination
Le_Fanu['Relative Frequency'] = Le_Fanu['Frequency'] / total_combinations_Fanu

# Filter out instances with frequency equal to 1
Le_Fanu = Le_Fanu[Le_Fanu['Frequency'] > 1]

# Sort the DataFrame by frequency in descending order
Le_Fanu = Le_Fanu.sort_values(by='Relative Frequency', ascending=False)

# %%
Le_Fanu.head(20)
# Out:
#         Structure  Frequency  Relative Frequency
# 200            NN        802            0.035079
# 3              RB        502            0.021957
# 360       PRP VBD        268            0.011722
# 27             CC        205            0.008966
# 7        IN DT NN        172            0.007523
# 21          DT NN        152            0.006648
# 50        PRP VBP        128            0.005599
# 115   IN DT JJ NN        106            0.004636
# 193       NNP NNP        100            0.004374
# 263         IN NN         93            0.004068
# 385       PRP$ NN         86            0.003762
# 212           NNP         77            0.003368
# 136         JJ NN         72            0.003149
# 726            UH         71            0.003105
# 5241      VBZ PRP         67            0.002930
# 137    IN PRP$ NN         66            0.002887
# 587           NNS         65            0.002843
# 776           VBG         55            0.002406
# 1681   IN PRP VBD         54            0.002362
# 256         CC RB         54            0.002362

# %%
# Calculate sentence structures frequency using 3-grams
structure_frequency_3grams_Fanu = count_sentence_structures_3grams(text_Fanu)

# Calculate the total number of 3-grams in the corpus
total_3grams_Fanu = sum(structure_frequency_3grams_Fanu.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_3grams_Fanu = pd.DataFrame(list(structure_frequency_3grams_Fanu.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_3grams_Fanu['Relative Frequency'] = df_structure_frequency_3grams_Fanu['Frequency'] / total_3grams_Fanu

# Sort the DataFrame by frequency in descending order
df_structure_frequency_3grams_Fanu = df_structure_frequency_3grams_Fanu.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_3grams_Fanu
# Out:
#              Structure  Frequency  Relative Frequency
# 46        (IN, DT, NN)       4335            0.026095
# 53        (DT, JJ, NN)       2924            0.017602
# 6         (DT, NN, IN)       2670            0.016073
# 70        (NN, IN, DT)       2305            0.013875
# 109       (IN, DT, JJ)       1932            0.011630
# ...                ...        ...                 ...
# 6537    (WP, VBZ, VBG)          1            0.000006
# 6539     (MD, PRP, NN)          1            0.000006
# 6544  (WRB, PRP$, VBG)          1            0.000006
# 3503     (NN, RB, VBP)          1            0.000006
# 9233    (VBG, IN, VBD)          1            0.000006
#
# [9234 rows x 3 columns]

# %%
df_structure_frequency_3grams_Fanu.head(25).to_csv('Fanu_structure_frequency_3grams.csv', index=False)

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find sentence structures frequency using 3-grams in each subset
# Find sentence structures frequency using 3-grams in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_3grams_subset = count_sentence_structures_3grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_3grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# 1097
# Subset 1:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1073
# Structure: ('DT', 'JJ', 'NN'), Frequency: 716
# Structure: ('DT', 'NN', 'IN'), Frequency: 654
# Structure: ('NN', 'IN', 'DT'), Frequency: 615
# Structure: ('IN', 'DT', 'JJ'), Frequency: 500
#
# Subset 2:
# Structure: ('IN', 'DT', 'NN'), Frequency: 679
# Structure: ('DT', 'NN', 'IN'), Frequency: 429
# Structure: ('DT', 'JJ', 'NN'), Frequency: 428
# Structure: ('NN', 'IN', 'DT'), Frequency: 344
# Structure: ('IN', 'DT', 'JJ'), Frequency: 282
#
# Subset 3:
# Structure: ('IN', 'DT', 'NN'), Frequency: 814
# Structure: ('DT', 'JJ', 'NN'), Frequency: 521
# Structure: ('DT', 'NN', 'IN'), Frequency: 509
# Structure: ('NN', 'IN', 'DT'), Frequency: 449
# Structure: ('IN', 'DT', 'JJ'), Frequency: 313
#
# Subset 4:
# Structure: ('IN', 'DT', 'NN'), Frequency: 849
# Structure: ('DT', 'JJ', 'NN'), Frequency: 597
# Structure: ('DT', 'NN', 'IN'), Frequency: 552
# Structure: ('NN', 'IN', 'DT'), Frequency: 424
# Structure: ('IN', 'DT', 'JJ'), Frequency: 404
#
# Subset 5:
# Structure: ('IN', 'DT', 'NN'), Frequency: 920
# Structure: ('DT', 'JJ', 'NN'), Frequency: 662
# Structure: ('DT', 'NN', 'IN'), Frequency: 526
# Structure: ('NN', 'IN', 'DT'), Frequency: 473
# Structure: ('IN', 'DT', 'JJ'), Frequency: 433

# %%
# Calculate sentence structures frequency using 3-grams
structure_frequency_4grams_Fanu = count_sentence_structures_4grams(text_Fanu)

# Calculate the total number of 3-grams in the corpus
total_4grams_Fanu = sum(structure_frequency_4grams_Fanu.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_4grams_Fanu = pd.DataFrame(list(structure_frequency_4grams_Fanu.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_4grams_Fanu['Relative Frequency'] = df_structure_frequency_4grams_Fanu['Frequency'] / total_4grams_Fanu

# Sort the DataFrame by frequency in descending order
df_structure_frequency_4grams_Fanu = df_structure_frequency_4grams_Fanu.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_4grams_Fanu
# Out:
#                   Structure  Frequency  Relative Frequency
# 75         (NN, IN, DT, NN)       1383            0.008651
# 117        (IN, DT, JJ, NN)       1342            0.008395
# 206        (IN, DT, NN, IN)       1229            0.007688
# 105        (DT, NN, IN, DT)       1087            0.006800
# 48          (IN, DT, NN, ,)       1058            0.006618
# ...                     ...        ...                 ...
# 19040  (PRP$, VBG, PRP, TO)          1            0.000006
# 19039   (,, PRP$, VBG, PRP)          1            0.000006
# 19036   (VBZ, IN, PRP, VBZ)          1            0.000006
# 19033    (CC, DT, WDT, VBZ)          1            0.000006
# 33501     (NNP, DT, NN, NN)          1            0.000006
#
# [33502 rows x 3 columns]

# %%
df_structure_frequency_4grams_Fanu.head(25).to_csv('Fanu_structure_frequency_4grams.csv', index=False)

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find sentence structures frequency using 4-grams in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_4grams_subset = count_sentence_structures_4grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_4grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# 1097
# Subset 1:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 370
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 345
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 323
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 279
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 253
#
# Subset 2:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 201
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 192
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 176
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 171
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 160
#
# Subset 3:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 281
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 221
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 217
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 206
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 189
#
# Subset 4:
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 289
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 262
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 253
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 208
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 207
#
# Subset 5:
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 295
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 278
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 251
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 248
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 224

# %%
# Calculate sentence structures frequency using 3-grams
structure_frequency_5grams_Fanu = count_sentence_structures_5grams(text_Fanu)

# Calculate the total number of 3-grams in the corpus
total_5grams_Fanu = sum(structure_frequency_5grams_Fanu.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_5grams_Fanu = pd.DataFrame(list(structure_frequency_5grams_Fanu.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_5grams_Fanu['Relative Frequency'] = df_structure_frequency_5grams_Fanu['Frequency'] / total_5grams_Fanu

# Sort the DataFrame by frequency in descending order
df_structure_frequency_5grams_Fanu = df_structure_frequency_5grams_Fanu.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_5grams_Fanu
# Out:
#                     Structure  Frequency  Relative Frequency
# 103      (DT, NN, IN, DT, NN)        651            0.004235
# 270      (IN, DT, NN, IN, DT)        511            0.003324
# 116       (IN, DT, JJ, NN, ,)        399            0.002596
# 312      (NN, IN, DT, JJ, NN)        394            0.002563
# 271       (NN, IN, DT, NN, ,)        394            0.002563
# ...                       ...        ...                 ...
# 31680   (IN, JJ, ,, VBD, NNP)          1            0.000007
# 31682   (,, VBD, NNP, NNP, :)          1            0.000007
# 31684   (NNP, :, CC, RB, VBG)          1            0.000007
# 31685  (:, CC, RB, VBG, PRP$)          1            0.000007
# 69551  (NNP, DT, NN, IN, PRP)          1            0.000007
#
# [69552 rows x 3 columns]

# %%
df_structure_frequency_5grams_Fanu.head(25).to_csv('Fanu_structure_frequency_5grams.csv', index=False)

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find sentence structures frequency using 4-grams in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_5grams_subset = count_sentence_structures_5grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_5grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# 1097
# Subset 1:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 169
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 132
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 112
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 105
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 98
#
# Subset 2:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 101
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 76
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 61
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 58
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 48
#
# Subset 3:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 121
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 93
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 79
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 67
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 65
#
# Subset 4:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 130
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 103
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 92
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 79
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 79
#
# Subset 5:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 130
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 107
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 89
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 81
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 79

# %% [markdown]
# # Gothic corpus

# %%
# Gothic corpus
import pandas as pd


structure_frequency_Gothic = count_sentence_structures(text_Gothic)

# Calculate the total number of combinations in the corpus
total_combinations_Gothic = sum(structure_frequency_Gothic.values())

# Create a DataFrame from the structure_frequency dictionary
Gothic = pd.DataFrame(list(structure_frequency_Gothic.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each combination
Gothic['Relative Frequency'] = Gothic['Frequency'] / total_combinations_Gothic

# Filter out instances with frequency equal to 1
Gothic = Gothic[Gothic['Frequency'] > 1]

# Sort the DataFrame by frequency in descending order
Gothic = Gothic.sort_values(by='Relative Frequency', ascending=False)

# %%
Gothic.head(20)
# Out:
#         Structure  Frequency  Relative Frequency
# 14             NN      16452            0.035136
# 46             RB       9706            0.020729
# 102            CC       4591            0.009805
# 15     NN PRP VBD       3539            0.007558
# 157      IN DT NN       2804            0.005988
# 434       PRP VBD       2588            0.005527
# 259         DT NN       2442            0.005215
# 860           NNS       2243            0.004790
# 296           NNP       2226            0.004754
# 173    NN VBD NNP       2087            0.004457
# 39        PRP VBP       2010            0.004293
# 2303   NN VBD PRP       1857            0.003966
# 134         IN NN       1848            0.003947
# 10    IN DT JJ NN       1675            0.003577
# 640       NNP NNP       1556            0.003323
# 239       PRP$ NN       1540            0.003289
# 106         JJ NN       1480            0.003161
# 13         NN NNP       1476            0.003152
# 242            IN       1442            0.003080
# 34     JJ NNP NNP       1427            0.003048

# %%
# Calculate sentence structures frequency using 3-grams
structure_frequency_3grams_Gothic = count_sentence_structures_3grams(text_Gothic)

# Calculate the total number of 3-grams in the corpus
total_3grams_Gothic = sum(structure_frequency_3grams_Gothic.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_3grams_Gothic = pd.DataFrame(list(structure_frequency_3grams_Gothic.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_3grams_Gothic['Relative Frequency'] = df_structure_frequency_3grams_Gothic['Frequency'] / total_3grams_Gothic

# Sort the DataFrame by frequency in descending order
df_structure_frequency_3grams_Gothic = df_structure_frequency_3grams_Gothic.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_3grams_Gothic
# Out:
#             Structure  Frequency  Relative Frequency
# 4        (IN, DT, NN)      72970        2.194610e-02
# 33       (DT, NN, IN)      50940        1.532046e-02
# 20       (DT, JJ, NN)      42276        1.271472e-02
# 328      (NN, IN, DT)      37488        1.127471e-02
# 179       (DT, NN, ,)      30687        9.229270e-03
# ...               ...        ...                 ...
# 16915   (NNP, UH, NN)          1        3.007550e-07
# 16914  (PRP, NNP, UH)          1        3.007550e-07
# 16910    (JJ, ), NNP)          1        3.007550e-07
# 16908   (DT, RP, WRB)          1        3.007550e-07
# 21363     (TO, :, JJ)          1        3.007550e-07
#
# [21364 rows x 3 columns]

# %%
df_structure_frequency_3grams_Gothic.head(25).to_csv('Gothic_structure_frequency_3grams.csv', index=False)

# %%
# Poe vs Gothic

# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find sentence structures frequency using 3-grams in each subset
# Find sentence structures frequency using 3-grams in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_3grams_subset = count_sentence_structures_3grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_3grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# Subset 1:
# Structure: ('IN', 'DT', 'NN'), Frequency: 726
# Structure: ('DT', 'NN', 'IN'), Frequency: 538
# Structure: ('DT', 'JJ', 'NN'), Frequency: 449
# Structure: ('NN', 'IN', 'DT'), Frequency: 362
# Structure: ('NN', ',', 'CC'), Frequency: 347
#
# Subset 2:
# Structure: ('IN', 'DT', 'NN'), Frequency: 609
# Structure: ('DT', 'NN', 'IN'), Frequency: 445
# Structure: ('DT', 'JJ', 'NN'), Frequency: 360
# Structure: ('NN', 'IN', 'DT'), Frequency: 295
# Structure: ('NN', ',', 'CC'), Frequency: 295
#
# Subset 3:
# Structure: ('IN', 'DT', 'NN'), Frequency: 531
# Structure: ('DT', 'NN', 'IN'), Frequency: 347
# Structure: ('DT', 'JJ', 'NN'), Frequency: 329
# Structure: ('NN', ',', 'CC'), Frequency: 315
# Structure: ('PRP', 'MD', 'VB'), Frequency: 305
#
# Subset 4:
# Structure: ('IN', 'DT', 'NN'), Frequency: 631
# Structure: ('DT', 'JJ', 'NN'), Frequency: 438
# Structure: ('DT', 'NN', 'IN'), Frequency: 408
# Structure: ('NN', ',', 'CC'), Frequency: 310
# Structure: ('DT', 'NN', ','), Frequency: 305
#
# Subset 5:
# Structure: ('IN', 'DT', 'NN'), Frequency: 813
# Structure: ('DT', 'JJ', 'NN'), Frequency: 614
# Structure: ('DT', 'NN', 'IN'), Frequency: 579
# Structure: ('NN', 'IN', 'DT'), Frequency: 453
# Structure: ('IN', 'DT', 'JJ'), Frequency: 386
#
# Subset 6:
# Structure: ('IN', 'DT', 'NN'), Frequency: 687
# Structure: ('DT', 'JJ', 'NN'), Frequency: 523
# Structure: ('DT', 'NN', 'IN'), Frequency: 494
# Structure: ('NN', 'IN', 'DT'), Frequency: 386
# Structure: ('IN', 'DT', 'JJ'), Frequency: 325
#
# Subset 7:
# Structure: ('IN', 'DT', 'NN'), Frequency: 675
# Structure: ('DT', 'JJ', 'NN'), Frequency: 548
# Structure: ('DT', 'NN', 'IN'), Frequency: 482
# Structure: ('NN', 'IN', 'DT'), Frequency: 391
# Structure: ('DT', 'NN', ','), Frequency: 316
#
# Subset 8:
# Structure: ('IN', 'DT', 'NN'), Frequency: 729
# Structure: ('DT', 'JJ', 'NN'), Frequency: 567
# Structure: ('DT', 'NN', 'IN'), Frequency: 530
# Structure: ('NN', 'IN', 'DT'), Frequency: 393
# Structure: ('DT', 'NN', ','), Frequency: 321
#
# Subset 9:
# Structure: ('IN', 'DT', 'NN'), Frequency: 601
# Structure: ('DT', 'JJ', 'NN'), Frequency: 443
# Structure: ('DT', 'NN', 'IN'), Frequency: 382
# Structure: ('NN', 'IN', 'DT'), Frequency: 329
# Structure: ('DT', 'NN', ','), Frequency: 290
#
# Subset 10:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1067
# Structure: ('DT', 'NN', 'IN'), Frequency: 738
# Structure: ('DT', 'JJ', 'NN'), Frequency: 575
# Structure: ('NN', 'IN', 'DT'), Frequency: 563
# Structure: ('DT', 'NN', ','), Frequency: 445
#
# Subset 11:
# Structure: ('IN', 'DT', 'NN'), Frequency: 983
# Structure: ('DT', 'NN', 'IN'), Frequency: 768
# Structure: ('DT', 'JJ', 'NN'), Frequency: 583
# Structure: ('NN', 'IN', 'DT'), Frequency: 507
# Structure: ('PRP', 'MD', 'VB'), Frequency: 507
#
# Subset 12:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1078
# Structure: ('DT', 'NN', 'IN'), Frequency: 862
# Structure: ('DT', 'JJ', 'NN'), Frequency: 659
# Structure: ('NN', 'IN', 'DT'), Frequency: 584
# Structure: ('PRP', 'MD', 'VB'), Frequency: 553
#
# Subset 13:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1465
# Structure: ('DT', 'NN', 'IN'), Frequency: 1028
# Structure: ('NN', 'IN', 'DT'), Frequency: 770
# Structure: ('DT', 'JJ', 'NN'), Frequency: 764
# Structure: ('DT', 'NN', ','), Frequency: 623
#
# Subset 14:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1105
# Structure: ('DT', 'NN', 'IN'), Frequency: 850
# Structure: ('DT', 'JJ', 'NN'), Frequency: 673
# Structure: ('NN', 'IN', 'DT'), Frequency: 579
# Structure: ('PRP', 'MD', 'VB'), Frequency: 520
#
# Subset 15:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1330
# Structure: ('DT', 'NN', 'IN'), Frequency: 920
# Structure: ('DT', 'JJ', 'NN'), Frequency: 672
# Structure: ('DT', 'NN', ','), Frequency: 651
# Structure: ('NN', 'IN', 'DT'), Frequency: 621
#
# Subset 16:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1527
# Structure: ('DT', 'NN', 'IN'), Frequency: 1009
# Structure: ('DT', 'JJ', 'NN'), Frequency: 797
# Structure: ('NN', 'IN', 'DT'), Frequency: 729
# Structure: ('DT', 'NN', ','), Frequency: 703
#
# Subset 17:
# Structure: ('IN', 'DT', 'NN'), Frequency: 830
# Structure: ('DT', 'NN', 'IN'), Frequency: 561
# Structure: ('DT', 'JJ', 'NN'), Frequency: 530
# Structure: ('NN', 'IN', 'DT'), Frequency: 460
# Structure: ('IN', 'DT', 'JJ'), Frequency: 407
#
# Subset 18:
# Structure: ('IN', 'DT', 'NN'), Frequency: 724
# Structure: ('DT', 'NN', 'IN'), Frequency: 520
# Structure: ('DT', 'JJ', 'NN'), Frequency: 437
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 365
# Structure: ('NN', 'IN', 'DT'), Frequency: 348
#
# Subset 19:
# Structure: ('IN', 'DT', 'NN'), Frequency: 812
# Structure: ('DT', 'NN', 'IN'), Frequency: 557
# Structure: ('NN', 'IN', 'DT'), Frequency: 452
# Structure: ('DT', 'JJ', 'NN'), Frequency: 446
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 365
#
# Subset 20:
# Structure: ('IN', 'DT', 'NN'), Frequency: 821
# Structure: ('DT', 'NN', 'IN'), Frequency: 508
# Structure: ('NN', 'IN', 'DT'), Frequency: 402
# Structure: ('DT', 'JJ', 'NN'), Frequency: 384
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 342
#
# Subset 21:
# Structure: ('IN', 'DT', 'NN'), Frequency: 733
# Structure: ('DT', 'NN', 'IN'), Frequency: 456
# Structure: ('DT', 'JJ', 'NN'), Frequency: 397
# Structure: ('NN', 'IN', 'DT'), Frequency: 361
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 287
#
# Subset 22:
# Structure: ('IN', 'DT', 'NN'), Frequency: 985
# Structure: ('DT', 'NN', 'IN'), Frequency: 690
# Structure: ('DT', 'JJ', 'NN'), Frequency: 505
# Structure: ('NN', 'IN', 'DT'), Frequency: 499
# Structure: ('IN', 'DT', 'JJ'), Frequency: 332
#
# Subset 23:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1046
# Structure: ('DT', 'NN', 'IN'), Frequency: 707
# Structure: ('NN', 'IN', 'DT'), Frequency: 586
# Structure: ('DT', 'JJ', 'NN'), Frequency: 543
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 342
#
# Subset 24:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1022
# Structure: ('DT', 'NN', 'IN'), Frequency: 740
# Structure: ('DT', 'JJ', 'NN'), Frequency: 608
# Structure: ('NN', 'IN', 'DT'), Frequency: 568
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 445
#
# Subset 25:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1042
# Structure: ('DT', 'NN', 'IN'), Frequency: 695
# Structure: ('DT', 'JJ', 'NN'), Frequency: 547
# Structure: ('NN', 'IN', 'DT'), Frequency: 476
# Structure: ('IN', 'PRP', 'VBD'), Frequency: 384

# %%
# Fanu vs Gothic

# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find sentence structures frequency using 3-grams in each subset
# Find sentence structures frequency using 3-grams in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_3grams_subset = count_sentence_structures_3grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_3grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# Subset 1:
# Structure: ('IN', 'DT', 'NN'), Frequency: 572
# Structure: ('DT', 'NN', 'IN'), Frequency: 418
# Structure: ('DT', 'JJ', 'NN'), Frequency: 348
# Structure: ('NN', 'IN', 'DT'), Frequency: 284
# Structure: ('NN', ',', 'CC'), Frequency: 272
#
# Subset 2:
# Structure: ('IN', 'DT', 'NN'), Frequency: 367
# Structure: ('DT', 'NN', 'IN'), Frequency: 267
# Structure: ('DT', 'JJ', 'NN'), Frequency: 214
# Structure: ('NN', ',', 'CC'), Frequency: 185
# Structure: ('NN', 'IN', 'DT'), Frequency: 172
#
# Subset 3:
# Structure: ('IN', 'DT', 'NN'), Frequency: 462
# Structure: ('DT', 'NN', 'IN'), Frequency: 339
# Structure: ('DT', 'JJ', 'NN'), Frequency: 299
# Structure: ('NN', 'IN', 'DT'), Frequency: 240
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 222
#
# Subset 4:
# Structure: ('IN', 'DT', 'NN'), Frequency: 395
# Structure: ('DT', 'NN', 'IN'), Frequency: 268
# Structure: ('DT', 'JJ', 'NN'), Frequency: 230
# Structure: ('NN', ',', 'CC'), Frequency: 227
# Structure: ('PRP', 'MD', 'VB'), Frequency: 208
#
# Subset 5:
# Structure: ('IN', 'DT', 'NN'), Frequency: 345
# Structure: ('DT', 'JJ', 'NN'), Frequency: 246
# Structure: ('DT', 'NN', 'IN'), Frequency: 235
# Structure: ('NN', ',', 'CC'), Frequency: 215
# Structure: ('PRP', 'MD', 'VB'), Frequency: 205
#
# Subset 6:
# Structure: ('IN', 'DT', 'NN'), Frequency: 492
# Structure: ('DT', 'JJ', 'NN'), Frequency: 349
# Structure: ('DT', 'NN', 'IN'), Frequency: 297
# Structure: ('NN', 'IN', 'DT'), Frequency: 239
# Structure: ('DT', 'NN', ','), Frequency: 222
#
# Subset 7:
# Structure: ('IN', 'DT', 'NN'), Frequency: 610
# Structure: ('DT', 'NN', 'IN'), Frequency: 449
# Structure: ('DT', 'JJ', 'NN'), Frequency: 443
# Structure: ('NN', 'IN', 'DT'), Frequency: 333
# Structure: ('IN', 'DT', 'JJ'), Frequency: 278
#
# Subset 8:
# Structure: ('IN', 'DT', 'NN'), Frequency: 468
# Structure: ('DT', 'JJ', 'NN'), Frequency: 360
# Structure: ('DT', 'NN', 'IN'), Frequency: 311
# Structure: ('NN', 'IN', 'DT'), Frequency: 275
# Structure: ('DT', 'NN', ','), Frequency: 231
#
# Subset 9:
# Structure: ('IN', 'DT', 'NN'), Frequency: 482
# Structure: ('DT', 'JJ', 'NN'), Frequency: 374
# Structure: ('DT', 'NN', 'IN'), Frequency: 360
# Structure: ('NN', 'IN', 'DT'), Frequency: 281
# Structure: ('IN', 'DT', 'JJ'), Frequency: 227
#
# Subset 10:
# Structure: ('IN', 'DT', 'NN'), Frequency: 476
# Structure: ('DT', 'JJ', 'NN'), Frequency: 390
# Structure: ('DT', 'NN', 'IN'), Frequency: 347
# Structure: ('NN', 'IN', 'DT'), Frequency: 267
# Structure: ('DT', 'NN', ','), Frequency: 233
#
# Subset 11:
# Structure: ('IN', 'DT', 'NN'), Frequency: 498
# Structure: ('DT', 'JJ', 'NN'), Frequency: 388
# Structure: ('DT', 'NN', 'IN'), Frequency: 350
# Structure: ('NN', 'IN', 'DT'), Frequency: 247
# Structure: ('DT', 'NN', ','), Frequency: 224
#
# Subset 12:
# Structure: ('IN', 'DT', 'NN'), Frequency: 446
# Structure: ('DT', 'JJ', 'NN'), Frequency: 337
# Structure: ('DT', 'NN', 'IN'), Frequency: 326
# Structure: ('NN', 'IN', 'DT'), Frequency: 257
# Structure: ('NN', ',', 'CC'), Frequency: 202
#
# Subset 13:
# Structure: ('IN', 'DT', 'NN'), Frequency: 423
# Structure: ('DT', 'JJ', 'NN'), Frequency: 320
# Structure: ('DT', 'NN', 'IN'), Frequency: 262
# Structure: ('NN', 'IN', 'DT'), Frequency: 232
# Structure: ('DT', 'NN', ','), Frequency: 220
#
# Subset 14:
# Structure: ('IN', 'DT', 'NN'), Frequency: 795
# Structure: ('DT', 'NN', 'IN'), Frequency: 544
# Structure: ('NN', 'IN', 'DT'), Frequency: 420
# Structure: ('DT', 'JJ', 'NN'), Frequency: 410
# Structure: ('DT', 'NN', ','), Frequency: 321
#
# Subset 15:
# Structure: ('IN', 'DT', 'NN'), Frequency: 712
# Structure: ('DT', 'NN', 'IN'), Frequency: 547
# Structure: ('DT', 'JJ', 'NN'), Frequency: 399
# Structure: ('NN', 'IN', 'DT'), Frequency: 380
# Structure: ('DT', 'NN', ','), Frequency: 336
#
# Subset 16:
# Structure: ('IN', 'DT', 'NN'), Frequency: 739
# Structure: ('DT', 'NN', 'IN'), Frequency: 564
# Structure: ('DT', 'JJ', 'NN'), Frequency: 439
# Structure: ('PRP', 'MD', 'VB'), Frequency: 403
# Structure: ('NN', 'IN', 'DT'), Frequency: 374
#
# Subset 17:
# Structure: ('IN', 'DT', 'NN'), Frequency: 740
# Structure: ('DT', 'NN', 'IN'), Frequency: 602
# Structure: ('DT', 'JJ', 'NN'), Frequency: 474
# Structure: ('NN', 'IN', 'DT'), Frequency: 405
# Structure: ('PRP', 'MD', 'VB'), Frequency: 393
#
# Subset 18:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1041
# Structure: ('DT', 'NN', 'IN'), Frequency: 794
# Structure: ('NN', 'IN', 'DT'), Frequency: 571
# Structure: ('DT', 'JJ', 'NN'), Frequency: 570
# Structure: ('DT', 'NN', ','), Frequency: 438
#
# Subset 19:
# Structure: ('IN', 'DT', 'NN'), Frequency: 861
# Structure: ('DT', 'NN', 'IN'), Frequency: 562
# Structure: ('DT', 'JJ', 'NN'), Frequency: 454
# Structure: ('NN', 'IN', 'DT'), Frequency: 416
# Structure: ('DT', 'NN', ','), Frequency: 366
#
# Subset 20:
# Structure: ('IN', 'DT', 'NN'), Frequency: 761
# Structure: ('DT', 'NN', 'IN'), Frequency: 596
# Structure: ('DT', 'JJ', 'NN'), Frequency: 478
# Structure: ('NN', 'IN', 'DT'), Frequency: 419
# Structure: ('PRP', 'MD', 'VB'), Frequency: 376
#
# Subset 21:
# Structure: ('IN', 'DT', 'NN'), Frequency: 970
# Structure: ('DT', 'NN', 'IN'), Frequency: 689
# Structure: ('DT', 'NN', ','), Frequency: 489
# Structure: ('DT', 'JJ', 'NN'), Frequency: 473
# Structure: ('NN', 'IN', 'DT'), Frequency: 452
#
# Subset 22:
# Structure: ('IN', 'DT', 'NN'), Frequency: 949
# Structure: ('DT', 'NN', 'IN'), Frequency: 609
# Structure: ('DT', 'JJ', 'NN'), Frequency: 505
# Structure: ('DT', 'NN', ','), Frequency: 446
# Structure: ('PRP', 'MD', 'VB'), Frequency: 439
#
# Subset 23:
# Structure: ('IN', 'DT', 'NN'), Frequency: 1028
# Structure: ('DT', 'NN', 'IN'), Frequency: 697
# Structure: ('DT', 'JJ', 'NN'), Frequency: 553
# Structure: ('NN', 'IN', 'DT'), Frequency: 511
# Structure: ('DT', 'NN', ','), Frequency: 448
#
# Subset 24:
# Structure: ('IN', 'DT', 'NN'), Frequency: 597
# Structure: ('DT', 'NN', 'IN'), Frequency: 427
# Structure: ('DT', 'JJ', 'NN'), Frequency: 373
# Structure: ('NN', 'IN', 'DT'), Frequency: 331
# Structure: ('IN', 'DT', 'JJ'), Frequency: 298
#
# Subset 25:
# Structure: ('IN', 'DT', 'NN'), Frequency: 552
# Structure: ('DT', 'NN', 'IN'), Frequency: 353
# Structure: ('DT', 'JJ', 'NN'), Frequency: 326
# Structure: ('NN', 'IN', 'DT'), Frequency: 266
# Structure: ('IN', 'PRP$', 'NN'), Frequency: 226

# %%
# Calculate sentence structures frequency using 4-grams
structure_frequency_4grams_Gothic = count_sentence_structures_4grams(text_Gothic)

# Calculate the total number of 3-grams in the corpus
total_4grams_Gothic = sum(structure_frequency_4grams_Gothic.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_4grams_Gothic = pd.DataFrame(list(structure_frequency_4grams_Gothic.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_4grams_Gothic['Relative Frequency'] = df_structure_frequency_4grams_Gothic['Frequency'] / total_4grams_Gothic

# Sort the DataFrame by frequency in descending order
df_structure_frequency_4grams_Gothic = df_structure_frequency_4grams_Gothic.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_4grams_Gothic
# Out:
#                 Structure  Frequency  Relative Frequency
# 445      (NN, IN, DT, NN)      22172        6.917192e-03
# 33       (IN, DT, NN, IN)      21508        6.710038e-03
# 90       (IN, DT, JJ, NN)      18695        5.832442e-03
# 431      (DT, NN, IN, DT)      17623        5.498001e-03
# 436       (IN, DT, NN, ,)      17194        5.364162e-03
# ...                   ...        ...                 ...
# 91898    (VBN, RP, JJ, :)          1        3.119787e-07
# 91901    (NN, (, JJ, PRP)          1        3.119787e-07
# 91902     ((, JJ, PRP, ))          1        3.119787e-07
# 91903   (JJ, PRP, ), RBS)          1        3.119787e-07
# 140930    (VB, TO, ,, TO)          1        3.119787e-07
#
# [140931 rows x 3 columns]

# %%
df_structure_frequency_4grams_Gothic.head(25).to_csv('Gothic_structure_frequency_4grams.csv', index=False)

# %%
#Gothic vs Poe
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find sentence structures frequency using 4-grams in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_4grams_subset = count_sentence_structures_4grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_4grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:5]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# Subset 1:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 235
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 193
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 180
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 166
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 164
#
# Subset 2:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 207
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 148
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 127
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 117
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 112
#
# Subset 3:
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 152
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 151
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 120
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 119
# Structure: ('PRP', 'VBP', 'JJ', 'NN'), Frequency: 116
#
# Subset 4:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 189
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 157
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 152
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 143
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 119
#
# Subset 5:
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 262
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 257
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 227
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 171
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 166
#
# Subset 6:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 202
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 196
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 182
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 155
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 151
#
# Subset 7:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 226
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 204
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 167
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 157
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 141
#
# Subset 8:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 234
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 207
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 202
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 153
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 152
#
# Subset 9:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 174
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 168
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 140
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 131
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 122
#
# Subset 10:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 354
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 315
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 303
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 263
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 254
#
# Subset 11:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 312
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 298
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 267
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 229
# Structure: (',', "''", 'VBD', 'NNP'), Frequency: 225
#
# Subset 12:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 329
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 324
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 313
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 304
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 231
#
# Subset 13:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 459
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 433
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 413
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 336
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 331
#
# Subset 14:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 335
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 318
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 304
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 281
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 232
#
# Subset 15:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 378
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 358
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 345
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 322
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 270
#
# Subset 16:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 448
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 417
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 371
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 363
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 341
#
# Subset 17:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 299
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 268
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 244
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 220
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 201
#
# Subset 18:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 231
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 228
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 189
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 156
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 146
#
# Subset 19:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 275
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 261
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 224
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 216
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 160
#
# Subset 20:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 252
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 230
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 187
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 178
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 167
#
# Subset 21:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 234
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 229
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 194
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 149
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 130
#
# Subset 22:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 337
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 317
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 231
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 226
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 174
#
# Subset 23:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 376
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 325
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 286
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 245
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 203
#
# Subset 24:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 347
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 341
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 307
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 262
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 236
#
# Subset 25:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 340
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 308
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 267
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 226
# Structure: (',', 'IN', 'DT', 'NN'), Frequency: 223

# %%
#Gothic vs Fanu
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find sentence structures frequency using 4-grams in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_4grams_subset = count_sentence_structures_4grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_4grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:10]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# Subset 1:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 185
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 153
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 145
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 130
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 125
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 89
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 78
# Structure: ('PRP', 'VBD', 'DT', 'NN'), Frequency: 77
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 76
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 76
#
# Subset 2:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 117
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 87
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 84
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 83
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 74
# Structure: ('PRP', 'VBP', 'JJ', 'NN'), Frequency: 68
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 65
# Structure: ('PRP', 'VBD', 'DT', 'NN'), Frequency: 64
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 64
# Structure: ('PRP', 'MD', 'RB', 'VB'), Frequency: 58
#
# Subset 3:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 157
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 117
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 98
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 98
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 94
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 86
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 84
# Structure: ('PRP', 'VBP', 'JJ', 'NN'), Frequency: 64
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 62
# Structure: ('DT', 'NN', 'IN', 'PRP$'), Frequency: 60
#
# Subset 4:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 121
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 108
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 92
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 83
# Structure: ('PRP', 'VBP', 'JJ', 'NN'), Frequency: 81
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 74
# Structure: ('NN', ',', 'CC', 'VBD'), Frequency: 73
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 72
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 69
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 68
#
# Subset 5:
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 99
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 92
# Structure: ('PRP', 'VBP', 'JJ', 'NN'), Frequency: 87
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 77
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 76
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 74
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 72
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 69
# Structure: ('.', 'NN', 'PRP', 'VBD'), Frequency: 59
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 58
#
# Subset 6:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 143
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 142
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 115
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 106
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 88
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 78
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 72
# Structure: ('PRP', 'VBD', 'DT', 'NN'), Frequency: 68
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 64
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 61
#
# Subset 7:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 197
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 196
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 177
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 130
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 126
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 112
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 99
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 99
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 86
# Structure: ('NN', ',', 'PRP', 'VBD'), Frequency: 82
#
# Subset 8:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 150
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 132
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 111
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 108
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 105
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 102
# Structure: ('NN', 'IN', 'DT', 'JJ'), Frequency: 72
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 70
# Structure: ('NN', ',', 'PRP', 'VBD'), Frequency: 65
# Structure: ('JJ', 'NN', 'IN', 'DT'), Frequency: 63
#
# Subset 9:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 153
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 139
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 138
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 107
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 102
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 87
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 86
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 86
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 79
# Structure: ('PRP', 'MD', 'RB', 'VB'), Frequency: 73
#
# Subset 10:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 151
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 145
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 115
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 113
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 113
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 95
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 70
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 69
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 68
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 65
#
# Subset 11:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 160
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 134
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 131
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 108
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 107
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 90
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 79
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 74
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 73
# Structure: ('IN', 'PRP$', 'NN', ','), Frequency: 66
#
# Subset 12:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 131
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 131
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 125
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 100
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 85
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 79
# Structure: ('NN', 'IN', 'DT', 'JJ'), Frequency: 72
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 70
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 66
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 63
#
# Subset 13:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 128
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 120
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 94
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 93
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 92
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 87
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 73
# Structure: ('NN', 'IN', 'DT', 'JJ'), Frequency: 63
# Structure: ('NN', ',', 'PRP', 'VBD'), Frequency: 62
# Structure: ('JJ', 'NN', 'IN', 'DT'), Frequency: 56
#
# Subset 14:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 263
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 243
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 228
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 191
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 185
# Structure: (',', "''", 'VBD', 'NNP'), Frequency: 184
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 136
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 108
# Structure: ('JJ', 'NN', 'IN', 'DT'), Frequency: 99
# Structure: ('DT', 'NN', '.', "''"), Frequency: 93
#
# Subset 15:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 227
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 212
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 199
# Structure: (',', "''", 'VBD', 'NNP'), Frequency: 176
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 173
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 156
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 143
# Structure: ('DT', 'NN', '.', "''"), Frequency: 111
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 96
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 94
#
# Subset 16:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 230
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 223
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 204
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 178
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 167
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 140
# Structure: ('PRP', 'MD', 'RB', 'VB'), Frequency: 135
# Structure: (',', "''", 'VBD', 'NNP'), Frequency: 117
# Structure: ('DT', 'NN', '.', "''"), Frequency: 117
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 105
# Subset 17:
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 233
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 223
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 219
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 209
# Structure: (',', "''", 'VBD', 'NNP'), Frequency: 165
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 152
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 150
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 112
# Structure: ('PRP', 'MD', 'RB', 'VB'), Frequency: 110
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 99
#
# Subset 18:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 331
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 330
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 324
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 258
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 240
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 174
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 151
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 133
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 132
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 127
#
# Subset 19:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 260
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 222
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 207
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 191
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 182
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 154
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 134
# Structure: ('DT', 'NN', '.', "''"), Frequency: 124
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 122
# Structure: (',', "''", 'VBD', 'NNP'), Frequency: 110
#
# Subset 20:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 239
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 221
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 217
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 192
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 173
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 171
# Structure: ('PRP', 'MD', 'RB', 'VB'), Frequency: 117
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 107
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 99
# Structure: ('DT', 'NN', 'IN', 'NN'), Frequency: 97
#
# Subset 21:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 278
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 273
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 250
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 232
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 194
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 150
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 137
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 125
# Structure: (',', 'IN', 'DT', 'NN'), Frequency: 118
# Structure: ('PRP', 'MD', 'RB', 'VB'), Frequency: 116
#
# Subset 22:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 269
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 242
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 240
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 226
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 207
# Structure: (',', "''", 'VBD', 'NNP'), Frequency: 171
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 157
# Structure: ('PRP', 'MD', 'RB', 'VB'), Frequency: 155
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 146
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 144
#
# Subset 23:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 308
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 289
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 249
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 247
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 240
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 175
# Structure: (',', 'IN', 'DT', 'NN'), Frequency: 122
# Structure: ('DT', 'JJ', 'NN', ','), Frequency: 119
# Structure: ('NNP', 'NNP', 'NNP', 'NNP'), Frequency: 119
# Structure: ('DT', 'NN', ',', 'CC'), Frequency: 116
#
# Subset 24:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 212
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 194
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 189
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 157
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 149
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 117
# Structure: ('JJ', 'NN', 'IN', 'DT'), Frequency: 86
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 79
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 79
# Structure: ('NN', 'IN', 'DT', 'JJ'), Frequency: 75
#
# Subset 25:
# Structure: ('NN', 'IN', 'DT', 'NN'), Frequency: 182
# Structure: ('IN', 'DT', 'NN', 'IN'), Frequency: 142
# Structure: ('IN', 'DT', 'JJ', 'NN'), Frequency: 135
# Structure: ('DT', 'JJ', 'NN', 'IN'), Frequency: 125
# Structure: ('DT', 'NN', 'IN', 'DT'), Frequency: 99
# Structure: ('NN', 'IN', 'PRP$', 'NN'), Frequency: 91
# Structure: ('IN', 'DT', 'NN', ','), Frequency: 90
# Structure: ('IN', 'DT', 'NN', '.'), Frequency: 80
# Structure: ('JJ', 'NN', 'IN', 'DT'), Frequency: 79
# Structure: ('DT', 'NN', 'IN', 'PRP$'), Frequency: 79

# %%
# Calculate sentence structures frequency using 5-grams
structure_frequency_5grams_Gothic = count_sentence_structures_5grams(text_Gothic)

# Calculate the total number of 3-grams in the corpus
total_5grams_Gothic = sum(structure_frequency_5grams_Gothic.values())

# Create a DataFrame from the structure_frequency dictionary
df_structure_frequency_5grams_Gothic = pd.DataFrame(list(structure_frequency_5grams_Gothic.items()), columns=['Structure', 'Frequency'])

# Calculate the relative frequency for each 3-gram
df_structure_frequency_5grams_Gothic['Relative Frequency'] = df_structure_frequency_5grams_Gothic['Frequency'] / total_5grams_Gothic

# Sort the DataFrame by frequency in descending order
df_structure_frequency_5grams_Gothic = df_structure_frequency_5grams_Gothic.sort_values(by='Frequency', ascending=False)

# %%
df_structure_frequency_5grams_Gothic
# Out:
#                       Structure  Frequency  Relative Frequency
# 467        (DT, NN, IN, DT, NN)      10351        3.352479e-03
# 466        (IN, DT, NN, IN, DT)       7967        2.580350e-03
# 1080        (NN, IN, DT, NN, ,)       5920        1.917368e-03
# 88          (IN, DT, JJ, NN, ,)       5328        1.725631e-03
# 457        (IN, DT, JJ, NN, IN)       5208        1.686766e-03
# ...                         ...        ...                 ...
# 268351    (VBP, VB, DT, JJ, CD)          1        3.238797e-07
# 268354      (JJ, CD, ., NN, IN)          1        3.238797e-07
# 268355     (CD, ., NN, IN, VBG)          1        3.238797e-07
# 268357   (JJ, VBG, VBN, RB, RB)          1        3.238797e-07
# 492225  (VBD, VB, JJ, IN, PRP$)          1        3.238797e-07
#
# [492226 rows x 3 columns]

# %%
df_structure_frequency_5grams_Gothic.head(25).to_csv('Gothic_structure_frequency_5grams.csv', index=False)

# %%
# Poe vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find sentence structures frequency using 4-grams in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_5grams_subset = count_sentence_structures_5grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_5grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:100]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# Subset 1:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 110
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 76
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 65
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 57
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 55
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 52
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 46
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 42
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 36
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 36
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 36
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 34
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 34
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 33
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 33
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 32
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 32
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 32
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 30
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 30
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 29
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 28
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 27
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 27
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 26
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 25
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 24
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 24
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 24
# Structure: ('NN', 'PRP', 'VBD', ',', 'VBG'), Frequency: 24
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 24
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 23
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 22
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 22
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 22
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 22
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 22
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 22
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 20
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 20
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 20
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 20
# Structure: ('PRP', 'IN', 'DT', 'NN', ','), Frequency: 20
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 19
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 19
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 19
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 19
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 19
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 18
# Structure: ('CC', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 18
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 17
# Structure: ('MD', 'VB', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 17
# Structure: ('PRP', 'VBD', 'VBN', 'TO', 'VB'), Frequency: 17
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 17
# Structure: ('DT', 'NN', 'IN', 'DT', 'NNS'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', 'IN', 'VBG'), Frequency: 16
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'TO'), Frequency: 16
# Structure: (',', 'CC', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 16
# Structure: ('PRP$', 'NN', ':', 'CC', 'PRP'), Frequency: 16
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 16
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 16
# Structure: ('DT', 'JJ', 'NN', 'TO', 'VB'), Frequency: 15
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 15
# Structure: (',', 'IN', 'PRP', 'MD', 'VB'), Frequency: 15
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 15
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NNS'), Frequency: 15
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'IN'), Frequency: 15
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 15
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 15
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 14
# Structure: ('TO', 'VB', 'PRP', ',', 'CC'), Frequency: 14
# Structure: ('VBG', 'IN', 'DT', 'NN', ','), Frequency: 14
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 14
# Structure: ('DT', 'NN', ',', 'CC', 'DT'), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 14
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 14
# Structure: ('NN', ',', 'PRP', 'VBD', 'RB'), Frequency: 14
# Structure: (',', 'VBG', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('DT', 'NN', ':', 'CC', 'PRP'), Frequency: 14
# Structure: ('NN', ',', 'CC', 'RB', 'PRP'), Frequency: 14
# Structure: ('NN', 'IN', 'PRP', 'MD', 'VB'), Frequency: 13
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 13
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 13
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 13
# Structure: ('VBD', 'DT', 'NN', 'TO', 'VB'), Frequency: 13
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', 'TO', 'VB'), Frequency: 13
#
# Subset 2:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 79
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 47
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 46
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 46
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 37
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 36
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 36
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 36
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 36
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 35
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 34
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 33
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 31
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 31
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 31
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 31
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 30
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 29
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 28
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 27
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 26
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 26
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 25
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 25
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 24
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 24
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 23
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 23
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 22
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 22
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 22
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 22
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 21
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 21
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 21
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 20
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 20
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 19
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 19
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 19
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 18
# Structure: (',', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 18
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 18
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 17
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 17
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 16
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 16
# Structure: ('NN', 'PRP', 'VBD', ',', 'VBG'), Frequency: 16
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 15
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 15
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('NN', 'TO', 'VB', 'DT', 'NN'), Frequency: 15
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 15
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 15
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'VBP'), Frequency: 15
# Structure: ('IN', 'PRP', 'MD', 'VB', 'PRP'), Frequency: 14
# Structure: ('NN', 'IN', 'PRP', ',', 'CC'), Frequency: 14
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 14
# Structure: ('VB', 'DT', 'NN', 'IN', 'PRP'), Frequency: 14
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 14
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 14
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'IN'), Frequency: 14
# Structure: ('VBD', 'PRP', 'IN', 'PRP$', 'NN'), Frequency: 14
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 14
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('NN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 13
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 13
# Structure: ('NN', 'IN', 'PRP', 'MD', 'VB'), Frequency: 13
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 13
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 13
# Structure: ('IN', 'PRP$', 'NN', 'IN', 'DT'), Frequency: 13
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', ':', 'CC'), Frequency: 13
# Structure: ('NN', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'PRP', ','), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP'), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 13
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('PRP', 'VBD', 'VBN', 'IN', 'DT'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 12
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 12
# Structure: ('MD', 'VB', 'DT', 'NN', 'IN'), Frequency: 12
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'PRP'), Frequency: 12
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('TO', 'VB', 'PRP$', 'NN', ','), Frequency: 12
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'TO'), Frequency: 12
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: (',', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 12
# Structure: (',', 'CC', 'VBD', 'PRP', 'TO'), Frequency: 12
# Structure: (',', 'CC', 'PRP', 'VBD', 'PRP'), Frequency: 12
# Structure: ('NN', 'NN', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('VBD', 'IN', 'DT', 'NN', ','), Frequency: 12
# Subset 3:
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 52
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 51
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 46
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 46
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 36
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 34
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 34
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 33
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 33
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 32
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 32
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 31
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 31
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 31
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 30
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 30
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 29
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 27
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 27
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 27
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 26
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 26
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 26
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 26
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 24
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 24
# Structure: (',', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 24
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 24
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 23
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 23
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 22
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 22
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 21
# Structure: (',', 'CC', 'PRP', 'VBP', 'JJ'), Frequency: 21
# Structure: ('PRP', 'MD', 'VB', 'TO', 'VB'), Frequency: 21
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 21
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 21
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 21
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'PRP'), Frequency: 21
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 20
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 20
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('NN', 'PRP', 'VBD', ',', 'VBG'), Frequency: 20
# Structure: (',', 'IN', 'PRP', 'MD', 'VB'), Frequency: 20
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 19
# Structure: ('DT', 'NN', ':', 'CC', 'PRP'), Frequency: 19
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 19
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 19
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: ('PRP$', 'NN', ',', 'CC', 'PRP'), Frequency: 19
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 18
# Structure: ('RB', ',', 'IN', 'PRP', 'VBD'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 18
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 18
# Structure: ('NN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 17
# Structure: (':', 'CC', 'PRP', 'MD', 'VB'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 17
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 17
# Structure: ('NN', ':', 'CC', 'PRP', 'VBP'), Frequency: 17
# Structure: ('NNP', 'NNP', ',', 'PRP', 'VBP'), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 16
# Structure: ('PRP', 'VBD', 'TO', 'VB', 'PRP'), Frequency: 16
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 16
# Structure: ('.', 'NN', 'VBD', 'NNP', ','), Frequency: 16
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 16
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 16
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 15
# Structure: (':', 'CC', 'PRP', 'VBD', 'RB'), Frequency: 15
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 15
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 15
# Structure: ('VBD', 'DT', 'NN', ',', 'CC'), Frequency: 15
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'IN', 'PRP'), Frequency: 15
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('IN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 15
# Structure: ('NN', ',', 'PRP', 'MD', 'VB'), Frequency: 14
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 14
# Structure: ('NN', ',', 'CC', 'PRP', 'VBP'), Frequency: 14
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 14
# Structure: ('JJ', 'NN', ':', 'CC', 'PRP'), Frequency: 14
# Structure: ('IN', 'PRP$', 'NN', ':', 'CC'), Frequency: 14
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 14
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 14
# Structure: (',', 'CC', 'PRP', 'MD', 'VB'), Frequency: 14
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'IN'), Frequency: 14
# Structure: ('CC', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 13
# Structure: (':', 'CC', 'PRP', 'VBD', 'PRP'), Frequency: 13
# Structure: ('DT', 'NN', 'TO', 'VB', 'PRP'), Frequency: 13
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('PRP', 'MD', 'VB', 'PRP', '.'), Frequency: 13
# Structure: (',', 'IN', 'PRP', 'VBD', 'RB'), Frequency: 13
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 13
# Structure: ('NNS', 'IN', 'DT', 'NN', '.'), Frequency: 13
# Structure: ('VBD', 'IN', 'DT', 'NN', ','), Frequency: 13
# Structure: ('JJ', 'NN', ',', 'CC', 'VBD'), Frequency: 13
# Structure: ('PRP$', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 13
#
# Subset 4:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 74
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 53
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 51
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 46
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 43
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 39
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 39
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 38
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 35
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 34
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 34
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 32
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 32
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 32
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 31
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 30
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 29
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 29
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 29
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 26
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 25
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 24
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 24
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 23
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 22
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 22
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 22
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 21
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 21
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 21
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 20
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 20
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 19
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 19
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 19
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 19
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 19
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 19
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 19
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 18
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 18
# Structure: ('PRP$', 'NN', ',', 'PRP', 'VBD'), Frequency: 18
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 18
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 18
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 18
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 17
# Structure: ('NN', ',', 'PRP', 'VBD', 'PRP'), Frequency: 17
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 17
# Structure: ('IN', 'PRP$', 'NN', ',', 'PRP'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 17
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 17
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 17
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 16
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 16
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 16
# Structure: ('PRP', 'VBD', 'PRP$', 'NN', 'IN'), Frequency: 16
# Structure: (':', 'CC', 'PRP', 'MD', 'VB'), Frequency: 16
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 16
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 15
# Structure: ('PRP', 'IN', 'DT', 'NN', ','), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 15
# Structure: ('RB', ',', 'IN', 'PRP', 'VBD'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 15
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 15
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('PRP', 'VBD', 'PRP', 'TO', 'VB'), Frequency: 14
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 14
# Structure: (',', 'IN', 'PRP', 'VBD', 'RB'), Frequency: 14
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 14
# Structure: (',', 'CC', 'PRP', 'VBD', 'RB'), Frequency: 14
# Structure: ('RB', ',', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NNS'), Frequency: 13
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('PRP$', 'NN', ':', 'PRP', 'VBD'), Frequency: 13
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 13
# Structure: (',', 'CC', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', ':', 'PRP'), Frequency: 13
# Structure: ('PRP$', 'JJ', 'NN', ',', 'CC'), Frequency: 13
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 13
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 13
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP'), Frequency: 13
# Structure: ('VBD', 'DT', 'NN', ',', 'CC'), Frequency: 13
# Structure: (',', 'CC', 'VBD', 'IN', 'DT'), Frequency: 13
# Structure: ('PRP$', 'NN', ',', 'CC', 'PRP'), Frequency: 13
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 13
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 12
# Structure: ('VB', 'PRP', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('JJ', 'NN', ',', 'CC', 'RB'), Frequency: 12
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 12
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 12
# Structure: ('VBG', 'DT', 'JJ', 'NN', 'IN'), Frequency: 12
# Subset 5:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 100
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 79
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 71
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 62
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 61
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 59
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 56
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 55
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 53
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 50
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 47
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 43
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 42
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 32
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 32
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 32
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 32
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 32
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 31
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 31
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 30
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 30
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 29
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 29
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 29
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 28
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 27
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 27
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 26
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 26
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 26
# Structure: ('NN', ',', 'NN', ',', 'CC'), Frequency: 26
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 26
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 25
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 25
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 25
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 24
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 24
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 24
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 23
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 23
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 23
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 22
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('DT', 'NN', 'IN', 'NN', ':'), Frequency: 22
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 21
# Structure: ('DT', 'JJ', 'CC', 'JJ', 'NN'), Frequency: 21
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 21
# Structure: ('IN', 'DT', 'NN', ',', 'DT'), Frequency: 21
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 21
# Structure: ('NN', 'IN', 'NN', 'CC', 'NN'), Frequency: 21
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 20
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 20
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 20
# Structure: (',', 'NN', ',', 'CC', 'NN'), Frequency: 20
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 20
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 19
# Structure: ('VBD', 'DT', 'NN', 'IN', 'NN'), Frequency: 19
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 19
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 19
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 18
# Structure: ('PRP$', 'NN', ':', 'PRP', 'VBD'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', ',', 'PRP'), Frequency: 18
# Structure: (',', 'CC', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 18
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 18
# Structure: ('DT', 'JJ', ',', 'JJ', 'NN'), Frequency: 18
# Structure: ('NN', ',', 'PRP', 'VBD', 'RB'), Frequency: 18
# Structure: ('NN', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 18
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 17
# Structure: ('NN', 'IN', 'JJ', 'NN', ','), Frequency: 17
# Structure: (',', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 17
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 17
# Structure: (',', 'CC', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 16
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 16
# Structure: ('NN', ',', 'PRP', 'VBD', 'PRP'), Frequency: 16
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 16
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 16
# Structure: ('PRP', 'IN', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('PRP', 'VBD', 'VBN', 'IN', 'DT'), Frequency: 16
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('NN', ',', 'CC', 'NN', ','), Frequency: 16
# Structure: ('IN', 'NN', ',', 'PRP', 'VBD'), Frequency: 16
# Structure: ('NN', ',', 'DT', 'NN', ','), Frequency: 15
# Structure: ('DT', 'NN', ',', 'DT', 'JJ'), Frequency: 15
# Structure: ('JJ', 'CC', 'JJ', 'NN', ','), Frequency: 15
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 15
# Structure: ('JJ', 'NN', ',', 'IN', 'DT'), Frequency: 15
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('NNS', 'IN', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('IN', 'DT', 'JJ', 'NN', 'NN'), Frequency: 15
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'JJ'), Frequency: 15
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 15
#
# Subset 6:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 81
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 68
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 64
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 48
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 47
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 44
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 43
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 42
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 42
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 42
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 41
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 41
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 40
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 38
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 35
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 32
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 27
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 27
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 27
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 26
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 26
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 26
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 25
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 24
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 23
# Structure: (',', 'CC', 'DT', 'JJ', 'NN'), Frequency: 23
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 21
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 21
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 21
# Structure: ('IN', 'DT', 'JJ', 'NN', 'NN'), Frequency: 21
# Structure: ('IN', 'NN', 'CC', 'NN', ','), Frequency: 20
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 20
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 20
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 19
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 18
# Structure: ('CC', 'DT', 'JJ', 'NN', 'IN'), Frequency: 18
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 18
# Structure: ('NN', 'IN', 'NNP', 'NNP', 'NNP'), Frequency: 18
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 17
# Structure: ('JJ', 'NN', ',', 'DT', 'NN'), Frequency: 17
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 17
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: (':', 'PRP', 'MD', 'RB', 'VB'), Frequency: 17
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('NN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 16
# Structure: ('IN', 'NN', ',', 'PRP', 'VBD'), Frequency: 16
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 16
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 16
# Structure: ('IN', 'DT', 'NN', ',', 'DT'), Frequency: 16
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 16
# Structure: ('PRP', 'MD', 'RB', 'VB', 'DT'), Frequency: 16
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 16
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 16
# Structure: ('VBD', 'DT', 'NN', 'IN', 'NN'), Frequency: 16
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 16
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 16
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 15
# Structure: ('RB', ',', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('NN', ',', 'DT', 'NN', ','), Frequency: 15
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 15
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 15
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 15
# Structure: ('DT', 'JJ', 'JJ', 'NN', ','), Frequency: 15
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', 'TO', 'VB', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', ',', 'CC', 'DT', 'JJ'), Frequency: 15
# Structure: ('NN', ',', 'PRP', 'VBD', 'RB'), Frequency: 14
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 14
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 14
# Structure: ('CC', 'PRP', 'MD', 'RB', 'VB'), Frequency: 14
# Structure: ('PRP', 'VBD', 'IN', 'PRP$', 'NN'), Frequency: 14
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 14
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 14
# Structure: ('NN', ',', 'PRP', 'VBD', 'PRP'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', ':', 'PRP'), Frequency: 14
# Structure: ('NN', 'IN', 'NN', 'CC', 'NN'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 14
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 13
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', ',', 'DT'), Frequency: 13
# Structure: ('DT', 'NN', ',', 'IN', 'DT'), Frequency: 13
# Structure: ('JJ', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', 'IN', 'JJ'), Frequency: 13
# Structure: ('JJ', 'NN', 'IN', 'JJ', 'NN'), Frequency: 13
# Structure: ('PRP', 'MD', 'RB', 'VB', 'IN'), Frequency: 13
# Structure: ('NN', 'CC', 'NN', ',', 'CC'), Frequency: 13
# Subset 7:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 87
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 63
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 52
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 50
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 47
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 47
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 46
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 45
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 43
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 42
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 42
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 40
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 37
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 36
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 35
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 34
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 33
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 30
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 27
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 27
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 27
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 26
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 25
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 24
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 23
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 22
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 22
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 22
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 21
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 21
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 21
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 20
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 20
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 20
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 19
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 19
# Structure: ('PRP', 'MD', 'RB', 'VB', 'VBN'), Frequency: 19
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'CC', 'NN'), Frequency: 18
# Structure: (',', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 18
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 18
# Structure: (',', 'NNP', 'VBD', 'PRP', ','), Frequency: 17
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 17
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 17
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 17
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 17
# Structure: ('NN', ':', 'PRP', 'VBD', 'RB'), Frequency: 17
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 16
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('DT', 'JJ', ',', 'JJ', 'NN'), Frequency: 16
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 16
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 16
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 15
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('JJ', 'NN', ',', 'CC', 'VBD'), Frequency: 15
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', 'IN', 'NN', 'CC', 'NN'), Frequency: 15
# Structure: ('PRP', 'IN', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', ',', 'CC', 'VBD', 'IN'), Frequency: 15
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 15
# Structure: (',', 'CC', 'DT', 'JJ', 'NN'), Frequency: 14
# Structure: ('IN', 'PRP$', 'NN', ',', 'DT'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 14
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 14
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 14
# Structure: ('IN', 'DT', 'JJ', ',', 'JJ'), Frequency: 14
# Structure: ('JJ', ',', 'JJ', 'NN', ','), Frequency: 14
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', ',', 'VBD'), Frequency: 14
# Structure: ('NN', ',', 'DT', 'NN', ','), Frequency: 14
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 14
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('.', 'JJ', 'NN', 'PRP', 'VBP'), Frequency: 14
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 14
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 14
# Structure: ('DT', 'NN', 'CC', 'NN', 'IN'), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', ':', 'CC'), Frequency: 13
# Structure: (':', 'PRP', 'MD', 'RB', 'VB'), Frequency: 13
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 13
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 13
# Structure: ('NN', 'IN', 'DT', 'NN', 'CC'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', ':', 'PRP'), Frequency: 13
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('NN', ',', 'PRP', 'VBD', 'DT'), Frequency: 13
# Structure: ('IN', 'DT', 'NNS', 'IN', 'DT'), Frequency: 13
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('PRP', 'VBD', 'RB', 'VBN', 'IN'), Frequency: 13
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('NN', ',', 'NN', ',', 'NN'), Frequency: 13
# Structure: ('JJ', 'NN', ',', 'IN', 'DT'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', ',', 'DT'), Frequency: 13
# Structure: ('PRP', 'VBD', 'IN', 'PRP$', 'NN'), Frequency: 13
#
# Subset 8:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 86
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 74
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 68
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 54
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 51
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 50
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 49
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 45
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 44
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 41
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 40
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 35
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 33
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 32
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 31
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 30
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 30
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 29
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 28
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 28
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 28
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 28
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 27
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 27
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 27
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 26
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 24
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 24
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 24
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 23
# Structure: ('JJ', 'NN', ':', 'PRP', 'VBD'), Frequency: 22
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 22
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 22
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 22
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('JJ', 'NN', 'IN', 'NN', ','), Frequency: 22
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 21
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 21
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 21
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 21
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 20
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 20
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 20
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 20
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 20
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 20
# Structure: ('NN', ',', 'PRP', 'VBD', 'RB'), Frequency: 19
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 19
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 19
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 19
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 19
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 19
# Structure: ('DT', 'JJ', 'CC', 'JJ', 'NN'), Frequency: 19
# Structure: (',', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 19
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 18
# Structure: ('PRP', 'MD', 'RB', 'VB', 'VBN'), Frequency: 18
# Structure: ('NN', ',', 'CC', 'DT', 'JJ'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 18
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 17
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 17
# Structure: ('JJ', 'NN', 'NNP', 'NNP', 'NNP'), Frequency: 17
# Structure: ('PRP', 'VBD', 'JJ', 'TO', 'VB'), Frequency: 17
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 16
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 16
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 16
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 16
# Structure: ('IN', 'DT', 'JJ', 'NN', 'NN'), Frequency: 16
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 15
# Structure: ('NN', ',', 'PRP', 'VBD', 'DT'), Frequency: 15
# Structure: ('DT', 'JJ', 'NN', 'IN', 'JJ'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 15
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', 'IN', 'NN', 'CC', 'NN'), Frequency: 15
# Structure: (',', 'CC', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: (',', 'PRP', 'VBD', 'TO', 'VB'), Frequency: 15
# Structure: ('VBD', 'TO', 'VB', 'DT', 'NN'), Frequency: 15
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', 'IN', 'WDT', 'PRP', 'VBD'), Frequency: 14
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 14
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 14
# Structure: ('NN', ',', 'DT', 'NN', ','), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', ',', 'PRP'), Frequency: 14
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: (',', 'PRP', 'VBD', 'DT', 'JJ'), Frequency: 14
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 14
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'JJ'), Frequency: 14
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', 'IN', 'NNP'), Frequency: 14
# Structure: ('NN', ':', 'PRP', 'VBD', 'RB'), Frequency: 13
# Structure: ('.', 'JJ', 'NN', 'PRP', 'VBP'), Frequency: 13
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 13
# Structure: ('NN', ',', 'NN', ',', 'NN'), Frequency: 13
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 13
# Subset 9:
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 58
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 53
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 47
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 46
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 45
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 42
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 41
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 39
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 38
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 34
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 32
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 31
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 30
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 26
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 26
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 26
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 25
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 24
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 24
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 23
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 23
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 23
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 22
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 22
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 22
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 21
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 21
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 20
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 20
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 20
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 19
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 19
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 18
# ...
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 34
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 33
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 33
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 32
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 31
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 31
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 30
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 30
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 29
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 29
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 28
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 28
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 27
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 26
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 26
# Structure: ('IN', 'DT', 'NN', 'IN', 'NNP'), Frequency: 26
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 25
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 24
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 24
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 23
# Structure: ('IN', 'DT', 'NNS', 'IN', 'DT'), Frequency: 23
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 22
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('NNS', 'IN', 'DT', 'NN', ','), Frequency: 21
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 21
# Structure: ('NN', 'IN', 'WDT', 'PRP', 'VBD'), Frequency: 20
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 20
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 20
# Structure: ('NNS', 'IN', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('DT', 'NN', 'CC', 'DT', 'NN'), Frequency: 20
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 20
# Structure: ('PRP$', 'JJ', 'NN', 'IN', 'DT'), Frequency: 19
# Structure: ('NN', 'IN', 'NNP', 'NNP', 'NNP'), Frequency: 19
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 19
# Structure: ('IN', 'PRP', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 19
# Structure: ('TO', 'DT', 'NN', 'IN', 'DT'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', ',', 'DT'), Frequency: 19
# Structure: ('JJ', 'NNS', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 19
# Structure: ('VBD', 'RB', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 18
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: (',', 'CC', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 18
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'TO', 'VB'), Frequency: 17
# Structure: ('IN', 'PRP$', 'JJ', 'NN', 'IN'), Frequency: 17
# Structure: ('NN', 'IN', 'NN', 'IN', 'DT'), Frequency: 17
# Structure: ('DT', 'NN', 'IN', 'PRP', 'VBD'), Frequency: 17
# Structure: ('IN', 'PRP$', 'NN', 'IN', 'DT'), Frequency: 16
# Structure: ('NNS', 'IN', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'WDT', 'PRP'), Frequency: 16
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 16
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 16
# Structure: ('PRP', 'IN', 'DT', 'NN', '.'), Frequency: 16
# Structure: ('CC', 'DT', 'NN', 'IN', 'DT'), Frequency: 16
# Structure: ('NNS', 'IN', 'DT', 'NN', '.'), Frequency: 16
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 16
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'DT', 'NNP'), Frequency: 16
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'DT', 'NNS'), Frequency: 15
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP'), Frequency: 15
# Structure: ('NN', 'IN', 'VBG', 'DT', 'NN'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 15
# Structure: ('VBD', 'IN', 'DT', 'NN', ','), Frequency: 15
# Structure: ('IN', 'PRP', 'VBD', 'RB', 'VBN'), Frequency: 15
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 15
# Structure: (',', 'CC', 'IN', 'PRP', 'VBD'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'CC', 'DT'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 15
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 14
# Structure: ('JJ', 'IN', 'DT', 'NN', 'IN'), Frequency: 14
#
# Subset 24:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 150
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 115
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 101
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 100
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 93
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 84
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 80
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 78
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 73
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 70
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 61
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 58
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 54
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 53
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 50
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 50
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 48
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 45
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 44
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 42
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 42
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 40
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 37
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 36
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 36
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 36
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 35
# Structure: ('IN', 'DT', 'NN', 'IN', 'NNP'), Frequency: 34
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 33
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 33
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 31
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 31
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 30
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 29
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 28
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 27
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 27
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 27
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 27
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 26
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 26
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 26
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 26
# Structure: ('DT', 'NN', 'IN', 'DT', 'NNP'), Frequency: 25
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 25
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 25
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 24
# Structure: ('JJ', 'NN', ',', 'IN', 'DT'), Frequency: 23
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 23
# Structure: ('NN', 'IN', 'WDT', 'PRP', 'VBD'), Frequency: 22
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 22
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 22
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 22
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 22
# Structure: ('IN', 'PRP$', 'NN', 'IN', 'DT'), Frequency: 22
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 21
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 21
# Structure: ('IN', 'DT', 'NN', 'IN', 'VBG'), Frequency: 21
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 21
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 21
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('IN', 'PRP$', 'NN', ',', 'IN'), Frequency: 20
# Structure: ('DT', 'NN', 'IN', 'PRP', 'VBD'), Frequency: 20
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 20
# Structure: ('PRP', 'IN', 'DT', 'JJ', 'NN'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', ',', 'VBD'), Frequency: 20
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NNS'), Frequency: 19
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 19
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NNP'), Frequency: 19
# Structure: ('NN', 'IN', 'NNP', 'NNP', 'NNP'), Frequency: 19
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 19
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 19
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: (',', 'IN', 'PRP$', 'NN', ','), Frequency: 18
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 18
# Structure: ('NN', ',', 'IN', 'PRP$', 'NN'), Frequency: 18
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 18
# Structure: ('DT', 'NN', ',', 'IN', 'DT'), Frequency: 18
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: ('NN', 'NN', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 17
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 17
# Structure: ('JJ', 'NN', 'IN', 'NN', ','), Frequency: 17
# Structure: ('JJ', 'NNS', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('NN', 'IN', 'VBG', 'DT', 'NN'), Frequency: 17
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 17
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: ('VBD', 'IN', 'DT', 'NN', ','), Frequency: 16
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 16
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 16
# Structure: ('IN', 'NNP', 'NNP', 'NNP', 'VBD'), Frequency: 16
# Structure: ('VBD', 'DT', 'NN', ',', 'CC'), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 16
# Structure: ('NNS', 'IN', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'DT', 'NNS'), Frequency: 16
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 16
# Subset 25:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 149
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 106
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 103
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 92
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 90
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 68
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 65
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 65
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 65
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 63
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 62
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 62
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 61
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 61
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 58
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 58
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 46
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 45
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 42
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 42
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 40
# Structure: ('DT', 'NN', ',', 'IN', 'DT'), Frequency: 39
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 38
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 37
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 35
# Structure: (',', 'IN', 'PRP$', 'NN', ','), Frequency: 32
# Structure: ('RB', ',', 'IN', 'DT', 'NN'), Frequency: 32
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 32
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 31
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 31
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 31
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 30
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 29
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 28
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 28
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 27
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 27
# Structure: ('IN', 'DT', 'NN', ',', 'DT'), Frequency: 27
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 27
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 27
# Structure: ('JJ', 'NN', ',', 'IN', 'DT'), Frequency: 26
# Structure: ('NN', 'IN', 'DT', 'NN', 'CC'), Frequency: 26
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 26
# Structure: ('DT', 'NN', 'IN', 'PRP', 'VBD'), Frequency: 25
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 25
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 25
# Structure: ('IN', 'PRP$', 'JJ', 'NN', 'IN'), Frequency: 25
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 25
# Structure: ('NN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 25
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 24
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 24
# Structure: ('NN', 'IN', 'WDT', 'PRP', 'VBD'), Frequency: 24
# Structure: ('DT', 'NN', 'IN', 'WDT', 'PRP'), Frequency: 23
# Structure: ('IN', 'PRP$', 'NN', ',', 'IN'), Frequency: 23
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 23
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 23
# Structure: ('JJ', 'NN', 'IN', 'PRP', 'VBD'), Frequency: 23
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 22
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 21
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 21
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 21
# Structure: ('IN', 'DT', 'NN', 'IN', 'WDT'), Frequency: 21
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'JJ'), Frequency: 21
# Structure: ('IN', 'PRP', 'VBD', 'RB', 'VBN'), Frequency: 21
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP'), Frequency: 21
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 20
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 20
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('NN', 'IN', 'PRP', 'MD', 'VB'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', 'NN', ','), Frequency: 20
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 20
# Structure: ('PRP', ',', 'IN', 'DT', 'NN'), Frequency: 20
# Structure: ('NN', ',', 'PRP', 'MD', 'VB'), Frequency: 20
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 20
# Structure: ('NN', 'IN', 'PRP', 'VBD', 'RB'), Frequency: 20
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'VBP'), Frequency: 20
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 19
# Structure: ('IN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 19
# Structure: ('IN', 'PRP', 'VBD', 'IN', 'DT'), Frequency: 19
# Structure: ('PRP', 'VBD', ',', 'IN', 'DT'), Frequency: 19
# Structure: ('PRP', 'VBD', 'RB', 'TO', 'VB'), Frequency: 19
# Structure: ('.', 'NN', 'PRP', 'VBD', 'IN'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', ',', 'RB'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NNS'), Frequency: 18
# Structure: ('VBD', 'RB', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('NN', 'IN', 'DT', 'NN', 'PRP'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 18
# Structure: (',', 'IN', 'PRP', 'VBD', ','), Frequency: 18
# Structure: ('DT', 'JJ', 'JJ', 'NN', 'IN'), Frequency: 18
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', 'PRP', 'VBD'), Frequency: 18
# Structure: ('PRP', ',', 'CC', 'PRP', 'VBD'), Frequency: 18
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 18
# Structure: (',', 'CC', 'PRP', 'VBD', 'IN'), Frequency: 17
# Structure: ('DT', 'NN', 'CC', 'DT', 'NN'), Frequency: 17
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: ('DT', 'JJ', 'NN', ',', 'PRP'), Frequency: 17
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('PRP', 'VBD', 'RB', 'IN', 'DT'), Frequency: 17

# %%
# Fanu vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find sentence structures frequency using 4-grams in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    structure_frequency_5grams_subset = count_sentence_structures_5grams_subset(subset_text)
    
    # Sort the subset by frequency in descending order
    sorted_subset = sorted(structure_frequency_5grams_subset.items(), key=lambda x: x[1], reverse=True)
    
    print(f"Subset {i + 1}:")
    for structure, frequency in sorted_subset[:100]:  # Print only the first 5 structures
        print(f"Structure: {structure}, Frequency: {frequency}")
    print()  # Print an empty line to separate subsets
# Out:
# Subset 1:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 86
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 57
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 52
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 46
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 40
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 37
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 35
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 31
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 30
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 30
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 29
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 28
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 27
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 25
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 25
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 24
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 24
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 24
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 24
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 22
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 22
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 20
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 20
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 19
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 19
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 19
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 19
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 19
# Structure: ('NN', 'PRP', 'VBD', ',', 'VBG'), Frequency: 19
# Structure: ('PRP', 'IN', 'DT', 'NN', ','), Frequency: 19
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 18
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 18
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 17
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 17
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 17
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 17
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 17
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 16
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 16
# Structure: ('PRP', 'VBD', 'VBN', 'TO', 'VB'), Frequency: 16
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 16
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 15
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 15
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 15
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 15
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 15
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('DT', 'NN', ',', 'CC', 'DT'), Frequency: 14
# Structure: (',', 'CC', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 14
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 14
# Structure: ('MD', 'VB', 'DT', 'NN', 'IN'), Frequency: 13
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 13
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 13
# Structure: (',', 'CC', 'VBG', 'DT', 'NN'), Frequency: 13
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'DT', 'NNS'), Frequency: 13
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', 'TO', 'VB'), Frequency: 12
# Structure: (',', 'IN', 'PRP', 'MD', 'VB'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', 'IN', 'VBG'), Frequency: 12
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'TO'), Frequency: 12
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 12
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 12
# Structure: ('DT', 'NN', 'TO', 'VB', 'PRP'), Frequency: 12
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 12
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 12
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('PRP', 'VBD', 'TO', 'VB', 'PRP'), Frequency: 12
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('NN', ',', 'CC', 'RB', 'PRP'), Frequency: 12
# Structure: ('NN', 'TO', 'VB', 'DT', 'NN'), Frequency: 11
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 11
# Structure: ('TO', 'VB', 'PRP', ',', 'CC'), Frequency: 11
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 11
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 11
# Structure: ('VBG', 'IN', 'DT', 'NN', ','), Frequency: 11
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 11
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 11
# Structure: ('VBD', 'DT', 'NN', 'TO', 'VB'), Frequency: 11
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 11
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 11
# Structure: ('NN', 'IN', 'PRP$', 'NNS', ','), Frequency: 11
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NNS'), Frequency: 11
# Structure: ('NN', ',', 'PRP', 'VBD', 'RB'), Frequency: 11
# Structure: ('NNS', 'IN', 'DT', 'NN', ','), Frequency: 11
# Structure: ('PRP', 'VBD', ',', 'VBG', 'DT'), Frequency: 11
# Structure: (',', 'VBG', 'DT', 'NN', 'IN'), Frequency: 11
# Structure: ('TO', 'VB', 'DT', 'NN', ','), Frequency: 11
#
# Subset 2:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 54
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 33
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 31
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 31
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 29
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 26
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 25
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 24
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 23
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 21
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 21
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 19
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 18
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 18
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 17
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 17
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 17
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 16
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 16
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 15
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 15
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 15
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 15
# Structure: ('NN', 'IN', 'PRP', 'MD', 'VB'), Frequency: 14
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 14
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 14
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 13
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 13
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 13
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 13
# Structure: (',', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 12
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 12
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'TO'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 12
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 12
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 11
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 11
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 11
# Structure: ('NN', 'PRP', 'VBD', ',', 'VBG'), Frequency: 11
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 11
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 11
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 11
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'IN'), Frequency: 10
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 10
# Structure: ('VBD', 'DT', 'NN', 'TO', 'VB'), Frequency: 10
# Structure: ('DT', 'JJ', 'NN', ':', 'CC'), Frequency: 10
# Structure: ('IN', 'VBG', 'DT', 'NN', 'IN'), Frequency: 10
# Structure: ('MD', 'VB', 'DT', 'NN', 'IN'), Frequency: 10
# Structure: ('IN', 'PRP', 'MD', 'VB', 'DT'), Frequency: 10
# Structure: ('PRP', 'VBD', 'RB', 'TO', 'VB'), Frequency: 10
# Structure: ('IN', 'PRP', 'MD', 'VB', 'PRP'), Frequency: 10
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'PRP'), Frequency: 10
# Structure: (',', 'PRP', 'VBD', 'TO', 'VB'), Frequency: 10
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 10
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 10
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 9
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 9
# Structure: ('PRP', 'VBD', ',', 'RB', '.'), Frequency: 9
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 9
# Structure: (',', 'NNP', 'PRP', 'VBD', '.'), Frequency: 9
# Structure: ('PRP', 'VBP', 'PRP', 'MD', 'VB'), Frequency: 9
# Structure: ('DT', 'NN', ',', 'CC', 'VB'), Frequency: 9
# Structure: ('IN', 'DT', 'NN', 'IN', 'VBG'), Frequency: 9
# Structure: ('PRP$', 'JJ', 'NN', ',', 'CC'), Frequency: 9
# Structure: ('VB', 'DT', 'NN', 'IN', 'PRP'), Frequency: 9
# Structure: ('CC', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 9
# Structure: (',', 'CC', 'PRP', 'VBD', 'PRP'), Frequency: 9
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 9
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 9
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 9
# Structure: ('IN', 'DT', 'NN', ',', 'NNP'), Frequency: 9
# Structure: ('PRP', 'VBD', 'PRP', 'TO', 'VB'), Frequency: 9
# Structure: (',', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 9
# Structure: ('CC', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 9
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 9
# Structure: ('.', 'NN', 'VBD', 'NNP', 'NNP'), Frequency: 9
# Structure: (',', 'CC', 'PRP', 'MD', 'VB'), Frequency: 8
# Structure: (',', 'CC', 'PRP', 'VBP', 'JJ'), Frequency: 8
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 8
# Structure: ('NNP', ',', 'PRP', 'VBP', 'JJ'), Frequency: 8
# Structure: ('JJ', 'NN', ',', 'IN', 'PRP'), Frequency: 8
# Structure: ('NN', '.', 'NN', 'VBD', 'NNP'), Frequency: 8
# Structure: ('.', 'NN', 'VBD', 'NNP', ','), Frequency: 8
# Structure: ('NNP', 'NNP', '.', 'NN', 'PRP'), Frequency: 8
# Structure: ('PRP$', 'NN', ':', 'CC', 'PRP'), Frequency: 8
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 8
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 8
# Structure: ('NN', 'IN', 'VBG', 'PRP$', 'NN'), Frequency: 8
# Structure: ('VBD', 'RB', 'IN', 'DT', 'NN'), Frequency: 8
# Structure: ('NN', 'PRP', 'VBD', ',', 'IN'), Frequency: 8
# Structure: ('IN', 'PRP$', 'NN', ':', 'CC'), Frequency: 8
# Subset 3:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 52
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 39
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 38
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 30
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 30
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 30
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 30
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 29
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 27
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 27
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 26
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 26
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 25
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 24
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 23
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 22
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 22
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 22
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 21
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 21
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 19
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 19
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 19
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 18
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 18
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 18
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 17
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 16
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 16
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 15
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 15
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 15
# Structure: ('DT', 'JJ', 'NN', 'PRP', 'VBD'), Frequency: 14
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 14
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 14
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 14
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 14
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 14
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 14
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 13
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 13
# Structure: ('NN', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 13
# Structure: ('NN', 'PRP', 'VBD', ',', 'VBG'), Frequency: 13
# Structure: ('VBD', 'PRP', 'IN', 'PRP$', 'NN'), Frequency: 13
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'VBP'), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 12
# Structure: ('PRP', 'VBD', 'VBN', 'IN', 'DT'), Frequency: 12
# Structure: (',', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 12
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 12
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 12
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 11
# Structure: ('VB', 'PRP', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('VBD', 'TO', 'VB', 'DT', 'NN'), Frequency: 11
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 11
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 11
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 11
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 10
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 10
# Structure: ('CC', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 10
# Structure: ('TO', 'VB', 'PRP$', 'NN', 'IN'), Frequency: 10
# Structure: ('NN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NNS'), Frequency: 10
# Structure: ('NN', 'IN', 'PRP$', 'NNS', ','), Frequency: 10
# Structure: (',', 'CC', 'VBD', 'PRP', 'IN'), Frequency: 10
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 10
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 10
# Structure: ('DT', 'JJ', 'NN', ':', 'CC'), Frequency: 10
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 10
# Structure: ('VB', 'DT', 'NN', 'IN', 'PRP'), Frequency: 10
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 10
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 10
# Structure: ('NN', 'TO', 'VB', 'DT', 'NN'), Frequency: 10
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 9
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 9
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 9
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 9
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 9
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'JJ'), Frequency: 9
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 9
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 9
# Structure: ('IN', 'PRP$', 'NN', 'IN', 'DT'), Frequency: 9
# Structure: ('VBD', 'IN', 'DT', 'NN', ','), Frequency: 9
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP'), Frequency: 9
# Structure: ('IN', 'PRP', 'VBD', 'VBN', 'IN'), Frequency: 9
# Structure: ('NN', 'IN', 'JJ', 'NN', '.'), Frequency: 9
# Structure: ('TO', 'VB', 'PRP$', 'NN', ','), Frequency: 9
# Structure: ('PRP$', 'NN', ',', 'CC', 'VB'), Frequency: 9
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 9
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 9
#
# Subset 4:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 45
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 39
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 34
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 33
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 28
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 27
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 27
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 26
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 24
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 24
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 23
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 23
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 23
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 22
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 22
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 21
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 21
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 20
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 19
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 19
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 18
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 18
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 17
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 17
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 17
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 17
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 17
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 16
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 16
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 16
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 15
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 15
# Structure: (',', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 15
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'PRP'), Frequency: 15
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 15
# Structure: ('PRP$', 'NN', ',', 'CC', 'PRP'), Frequency: 15
# Structure: (',', 'CC', 'PRP', 'VBP', 'JJ'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 15
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 15
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 14
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('DT', 'NN', ':', 'CC', 'PRP'), Frequency: 14
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 14
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 14
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 14
# Structure: ('NN', 'PRP', 'VBD', ',', 'VBG'), Frequency: 14
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 13
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 13
# Structure: ('.', 'NN', 'VBD', 'NNP', ','), Frequency: 13
# Structure: ('JJ', 'NN', ',', 'CC', 'VBD'), Frequency: 13
# Structure: ('NN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 13
# Structure: ('NN', ':', 'CC', 'PRP', 'VBP'), Frequency: 13
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 13
# Structure: ('IN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 13
# Structure: ('NNS', 'IN', 'DT', 'NN', '.'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 12
# Structure: (',', 'IN', 'PRP', 'MD', 'VB'), Frequency: 12
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 12
# Structure: ('DT', 'NN', 'TO', 'VB', 'PRP'), Frequency: 12
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 12
# Structure: ('PRP', 'MD', 'VB', 'TO', 'VB'), Frequency: 12
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 12
# Structure: (':', 'CC', 'PRP', 'MD', 'VB'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 12
# Structure: ('PRP$', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 12
# Structure: ('VBD', 'DT', 'NN', ',', 'CC'), Frequency: 11
# Structure: (',', 'CC', 'VBD', 'TO', 'VB'), Frequency: 11
# Structure: ('DT', 'NN', ',', 'IN', 'PRP'), Frequency: 11
# Structure: ('PRP', 'VBD', 'TO', 'VB', 'PRP'), Frequency: 11
# Structure: ('CC', 'PRP', 'MD', 'VB', 'DT'), Frequency: 11
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 11
# Structure: ('NN', 'IN', 'PRP', 'MD', 'VB'), Frequency: 11
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 11
# Structure: (':', 'CC', 'PRP', 'VBD', 'RB'), Frequency: 11
# Structure: ('NN', ',', 'PRP', 'MD', 'VB'), Frequency: 11
# Structure: ('NNP', 'NNP', ',', 'PRP', 'VBP'), Frequency: 11
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 10
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 10
# Structure: ('NN', ',', 'CC', 'PRP', 'VBP'), Frequency: 10
# Structure: ('IN', 'NNP', 'NNP', 'VBD', 'NN'), Frequency: 10
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 10
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 10
# Structure: ('PRP', 'VBD', 'VBN', 'TO', 'VB'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 10
# Structure: ('PRP', ',', 'IN', 'PRP', 'VBD'), Frequency: 10
# Structure: (',', 'IN', 'PRP', 'VBD', 'RB'), Frequency: 10
# Structure: ('VBD', 'IN', 'DT', 'NN', ','), Frequency: 10
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 10
# Structure: (',', 'CC', 'PRP', 'MD', 'VB'), Frequency: 10
# Structure: (',', 'NNP', 'VBD', 'NNP', ','), Frequency: 10
# Structure: ('NN', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 10
# Structure: (':', 'CC', 'PRP', 'VBP', 'JJ'), Frequency: 10
# Subset 5:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 36
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 34
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 30
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'NN'), Frequency: 26
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 26
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 25
# Structure: ('NN', '.', 'NN', 'PRP', 'VBD'), Frequency: 25
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 22
# Structure: ('RB', ',', 'IN', 'PRP', 'VBD'), Frequency: 20
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 20
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 19
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 19
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 19
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 18
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 18
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 18
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 17
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 17
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 17
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 17
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 17
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 16
# Structure: ('.', 'NN', 'PRP', 'VBD', ','), Frequency: 16
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: (',', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 15
# Structure: (':', 'CC', 'PRP', 'MD', 'VB'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 15
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 14
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 14
# Structure: (',', 'VBZ', 'PRP', 'VBD', ','), Frequency: 14
# Structure: ('JJ', 'NN', ':', 'CC', 'PRP'), Frequency: 14
# Structure: ('PRP$', 'NN', ',', 'CC', 'PRP'), Frequency: 14
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 14
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 14
# Structure: ('NN', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 13
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'PRP'), Frequency: 13
# Structure: (',', 'IN', 'PRP', 'MD', 'VB'), Frequency: 13
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 13
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 13
# Structure: ('NN', ',', 'CC', 'PRP', 'VBP'), Frequency: 13
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 13
# Structure: (',', 'CC', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 13
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 13
# Structure: (',', 'CC', 'PRP', 'VBP', 'JJ'), Frequency: 12
# Structure: ('NN', ',', 'CC', 'VBD', 'PRP'), Frequency: 12
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 12
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'IN'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 12
# Structure: (',', 'CC', 'PRP', 'VBD', 'RB'), Frequency: 11
# Structure: ('CC', 'PRP', 'VBP', 'JJ', 'NN'), Frequency: 11
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 11
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('DT', 'NN', ':', 'CC', 'PRP'), Frequency: 11
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 11
# Structure: ('PRP', 'VBD', 'PRP$', 'NN', 'IN'), Frequency: 11
# Structure: ('CC', 'PRP', 'MD', 'RB', 'VB'), Frequency: 11
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 11
# Structure: (':', 'CC', 'PRP', 'VBD', 'PRP'), Frequency: 11
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 10
# Structure: ('PRP', 'MD', 'VB', 'DT', 'JJ'), Frequency: 10
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 10
# Structure: ('NN', ',', 'IN', 'PRP', 'MD'), Frequency: 10
# Structure: ('VBD', 'DT', 'NN', ',', 'CC'), Frequency: 10
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 10
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 10
# Structure: ('NN', ',', 'PRP', 'VBD', 'PRP'), Frequency: 10
# Structure: ('PRP', 'VBD', 'PRP', 'IN', 'DT'), Frequency: 10
# Structure: ('PRP', 'VBD', 'TO', 'VB', 'PRP'), Frequency: 10
# Structure: (',', 'IN', 'PRP', 'VBD', 'RB'), Frequency: 10
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 10
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 10
# Structure: ('VBG', 'DT', 'JJ', 'NN', 'IN'), Frequency: 10
# Structure: ('PRP', 'VBP', 'JJ', 'NN', 'VBP'), Frequency: 10
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 10
# Structure: ('PRP', 'VBD', 'PRP', 'TO', 'VB'), Frequency: 10
# Structure: ('PRP', 'MD', 'VB', 'TO', 'VB'), Frequency: 10
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 10
# Structure: ('VB', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 10
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'TO'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 10
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 9
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 9
# Structure: ('IN', 'DT', 'NN', ',', 'RB'), Frequency: 9
# Structure: ('PRP', 'VBD', 'PRP$', 'JJ', 'NN'), Frequency: 9
# Structure: ('DT', 'JJ', 'NN', 'PRP', 'VBD'), Frequency: 9
# Structure: ('PRP', 'IN', 'DT', 'NN', ','), Frequency: 9
# Structure: ('MD', 'VB', 'DT', 'JJ', 'NN'), Frequency: 9
#
# Subset 6:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 55
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 38
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 37
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 37
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 33
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 31
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 29
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 29
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 28
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 28
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 27
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 26
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 24
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 22
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 21
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 21
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 21
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 20
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 20
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 20
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 19
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 18
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 18
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 17
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 17
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 16
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 15
# Structure: ('NN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 15
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 15
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 14
# Structure: ('DT', 'JJ', ',', 'JJ', 'NN'), Frequency: 14
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 14
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 13
# Structure: ('PRP$', 'NN', ',', 'PRP', 'VBD'), Frequency: 13
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 13
# Structure: ('PRP', 'VBD', 'IN', 'PRP$', 'NN'), Frequency: 13
# Structure: ('PRP$', 'NN', ':', 'PRP', 'VBD'), Frequency: 13
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 13
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 12
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 12
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', ':', 'PRP'), Frequency: 12
# Structure: ('NN', ',', 'PRP', 'VBD', 'PRP'), Frequency: 12
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 12
# Structure: ('PRP', 'IN', 'DT', 'NN', ','), Frequency: 12
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 12
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', ',', 'VBD'), Frequency: 12
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 11
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 11
# Structure: ('IN', 'PRP$', 'NN', ',', 'PRP'), Frequency: 11
# Structure: ('NN', 'IN', 'NN', 'IN', 'DT'), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 11
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 11
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 11
# Structure: ('VBD', 'TO', 'VB', 'DT', 'NN'), Frequency: 11
# Structure: ('VBD', 'DT', 'JJ', 'NN', '.'), Frequency: 11
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 11
# Structure: ('DT', 'JJ', 'CC', 'JJ', 'NN'), Frequency: 11
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 10
# Structure: ('NN', ':', 'CC', 'PRP', 'VBD'), Frequency: 10
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 10
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 10
# Structure: ('NN', 'NN', 'IN', 'DT', 'NN'), Frequency: 10
# Structure: ('NN', ',', 'PRP', 'VBD', 'DT'), Frequency: 10
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 10
# Structure: ('DT', 'JJ', 'NN', ',', 'DT'), Frequency: 10
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 10
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 10
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 10
# Structure: (',', 'CC', 'VBD', 'IN', 'DT'), Frequency: 9
# Structure: ('PRP', 'VBD', 'DT', 'NN', '.'), Frequency: 9
# Structure: ('.', 'NN', 'PRP', 'VBD', '.'), Frequency: 9
# Structure: ('DT', 'JJ', 'JJ', 'NN', ','), Frequency: 9
# Structure: (',', 'IN', 'PRP', 'VBD', 'DT'), Frequency: 9
# Structure: ('VBD', 'DT', 'NN', ',', 'CC'), Frequency: 9
# Structure: ('PRP', 'IN', 'DT', 'JJ', 'NN'), Frequency: 9
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 9
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 9
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 9
# Structure: (',', 'DT', 'NN', 'IN', 'NN'), Frequency: 9
# Structure: ('VB', 'PRP', 'IN', 'DT', 'NN'), Frequency: 9
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 9
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 9
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 9
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 9
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 9
# Structure: ('VBD', 'IN', 'PRP$', 'NN', '.'), Frequency: 9
# Structure: ('RB', 'IN', 'DT', 'NN', ','), Frequency: 9
# Structure: (',', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 9
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 9
# Structure: ('PRP$', 'NN', ',', 'CC', 'VBD'), Frequency: 9
# Subset 7:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 77
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 57
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 55
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 52
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 46
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 46
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 45
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 44
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 43
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 39
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 37
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 31
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 29
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 26
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 25
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 23
# Structure: ('JJ', 'NN', ',', 'PRP', 'VBD'), Frequency: 23
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 23
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 23
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 23
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 22
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 22
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 21
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 21
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 21
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 21
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 21
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 21
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 20
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 20
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 20
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 20
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 20
# Structure: ('VBD', 'DT', 'JJ', 'NN', ','), Frequency: 18
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 18
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 18
# Structure: ('NN', 'IN', 'NN', 'CC', 'NN'), Frequency: 18
# Structure: ('NN', ',', 'NN', ',', 'CC'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', ',', 'DT'), Frequency: 17
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 17
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('DT', 'JJ', 'NN', ',', 'PRP'), Frequency: 16
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 16
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 16
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'NN', ':'), Frequency: 15
# Structure: (',', 'NN', ',', 'CC', 'NN'), Frequency: 15
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'JJ'), Frequency: 14
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 14
# Structure: ('NN', ',', 'PRP', 'VBD', 'RB'), Frequency: 14
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 14
# Structure: ('IN', 'DT', 'JJ', 'NN', 'CC'), Frequency: 14
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('VBD', 'DT', 'NN', 'IN', 'NN'), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 14
# Structure: (',', 'CC', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 14
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 14
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 13
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 13
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 13
# Structure: ('IN', 'NN', ',', 'PRP', 'VBD'), Frequency: 13
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 13
# Structure: ('NN', ',', 'CC', 'NN', ','), Frequency: 13
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 13
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 13
# Structure: ('NNS', 'IN', 'DT', 'JJ', 'NN'), Frequency: 13
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 12
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('DT', 'JJ', 'CC', 'JJ', 'NN'), Frequency: 12
# Structure: (',', 'CC', 'VBD', 'DT', 'NN'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 12
# Structure: ('PRP', 'IN', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('NN', ',', 'PRP', 'VBD', 'PRP'), Frequency: 12
# Structure: ('IN', 'DT', 'JJ', 'NN', 'NN'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', ',', 'VBG'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'NN', 'CC'), Frequency: 12
# Structure: ('NN', 'IN', 'PRP$', 'NNS', ','), Frequency: 11
# Structure: ('PRP', 'VBD', 'IN', 'PRP', 'VBD'), Frequency: 11
# Structure: (',', 'PRP', 'MD', 'RB', 'VB'), Frequency: 11
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 11
# Structure: ('NN', 'IN', 'JJ', 'NN', ','), Frequency: 11
# Structure: ('PRP$', 'NN', ':', 'PRP', 'VBD'), Frequency: 11
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 11
# Structure: ('VB', 'DT', 'NN', 'IN', 'NN'), Frequency: 11
# Structure: ('NN', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 11
# Structure: ('DT', 'JJ', ',', 'JJ', 'NN'), Frequency: 11
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 11
#
# Subset 8:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 58
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 49
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 37
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 37
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 36
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 35
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 32
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 32
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 30
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 26
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 25
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 25
# Structure: ('DT', 'NN', ',', 'DT', 'NN'), Frequency: 25
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 24
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 23
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 23
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 23
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 23
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: (',', 'CC', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('CC', 'DT', 'JJ', 'NN', 'IN'), Frequency: 16
# Structure: ('IN', 'DT', 'JJ', 'NN', 'NN'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 15
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 15
# Structure: ('NN', ',', 'CC', 'DT', 'JJ'), Frequency: 15
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 15
# Structure: ('NN', ',', 'DT', 'NN', ','), Frequency: 15
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 14
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 14
# Structure: ('DT', 'NN', ',', 'PRP', 'VBD'), Frequency: 14
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 14
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 13
# Structure: ('NN', 'IN', 'NNP', 'NNP', 'NNP'), Frequency: 13
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 13
# Structure: ('IN', 'NN', ',', 'PRP', 'VBD'), Frequency: 13
# Structure: ('NN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 13
# Structure: ('IN', 'DT', 'JJ', 'NN', ':'), Frequency: 13
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 13
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', ',', 'DT'), Frequency: 13
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 13
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('JJ', 'NN', ',', 'DT', 'NN'), Frequency: 12
# Structure: ('IN', 'NN', 'CC', 'NN', ','), Frequency: 12
# Structure: ('DT', 'NN', ':', 'PRP', 'VBD'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 12
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 11
# Structure: ('DT', 'NN', 'NN', 'IN', 'DT'), Frequency: 11
# Structure: ('NN', 'NN', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 11
# Structure: (',', 'PRP', 'VBD', 'TO', 'VB'), Frequency: 11
# Structure: ('DT', 'JJ', 'NN', ',', 'DT'), Frequency: 11
# Structure: ('NN', ',', 'DT', 'JJ', 'NN'), Frequency: 11
# Structure: ('NN', 'IN', 'JJ', 'NN', ','), Frequency: 11
# Structure: ('DT', 'NN', ',', 'CC', 'DT'), Frequency: 11
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 11
# Structure: ('NN', ',', 'PRP', 'VBD', 'RB'), Frequency: 11
# Structure: (',', 'CC', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('NNP', '.', 'NN', 'PRP', 'VBD'), Frequency: 11
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 11
# Structure: ('NN', ',', 'NN', 'VBD', 'PRP'), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 10
# Structure: (':', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'NN', ':'), Frequency: 10
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 10
# Structure: ('DT', 'JJ', 'NN', 'IN', 'JJ'), Frequency: 10
# Structure: ('NN', 'VBD', 'DT', 'NN', 'IN'), Frequency: 10
# Structure: ('JJ', ',', 'JJ', ',', 'JJ'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'NN', '.'), Frequency: 10
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 10
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 10
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 10
# Structure: (',', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 10
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 10
# Structure: ('RB', ',', 'IN', 'DT', 'NN'), Frequency: 10
# Structure: ('IN', 'DT', 'NN', ':', 'PRP'), Frequency: 10
# Structure: ('NN', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 9
# Structure: ('PRP', 'VBD', 'VBN', 'IN', 'DT'), Frequency: 9
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 9
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 9
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 9
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 9
# Structure: ('NN', ':', 'PRP', 'VBD', 'DT'), Frequency: 9
# Structure: ('NN', 'IN', 'PRP$', 'NN', ':'), Frequency: 9
# Structure: (',', 'CC', 'DT', 'NN', 'IN'), Frequency: 9
# Structure: ('PRP', 'VBD', 'VBN', 'TO', 'VB'), Frequency: 9
# Structure: ('NN', ',', 'PRP', 'VBD', 'TO'), Frequency: 9
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 9
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 9
# Structure: ('VBD', 'DT', 'NN', ',', 'DT'), Frequency: 9
# Structure: ('PRP', 'VBD', 'DT', 'NN', ','), Frequency: 9
# Subset 9:
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 58
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 55
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 45
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 35
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 35
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 35
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 35
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 32
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 32
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 31
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 31
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 29
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 27
# Structure: ('DT', 'NN', 'IN', 'NN', 'IN'), Frequency: 24
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 24
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 22
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 22
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 21
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 21
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 21
# Structure: ('NN', ',', 'DT', 'NN', 'IN'), Frequency: 21
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 20
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 19
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 19
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 16
# Structure: (':', 'PRP', 'MD', 'RB', 'VB'), Frequency: 16
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 16
# ...
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 32
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 31
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 30
# Structure: ('NN', ',', 'PRP', 'MD', 'VB'), Frequency: 30
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 30
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 29
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 27
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 27
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 26
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 26
# Structure: ('IN', 'DT', 'NN', ',', 'PRP'), Frequency: 26
# Structure: ('IN', 'DT', 'NNS', 'IN', 'DT'), Frequency: 25
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 25
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 25
# Structure: ('IN', 'DT', 'NN', ':', 'CC'), Frequency: 25
# Structure: ('DT', 'NN', ',', 'IN', 'PRP'), Frequency: 25
# Structure: (',', 'CC', 'DT', 'JJ', 'NN'), Frequency: 24
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 24
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 24
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 23
# Structure: (',', 'PRP', 'MD', 'VB', 'PRP'), Frequency: 23
# Structure: ('DT', 'NN', ',', 'IN', 'DT'), Frequency: 23
# Structure: (',', "''", 'VBD', 'NNP', 'NNP'), Frequency: 22
# Structure: ('IN', 'DT', 'NN', '.', "''"), Frequency: 22
# Structure: ('JJ', 'NNS', 'IN', 'DT', 'NN'), Frequency: 22
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 21
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 21
# Structure: ('NNS', 'IN', 'DT', 'NN', ','), Frequency: 21
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 21
# Structure: ('IN', 'PRP', 'MD', 'RB', 'VB'), Frequency: 21
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 21
# Structure: ('IN', 'PRP', 'VBD', 'DT', 'NN'), Frequency: 21
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 21
# Structure: ("''", 'VBD', 'DT', 'NN', ','), Frequency: 20
# Structure: ('VBD', 'DT', 'NN', ',', '``'), Frequency: 20
# Structure: ('DT', 'NN', ',', 'CC', 'PRP'), Frequency: 20
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 20
# Structure: ('VBN', 'IN', 'DT', 'NN', ','), Frequency: 20
# Structure: ('NN', 'IN', 'DT', 'NN', ':'), Frequency: 19
# Structure: ('DT', 'JJ', 'NN', ':', 'CC'), Frequency: 19
# Structure: ('RB', ',', 'IN', 'DT', 'NN'), Frequency: 19
# Structure: ('NNS', 'IN', 'DT', 'NN', 'IN'), Frequency: 19
# Structure: ('NN', 'IN', 'DT', 'NNP', 'NNP'), Frequency: 19
# Structure: ('VB', 'DT', 'NN', 'IN', 'DT'), Frequency: 18
# Structure: (',', 'IN', 'PRP', 'MD', 'VB'), Frequency: 18
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 18
# Structure: (',', 'CC', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 18
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 18
# Structure: ('DT', 'JJ', 'NNS', 'IN', 'DT'), Frequency: 18
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'CC', 'DT'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', 'IN', 'DT', 'NNP'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'MD', 'VB'), Frequency: 18
# Structure: ('PRP', 'MD', 'RB', 'VB', 'PRP'), Frequency: 17
# Structure: (',', 'IN', 'PRP', 'VBP', 'RB'), Frequency: 17
# Structure: ('RB', 'IN', 'DT', 'JJ', 'NN'), Frequency: 17
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 17
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', 'VBD', 'RB'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', 'PRP', 'VBD'), Frequency: 17
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('IN', 'PRP$', 'NN', ',', 'IN'), Frequency: 17
# Structure: ('DT', 'NN', 'MD', 'VB', 'VBN'), Frequency: 17
# Structure: ('DT', 'NNP', 'NNP', 'NNP', 'NNP'), Frequency: 17
# Structure: ('MD', 'VB', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('IN', 'PRP', 'MD', 'VB', 'DT'), Frequency: 16
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 16
# Structure: ('DT', 'NN', ',', 'CC', 'RB'), Frequency: 16
# Structure: ('VB', 'PRP', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('CC', 'DT', 'JJ', 'NN', 'IN'), Frequency: 16
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 16
#
# Subset 24:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 104
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 83
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 70
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 54
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 52
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 50
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 45
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 44
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 38
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 38
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 38
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 32
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 32
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 32
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 31
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 29
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 29
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 28
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 25
# Structure: ('VBN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 25
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 23
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 22
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 22
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 20
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 20
# Structure: ('IN', 'DT', 'JJ', 'JJ', 'NN'), Frequency: 20
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 19
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 19
# Structure: ('IN', 'DT', 'JJ', 'NN', 'NN'), Frequency: 18
# Structure: ('IN', 'DT', 'JJ', 'NNS', 'IN'), Frequency: 18
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 18
# Structure: (',', 'NNP', 'VBD', 'NNP', 'NNP'), Frequency: 18
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 18
# Structure: ('PRP', 'IN', 'DT', 'NN', 'IN'), Frequency: 16
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 15
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('PRP', 'IN', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 15
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 15
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 15
# Structure: ('IN', 'PRP$', 'JJ', 'NN', '.'), Frequency: 15
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 15
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 14
# Structure: ('NN', ',', 'NNP', 'NNP', ','), Frequency: 14
# Structure: ('IN', 'DT', 'NN', 'IN', 'JJ'), Frequency: 14
# Structure: ('IN', 'PRP$', 'NN', ',', 'IN'), Frequency: 14
# Structure: ('JJ', 'NN', ',', 'IN', 'DT'), Frequency: 14
# Structure: ('NN', ',', 'IN', 'PRP', 'VBD'), Frequency: 14
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('DT', 'JJ', 'JJ', 'NN', 'IN'), Frequency: 14
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 14
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 14
# Structure: ('NN', ',', 'IN', 'PRP$', 'NN'), Frequency: 13
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', 'IN', 'NNP'), Frequency: 13
# Structure: (',', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 13
# Structure: ('NNP', 'VBD', 'NNP', 'NNP', ','), Frequency: 13
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'JJ'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', ',', 'VBD'), Frequency: 13
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 13
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 13
# Structure: ('TO', 'DT', 'NN', 'IN', 'DT'), Frequency: 13
# Structure: ('DT', 'NN', ',', 'IN', 'DT'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'JJ', 'NN'), Frequency: 12
# Structure: ('NNP', 'NNP', 'NNP', 'NN', 'NN'), Frequency: 12
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 12
# Structure: ('IN', 'NN', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('PRP', 'VBP', 'DT', 'NN', 'IN'), Frequency: 12
# Structure: ('DT', 'NN', 'VBD', 'VBN', 'IN'), Frequency: 12
# Structure: ('JJ', 'NNS', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('VBD', 'IN', 'DT', 'JJ', 'NN'), Frequency: 12
# Structure: ('VBD', 'PRP', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('IN', 'PRP', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('IN', 'PRP$', 'JJ', 'NN', 'IN'), Frequency: 12
# Structure: ('NN', 'IN', 'NNP', 'NNP', 'NNP'), Frequency: 12
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 12
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 12
# Structure: ('IN', 'DT', 'NN', ',', 'NNP'), Frequency: 11
# Structure: (',', 'IN', 'PRP$', 'NN', ','), Frequency: 11
# Structure: ('VBD', 'IN', 'DT', 'NN', ','), Frequency: 11
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'PRP', 'VBD'), Frequency: 11
# Structure: (',', 'NNP', 'NNP', ',', 'IN'), Frequency: 11
# Structure: ('PRP', 'MD', 'VB', 'DT', 'NN'), Frequency: 11
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 11
# Structure: ('DT', 'JJ', 'JJ', 'NN', ','), Frequency: 11
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 11
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 11
# Structure: (',', 'NNP', 'NNP', ',', 'NNP'), Frequency: 11
# Structure: ('IN', 'NNP', 'NNP', 'NNP', 'VBD'), Frequency: 11
# Structure: ('DT', 'NN', ',', 'NNP', 'NNP'), Frequency: 10
# Structure: ('DT', 'NN', 'IN', 'PRP', ','), Frequency: 10
# Structure: ('RB', 'RB', 'IN', 'PRP', 'VBD'), Frequency: 10
# Structure: ('JJ', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 10
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 10
# Structure: ('NNP', 'NNP', 'NNP', 'VBD', 'JJ'), Frequency: 10
# Structure: ('NNS', 'IN', 'DT', 'NN', ','), Frequency: 10
# Structure: ('NN', 'IN', 'NN', 'CC', 'NN'), Frequency: 10
# Subset 25:
# Structure: ('DT', 'NN', 'IN', 'DT', 'NN'), Frequency: 72
# Structure: ('DT', 'JJ', 'NN', 'IN', 'DT'), Frequency: 51
# Structure: ('IN', 'DT', 'JJ', 'NN', 'IN'), Frequency: 50
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 50
# Structure: ('JJ', 'NN', 'IN', 'DT', 'NN'), Frequency: 49
# Structure: ('IN', 'DT', 'NN', 'IN', 'DT'), Frequency: 39
# Structure: ('NN', 'IN', 'DT', 'NN', ','), Frequency: 37
# Structure: ('IN', 'DT', 'JJ', 'NN', ','), Frequency: 35
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 33
# Structure: ('NN', 'IN', 'DT', 'NN', 'IN'), Frequency: 33
# Structure: ('NN', 'IN', 'DT', 'JJ', 'NN'), Frequency: 32
# Structure: ('IN', 'DT', 'NN', ',', 'CC'), Frequency: 30
# Structure: ('NN', 'IN', 'DT', 'NN', '.'), Frequency: 27
# Structure: (',', 'IN', 'DT', 'JJ', 'NN'), Frequency: 26
# Structure: ('DT', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 24
# Structure: ('PRP', 'VBD', 'DT', 'NN', 'IN'), Frequency: 23
# Structure: ('NN', 'IN', 'NNP', 'NNP', 'NNP'), Frequency: 23
# Structure: ('NN', 'IN', 'PRP$', 'NN', ','), Frequency: 23
# Structure: (',', 'IN', 'DT', 'NN', 'IN'), Frequency: 22
# Structure: ('DT', 'JJ', 'NN', ',', 'IN'), Frequency: 20
# Structure: ('DT', 'NN', 'IN', 'DT', 'JJ'), Frequency: 19
# Structure: ('JJ', 'NN', 'IN', 'PRP$', 'NN'), Frequency: 18
# Structure: ('DT', 'NN', ',', 'CC', 'VBD'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', ',', 'CC'), Frequency: 18
# Structure: ('NN', 'IN', 'PRP$', 'NN', '.'), Frequency: 18
# Structure: ('IN', 'DT', 'NN', 'IN', 'NN'), Frequency: 18
# Structure: ('DT', 'JJ', 'NN', 'IN', 'NN'), Frequency: 18
# Structure: ('NN', 'IN', 'PRP$', 'JJ', 'NN'), Frequency: 17
# Structure: ('VBD', 'DT', 'JJ', 'NN', 'IN'), Frequency: 17
# Structure: ('RB', 'IN', 'DT', 'NN', 'IN'), Frequency: 17
# Structure: ('IN', 'DT', 'NN', ',', 'IN'), Frequency: 17
# Structure: ('IN', 'NNP', 'NNP', 'NNP', 'VBD'), Frequency: 17
# Structure: ('PRP$', 'NN', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('IN', 'PRP', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('PRP', 'VBD', 'IN', 'DT', 'NN'), Frequency: 16
# Structure: ('PRP', 'IN', 'DT', 'JJ', 'NN'), Frequency: 16
# Structure: ('IN', 'DT', 'JJ', 'NN', '.'), Frequency: 16
# Structure: ('JJ', 'NN', ',', 'IN', 'DT'), Frequency: 15
# Structure: ('NN', ',', 'IN', 'DT', 'NN'), Frequency: 15
# Structure: ('NN', 'IN', 'DT', 'NN', 'VBD'), Frequency: 15
# Structure: ('TO', 'VB', 'DT', 'NN', 'IN'), Frequency: 15
# Structure: ('PRP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 15
# Structure: (',', 'NNP', 'PRP', 'VBD', ','), Frequency: 15
# Structure: ('VBD', 'VBN', 'IN', 'DT', 'NN'), Frequency: 14
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP$'), Frequency: 14
# Structure: ('IN', 'NNP', 'NNP', 'NNP', 'NN'), Frequency: 14
# Structure: ('PRP', 'IN', 'DT', 'NN', '.'), Frequency: 14
# Structure: ('JJ', 'NN', 'IN', 'DT', 'JJ'), Frequency: 14
# Structure: ('VBD', 'DT', 'NN', 'IN', 'DT'), Frequency: 14
# Structure: ('NNP', ',', 'NNP', 'PRP', 'VBD'), Frequency: 14
# Structure: ('NN', ',', 'CC', 'PRP', 'VBD'), Frequency: 14
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'NN'), Frequency: 13
# Structure: ('VBN', 'IN', 'DT', 'NN', 'IN'), Frequency: 13
# Structure: ('NNP', 'NNP', 'NNP', 'NN', 'NN'), Frequency: 13
# Structure: ('DT', 'NN', 'CC', 'DT', 'NN'), Frequency: 13
# Structure: ('NN', ',', 'IN', 'DT', 'JJ'), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'WDT', 'PRP'), Frequency: 13
# Structure: ('NN', 'IN', 'WDT', 'PRP', 'VBD'), Frequency: 13
# Structure: ('VBD', 'RB', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: ('NNP', 'NNP', 'NNP', 'JJ', 'NN'), Frequency: 13
# Structure: ('TO', 'VB', 'IN', 'DT', 'NN'), Frequency: 13
# Structure: (',', 'CC', 'PRP', 'MD', 'VB'), Frequency: 13
# Structure: ('NN', ',', 'NN', 'PRP', 'VBD'), Frequency: 13
# Structure: ('IN', 'PRP$', 'NN', ',', 'CC'), Frequency: 13
# Structure: ('IN', 'DT', 'NN', 'IN', 'NNP'), Frequency: 13
# Structure: ('DT', 'NN', 'IN', 'NN', ','), Frequency: 12
# Structure: ('DT', 'NNS', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('NN', 'IN', 'DT', 'NN', 'NN'), Frequency: 12
# Structure: (',', 'IN', 'DT', 'NN', ','), Frequency: 12
# Structure: ('NN', 'IN', 'NN', ',', 'CC'), Frequency: 12
# Structure: ('DT', 'JJ', 'NN', 'IN', 'PRP'), Frequency: 12
# Structure: ('NN', 'IN', 'PRP', 'MD', 'VB'), Frequency: 12
# Structure: ('RB', ',', 'IN', 'DT', 'NN'), Frequency: 12
# Structure: ('DT', 'NN', 'IN', 'PRP$', 'JJ'), Frequency: 12
# Structure: ('IN', 'DT', 'NN', 'TO', 'VB'), Frequency: 12
# Structure: ('IN', 'PRP$', 'JJ', 'NN', ','), Frequency: 12
# Structure: ('NN', ',', 'NNP', 'NNP', ','), Frequency: 12
# Structure: ('TO', 'VB', 'DT', 'JJ', 'NN'), Frequency: 11
# Structure: ('IN', 'DT', 'NN', 'IN', 'PRP'), Frequency: 11
# Structure: ('NN', ',', 'CC', 'DT', 'NN'), Frequency: 11
# Structure: ('NN', 'VBD', 'IN', 'DT', 'NN'), Frequency: 11
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'IN'), Frequency: 11
# Structure: ('RB', 'IN', 'DT', 'NN', '.'), Frequency: 11
# Structure: ('PRP', 'MD', 'VB', 'PRP', 'IN'), Frequency: 11
# Structure: (',', 'CC', 'PRP', 'VBD', 'PRP'), Frequency: 11
# Structure: ('JJ', 'NN', 'IN', 'NNP', 'NNP'), Frequency: 11
# Structure: ('NN', 'IN', 'NNP', 'NNP', '.'), Frequency: 11
# Structure: ('NN', 'IN', 'PRP$', 'NN', 'CC'), Frequency: 11
# Structure: ('DT', 'NN', 'IN', 'PRP', 'VBD'), Frequency: 10
# Structure: ('VBD', 'IN', 'DT', 'NN', 'IN'), Frequency: 10
# Structure: ('IN', 'PRP$', 'NN', 'IN', 'DT'), Frequency: 10
# Structure: ('NNP', 'VBD', 'DT', 'JJ', 'NN'), Frequency: 10
# Structure: ('NNP', 'NNP', 'NNP', 'VBD', 'NN'), Frequency: 10
# Structure: ('NN', ',', 'NNP', 'PRP', 'VBD'), Frequency: 10
# Structure: ('IN', 'DT', 'NN', 'WDT', 'PRP'), Frequency: 10
# Structure: ('JJ', 'NN', ',', 'CC', 'PRP'), Frequency: 10
# Structure: ('VBD', 'DT', 'NN', 'IN', 'PRP$'), Frequency: 10
# Structure: (',', 'NNP', 'VBD', 'NNP', 'NNP'), Frequency: 10
# Structure: ('NNP', 'NNP', 'NNP', 'VBD', 'JJ'), Frequency: 10
# Structure: ('VB', 'DT', 'JJ', 'NN', 'IN'), Frequency: 9

# %% [markdown]
# # Hapax legomenon & it's POS

# %%
# Stemming function
def stem_text(text):
    stemmer = PorterStemmer()
    tokens = word_tokenize(text)
    stemmed_text = ' '.join([stemmer.stem(token) for token in tokens])
    return stemmed_text

# %% [markdown]
# # Allan Poe

# %%
from collections import Counter
from nltk.tokenize import word_tokenize

import pandas as pd

stemmed_text_Poe = stem_text(preprocessed_text_Poe)

# Tokenize the corpus into words
words_Poe = word_tokenize(stemmed_text_Poe)

# Count the frequency of each word
word_frequency_Poe = Counter(words_Poe)

# Identify Hapax legomena (words that occur only once)
hapax_legomena_Poe = [word for word, freq in word_frequency_Poe.items() if freq == 1]

# Initialize a dictionary to store the frequency of each general POS tag among Hapax legomena
pos_tag_frequency_Poe = {}

# Process each Hapax legomenon
for word in hapax_legomena_Poe:
    # Find the index of the first occurrence of the Hapax legomenon
    index_Poe = words_Poe.index(word)
    # Determine the POS tagging of the Hapax legomenon at its specific occurrence
    pos_tag_Poe = nltk.pos_tag([word])[0][1]
    # Generalize the POS tag to its main category
    general_pos_tag_Poe = pos_tag_Poe[:2]  # Take only the first two characters
    # Increment the frequency count for this general POS tag
    pos_tag_frequency_Poe[general_pos_tag_Poe] = pos_tag_frequency_Poe.get(general_pos_tag_Poe, 0) + 1

# Create a DataFrame from the pos_tag_frequency dictionary
Poe_Hapax = pd.DataFrame(list(pos_tag_frequency_Poe.items()), columns=['POS Tag', 'Frequency'])

# Calculate the total number of Hapax legomena
total_hapax_legomena_Poe = len(hapax_legomena_Poe)

# Calculate the relative frequency for each general POS tag among Hapax legomena
Poe_Hapax['Relative Frequency'] = Poe_Hapax['Frequency'] / total_hapax_legomena_Poe

# %%
Poe_Hapax.sort_values(by='Relative Frequency', ascending=False)
# Out:
#   POS Tag  Frequency  Relative Frequency
# 0      NN       3110            0.941568
# 1      JJ        116            0.035120
# 3      CD         50            0.015138
# 2      VB         15            0.004541
# 5      RB         10            0.003028
# 4      PR          1            0.000303
# 6      MD          1            0.000303

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import nltk
import re
import pandas as pd
from collections import Counter

# Define stemming function
def stem_text(text):
    stemmer = PorterStemmer()
    tokens = word_tokenize(text)
    stemmed_text = ' '.join([stemmer.stem(token) for token in tokens])
    return stemmed_text

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences

# Function to calculate hapax legomena and POS tag frequencies for a subset
def hapax_legomena_and_pos_tags(subset_text):
    # Stem the subset text
    stemmed_subset = stem_text(subset_text)
    
    # Tokenize the subset into words
    words = word_tokenize(stemmed_subset)
    
    # Count the frequency of each word
    word_frequency = Counter(words)
    
    # Identify hapax legomena (words that occur only once)
    hapax_legomena = [word for word, freq in word_frequency.items() if freq == 1]
    
    # Initialize a dictionary to store the frequency of each general POS tag among hapax legomena
    pos_tag_frequency = {}
    
    # Process each hapax legomenon
    for word in hapax_legomena:
        # Determine the POS tagging of the hapax legomenon
        pos_tag = nltk.pos_tag([word])[0][1]
        
        # Generalize the POS tag to its main category
        general_pos_tag = pos_tag[:2]  # Take only the first two characters
        
        # Increment the frequency count for this general POS tag
        pos_tag_frequency[general_pos_tag] = pos_tag_frequency.get(general_pos_tag, 0) + 1
    
    return pos_tag_frequency

# Read the Poe corpus text from file
file_path_Poe = 'Allan Poe - Full Corpus.txt'
with open(file_path_Poe, 'r') as file:
    text_Poe = file.read()

# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5
print(subset_size)

# Find hapax legomena and POS tag frequencies in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pos_tag_frequency_subset = hapax_legomena_and_pos_tags(subset_text)
    print(f"Hapax Legomena and POS Tag Frequencies in Subset {i + 1}:")
    print(pos_tag_frequency_subset)
# Out:
# 1568
# Hapax Legomena and POS Tag Frequencies in Subset 1:
# {'NN': 1772, 'JJ': 57, 'VB': 19, 'RB': 13, 'IN': 7, 'CD': 27, 'DT': 1, ':': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 2:
# {'NN': 2394, 'IN': 11, 'JJ': 89, 'VB': 15, 'RB': 18, 'CD': 2, 'PR': 1, 'WD': 1, 'DT': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 3:
# {'NN': 2256, 'JJ': 84, 'RB': 20, 'CD': 11, 'VB': 16, 'IN': 2, 'CC': 1, 'MD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 4:
# {'NN': 1476, 'JJ': 64, 'VB': 8, 'RB': 9, 'CD': 53, "''": 1, 'PO': 1, '.': 1, 'IN': 1, 'WD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 5:
# {'NN': 2533, 'JJ': 119, 'VB': 15, 'CD': 7, 'RB': 16, 'CC': 1, 'IN': 5, 'PR': 1, 'WD': 1}

# %% [markdown]
# # Sheridan Le Fanu

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
from collections import Counter
from nltk.tokenize import word_tokenize
import pandas as pd

stemmed_text_Fanu = stem_text(preprocessed_text_Fanu)

# Tokenize the corpus into words
words_Fanu = word_tokenize(stemmed_text_Fanu)

# Count the frequency of each word
word_frequency_Fanu = Counter(words_Fanu)

# Identify Hapax legomena (words that occur only once)
hapax_legomena_Fanu = [word for word, freq in word_frequency_Fanu.items() if freq == 1]

# Initialize a dictionary to store the frequency of each general POS tag among Hapax legomena
pos_tag_frequency_Fanu = {}

# Process each Hapax legomenon
for word in hapax_legomena_Fanu:
    # Find the index of the first occurrence of the Hapax legomenon
    index_Fanu = words_Fanu.index(word)
    # Determine the POS tagging of the Hapax legomenon at its specific occurrence
    pos_tag_Fanu = nltk.pos_tag([word])[0][1]
    # Generalize the POS tag to its main category
    general_pos_tag_Fanu = pos_tag_Fanu[:2]  # Take only the first two characters
    # Increment the frequency count for this general POS tag
    pos_tag_frequency_Fanu[general_pos_tag_Fanu] = pos_tag_frequency_Fanu.get(general_pos_tag_Fanu, 0) + 1

# Create a DataFrame from the pos_tag_frequency dictionary
Fanu_Hapax = pd.DataFrame(list(pos_tag_frequency_Fanu.items()), columns=['POS Tag', 'Frequency'])

# Calculate the total number of Hapax legomena
total_hapax_legomena_Fanu = len(hapax_legomena_Fanu)

# Calculate the relative frequency for each general POS tag among Hapax legomena
Fanu_Hapax['Relative Frequency'] = Fanu_Hapax['Frequency'] / total_hapax_legomena_Fanu

# %%
Fanu_Hapax.sort_values(by='Relative Frequency', ascending=False)
# Out:
#   POS Tag  Frequency  Relative Frequency
# 0      NN       2843            0.960473
# 1      JJ         83            0.028041
# 3      CD         17            0.005743
# 2      VB         10            0.003378
# 4      RB          4            0.001351
# 5      MD          1            0.000338
# 6      SY          1            0.000338
# 7      IN          1            0.000338

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5
print(subset_size)

# Find hapax legomena and POS tag frequencies in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pos_tag_frequency_subset = hapax_legomena_and_pos_tags(subset_text)
    print(f"Hapax Legomena and POS Tag Frequencies in Subset {i + 1}:")
    print(pos_tag_frequency_subset)
# Out:
# 1097
# Hapax Legomena and POS Tag Frequencies in Subset 1:
# {'NN': 1851, 'JJ': 77, 'CD': 5, 'VB': 13, 'RB': 5, 'IN': 1, 'MD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 2:
# {'NN': 1576, 'JJ': 70, 'RB': 9, 'VB': 17, 'DT': 1, '(': 1, ')': 1, 'IN': 4, 'CD': 3}
# Hapax Legomena and POS Tag Frequencies in Subset 3:
# {'NN': 1578, 'JJ': 60, 'RB': 5, 'VB': 8, 'DT': 1, 'IN': 1, 'CD': 5}
# Hapax Legomena and POS Tag Frequencies in Subset 4:
# {'NN': 1688, 'JJ': 74, 'VB': 15, 'IN': 7, 'RB': 2, 'SY': 1, 'CD': 4, 'CC': 1, "''": 1}
# Hapax Legomena and POS Tag Frequencies in Subset 5:
# {'NN': 1697, 'JJ': 76, 'VB': 18, 'TO': 1, 'RB': 5, 'MD': 3, 'CD': 4, 'IN': 3}

# %% [markdown]
# # Gothic corpus

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
from collections import Counter
from nltk.tokenize import word_tokenize
import pandas as pd

stemmed_text_Gothic = stem_text(preprocessed_text_Gothic)

# Tokenize the corpus into words
words_Gothic = word_tokenize(stemmed_text_Gothic)

# Count the frequency of each word
word_frequency_Gothic = Counter(words_Gothic)

# Identify Hapax legomena (words that occur only once)
hapax_legomena_Gothic = [word for word, freq in word_frequency_Gothic.items() if freq == 1]

# Initialize a dictionary to store the frequency of each general POS tag among Hapax legomena
pos_tag_frequency_Gothic = {}

# Process each Hapax legomenon
for word in hapax_legomena_Gothic:
    # Find the index of the first occurrence of the Hapax legomenon
    index_Gothic = words_Gothic.index(word)
    # Determine the POS tagging of the Hapax legomenon at its specific occurrence
    pos_tag_Gothic = nltk.pos_tag([word])[0][1]
    # Generalize the POS tag to its main category
    general_pos_tag_Gothic = pos_tag_Gothic[:2]  # Take only the first two characters
    # Increment the frequency count for this general POS tag
    pos_tag_frequency_Gothic[general_pos_tag_Gothic] = pos_tag_frequency_Gothic.get(general_pos_tag_Gothic, 0) + 1

# Create a DataFrame from the pos_tag_frequency dictionary
Gothic_Hapax = pd.DataFrame(list(pos_tag_frequency_Gothic.items()), columns=['POS Tag', 'Frequency'])

# Calculate the total number of Hapax legomena
total_hapax_legomena_Gothic = len(hapax_legomena_Gothic)

# Calculate the relative frequency for each general POS tag among Hapax legomena
Gothic_Hapax['Relative Frequency'] = Gothic_Hapax['Frequency'] / total_hapax_legomena_Gothic

# %%
Gothic_Hapax.sort_values(by='Relative Frequency', ascending=False)
# Out:
#   POS Tag  Frequency  Relative Frequency
# 1      NN       8342            0.958190
# 3      JJ        193            0.022169
# 0      CD        115            0.013209
# 4      VB         29            0.003331
# 2      RB         25            0.002872
# 5      IN          2            0.000230

# %%
#Poe vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1568

# Find hapax legomena and POS tag frequencies in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pos_tag_frequency_subset = hapax_legomena_and_pos_tags(subset_text)
    print(f"Hapax Legomena and POS Tag Frequencies in Subset {i + 1}:")
    print(pos_tag_frequency_subset)
# Out:
# Hapax Legomena and POS Tag Frequencies in Subset 1:
# {'CD': 4, 'NN': 1992, 'VB': 25, 'JJ': 74, 'RB': 12, 'IN': 5, 'PR': 2}
# Hapax Legomena and POS Tag Frequencies in Subset 2:
# {'NN': 1764, 'RB': 11, 'JJ': 69, 'VB': 16, 'IN': 5, 'CD': 3, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 3:
# {'NN': 1579, 'JJ': 53, 'RB': 15, 'VB': 25, 'IN': 3, 'SY': 1, 'DT': 1, 'CC': 1, 'CD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 4:
# {'NN': 1890, 'VB': 34, 'JJ': 78, 'RB': 8, 'CD': 1, 'WD': 1, 'IN': 4, 'DT': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 5:
# {'NN': 2686, 'RB': 17, 'VB': 22, 'JJ': 119, 'DT': 1, 'IN': 5, 'CD': 2, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 6:
# {'NN': 2513, 'RB': 21, 'JJ': 106, 'VB': 26, 'CD': 2, 'IN': 2, 'CC': 1, 'DT': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 7:
# {'NN': 2561, 'JJ': 105, 'VB': 25, 'RB': 14, 'IN': 7, 'DT': 3, 'CD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 8:
# {'NN': 2836, 'JJ': 109, 'IN': 7, 'VB': 24, 'RB': 20, 'CC': 2, 'SY': 1, 'DT': 3, 'WD': 2, 'CD': 2}
# Hapax Legomena and POS Tag Frequencies in Subset 9:
# {'NN': 2356, 'JJ': 105, 'RB': 20, 'VB': 17, 'IN': 10, 'CD': 5, 'DT': 5, 'WD': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 10:
# {'NN': 1248, 'RB': 9, 'JJ': 58, 'VB': 5, 'CD': 4, 'CC': 1, 'MD': 1, 'DT': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 11:
# {'NN': 1317, 'JJ': 70, 'RB': 7, 'IN': 3, 'VB': 10, '(': 1, ')': 1, 'CD': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 12:
# {'NN': 1402, 'JJ': 69, 'VB': 10, 'RB': 8, '(': 1, ')': 1, 'CD': 1, 'IN': 3}
# Hapax Legomena and POS Tag Frequencies in Subset 13:
# {'NN': 1448, 'JJ': 76, 'VB': 12, 'RB': 6, 'CC': 2, 'DT': 2, 'CD': 2, ':': 1, 'IN': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 14:
# {'NN': 1379, 'IN': 2, 'JJ': 66, 'RB': 6, 'VB': 16, 'CC': 2, 'DT': 2, 'CD': 2}
# Hapax Legomena and POS Tag Frequencies in Subset 15:
# {'NN': 1401, 'RB': 8, "''": 1, 'JJ': 56, 'CD': 3, 'IN': 3, 'VB': 12}
# Hapax Legomena and POS Tag Frequencies in Subset 16:
# {'NN': 1564, 'RB': 11, 'VB': 13, 'IN': 4, 'JJ': 73, 'DT': 1, "''": 1, 'CD': 28}
# Hapax Legomena and POS Tag Frequencies in Subset 17:
# {'NN': 1358, 'IN': 3, 'JJ': 67, 'CC': 1, 'VB': 16, 'RB': 19, 'CD': 4, 'DT': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 18:
# {'NN': 1229, 'RB': 11, 'JJ': 57, 'CD': 20, 'IN': 3, 'VB': 9, 'WD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 19:
# {'NN': 1583, 'CD': 18, 'JJ': 67, 'IN': 7, 'VB': 13, 'WD': 2, 'RB': 3}
# Hapax Legomena and POS Tag Frequencies in Subset 20:
# {'NN': 1283, 'JJ': 54, 'RB': 15, 'DT': 2, 'VB': 9, 'CD': 6, 'IN': 1, 'PR': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 21:
# {'NN': 1129, 'JJ': 45, 'VB': 13, 'RB': 6, 'CD': 8, 'DT': 2, 'IN': 7, 'PR': 1, 'PO': 1, 'CC': 1, 'LS': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 22:
# {'NN': 1285, 'JJ': 69, 'CD': 4, 'IN': 5, 'VB': 7, 'RB': 9, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 23:
# {'NN': 1484, 'JJ': 54, 'RB': 11, 'VB': 12, 'CD': 5, 'WD': 2, 'IN': 3, 'DT': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 24:
# {'NN': 1781, 'RB': 10, 'JJ': 52, 'IN': 3, 'VB': 15, 'CD': 4, 'DT': 1, 'WD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 25:
# {'NN': 1751, 'JJ': 50, 'RB': 15, 'VB': 27, 'IN': 3, 'WD': 1, 'DT': 3, 'CD': 1}

# %%
#Fanu vs Gothic
# Split the text into sentences
sentences = split_into_sentences(text_Gothic)
subset_size = 1097

# Find hapax legomena and POS tag frequencies in each subset
for i in range(25):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    pos_tag_frequency_subset = hapax_legomena_and_pos_tags(subset_text)
    print(f"Hapax Legomena and POS Tag Frequencies in Subset {i + 1}:")
    print(pos_tag_frequency_subset)
# Out:
# Hapax Legomena and POS Tag Frequencies in Subset 1:
# {'CD': 4, 'NN': 1846, 'VB': 22, 'JJ': 76, 'RB': 10, 'IN': 4, 'PR': 1, 'MD': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 2:
# {'NN': 1425, 'IN': 2, 'JJ': 52, 'RB': 8, 'VB': 12, 'CD': 1, 'PR': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 3:
# {'NN': 1618, 'VB': 18, 'JJ': 68, 'RB': 12, 'CD': 1, 'IN': 4, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 4:
# {'NN': 1377, 'RB': 14, 'JJ': 44, 'VB': 23, 'IN': 4, 'WP': 1, 'SY': 1, 'CD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 5:
# {'NN': 1390, 'JJ': 51, 'RB': 7, 'VB': 25, 'WP': 1, 'CC': 1, 'CD': 2, 'IN': 4, 'WD': 1, 'PR': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 6:
# {'NN': 1805, 'JJ': 73, 'RB': 10, 'VB': 18, 'IN': 4, 'DT': 2, 'CD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 7:
# {'NN': 2309, 'JJ': 106, 'VB': 18, 'IN': 5, 'RB': 11, 'CD': 2, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 8:
# {'JJ': 84, 'NN': 2063, 'CD': 6, 'RB': 19, 'VB': 20, 'IN': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 9:
# {'JJ': 89, 'NN': 2195, 'VB': 27, 'IN': 5, 'CC': 1, 'CD': 2, 'RB': 6, 'DT': 2}
# Hapax Legomena and POS Tag Frequencies in Subset 10:
# {'NN': 2135, 'VB': 23, 'JJ': 87, 'RB': 12, 'DT': 2, 'IN': 8, 'CD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 11:
# {'NN': 2311, 'JJ': 81, 'IN': 5, 'VB': 14, 'RB': 18, 'CC': 2, 'SY': 1, 'DT': 3, 'WD': 1, 'CD': 2}
# Hapax Legomena and POS Tag Frequencies in Subset 12:
# {'NN': 2138, 'JJ': 98, 'RB': 15, 'CD': 5, 'VB': 25, 'IN': 8, 'WD': 1, 'PR': 1, 'DT': 3}
# Hapax Legomena and POS Tag Frequencies in Subset 13:
# {'NN': 2035, 'JJ': 79, 'IN': 7, 'RB': 18, 'VB': 14, 'WD': 1, 'DT': 1, 'CC': 1, 'CD': 3, 'PR': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 14:
# {'NN': 1004, 'JJ': 52, 'CD': 4, 'IN': 2, 'VB': 8, 'CC': 1, 'RB': 7, 'MD': 1, 'DT': 1, '(': 1, ')': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 15:
# {'NN': 1125, 'RB': 8, 'JJ': 48, 'CD': 3, 'VB': 10, 'DT': 1, 'IN': 1, '(': 1, ')': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 16:
# {'NN': 1199, 'JJ': 70, 'RB': 8, 'IN': 2, 'VB': 8, 'CD': 1, 'CC': 1, "''": 1}
# Hapax Legomena and POS Tag Frequencies in Subset 17:
# {'NN': 1244, 'JJ': 61, 'RB': 6, 'VB': 10, "''": 1, '(': 1, ')': 1, 'CD': 2, 'IN': 2}
# Hapax Legomena and POS Tag Frequencies in Subset 18:
# {'NN': 1339, 'JJ': 66, 'RB': 6, 'IN': 3, 'VB': 8, 'CC': 1, 'DT': 1, 'CD': 2, ':': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 19:
# {'NN': 1232, 'VB': 11, 'JJ': 57, 'CC': 1, 'RB': 7, 'IN': 1, 'CD': 1, 'DT': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 20:
# {'NN': 1219, 'VB': 14, 'JJ': 61, 'CC': 2, 'RB': 4, 'IN': 2, "''": 1, 'CD': 3, 'DT': 2, 'MD': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 21:
# {'NN': 1281, 'VB': 12, 'RB': 7, "''": 1, 'JJ': 59, 'CD': 3, 'IN': 2, ':': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 22:
# {'NN': 1171, 'VB': 15, 'JJ': 35, ':': 1, 'IN': 4, 'RB': 7, 'CD': 2, '(': 1, ')': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 23:
# {'NN': 1422, 'JJ': 66, 'VB': 10, 'RB': 10, 'DT': 1, 'CD': 28, "''": 1, 'IN': 1, 'CC': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 24:
# {'NN': 1206, 'JJ': 63, 'RB': 14, 'CD': 5, 'IN': 4, 'VB': 11, 'DT': 1, 'PR': 1}
# Hapax Legomena and POS Tag Frequencies in Subset 25:
# {'NN': 1026, 'IN': 6, 'JJ': 51, 'RB': 12, 'VB': 14, 'CD': 2, 'WD': 1}

# %% [markdown]
# # N-gram

# %%
from nltk.tokenize import word_tokenize
from nltk import ngrams
from collections import Counter
import re

def find_ngrams(text, n):
    # Tokenize the text into words
    words = word_tokenize(text)
    # Remove punctuation
    words = [word for word in words if word.isalnum()]
    # Generate n-grams
    n_grams = ngrams(words, n)
    # Count the frequency of each n-gram
    n_gram_freq = Counter(n_grams)
    # Return the most common n-grams
    return n_gram_freq.most_common(25)

# %% [markdown]
# # Allan Poe

# %%
most_common_ngrams_Poe = find_ngrams(preprocessed_text_Poe, 3)
print("Most frequent {}-grams:".format(3), most_common_ngrams_Poe)
# Out:
# Most frequent 3-grams: [(('one', 'of', 'the'), 109), (('I', 'could', 'not'), 81), (('of', 'the', 'most'), 58), (('as', 'well', 'as'), 52), (('portion', 'of', 'the'), 44), (('would', 'have', 'been'), 44), (('that', 'of', 'the'), 43), (('might', 'have', 'been'), 42), (('which', 'I', 'had'), 36), (('I', 'had', 'been'), 35), (('part', 'of', 'the'), 34), (('that', 'it', 'was'), 34), (('in', 'regard', 'to'), 33), (('that', 'he', 'had'), 32), (('of', 'the', 'water'), 32), (('to', 'the', 'southward'), 32), (('on', 'account', 'of'), 31), (('by', 'means', 'of'), 31), (('to', 'and', 'fro'), 31), (('appeared', 'to', 'be'), 30), (('that', 'he', 'was'), 30), (('seemed', 'to', 'be'), 30), (('so', 'as', 'to'), 29), (('of', 'which', 'I'), 29), (('and', 'in', 'the'), 29)]

# %%
from nltk.tokenize import word_tokenize
from nltk import ngrams
from collections import Counter
import re
import pandas as pd

def find_ngrams(text, n):
    # Tokenize the text into words
    words = word_tokenize(text)
    # Remove punctuation
    words = [word for word in words if word.isalnum()]
    # Generate n-grams
    n_grams = ngrams(words, n)
    # Count the frequency of each n-gram
    n_gram_freq = Counter(n_grams)
    # Calculate the total number of n-grams
    total_ngrams = sum(n_gram_freq.values())
    # Calculate the relative frequency of each n-gram
    relative_frequency = {gram: freq / total_ngrams for gram, freq in n_gram_freq.items()}
    # Return the most common n-grams with their relative frequencies
    return [(gram, freq, relative_frequency[gram]) for gram, freq in n_gram_freq.most_common(25)]

most_common_ngrams_Poe = find_ngrams(preprocessed_text_Poe, 3)
print("Most frequent {}-grams:".format(3))
for gram, freq, relative_freq in most_common_ngrams_Poe:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")

most_common_3grams_Poe_df = pd.DataFrame(most_common_ngrams_Poe, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 3-grams:
# ('one', 'of', 'the'): Frequency = 109, Relative Frequency = 0.000547
# ('I', 'could', 'not'): Frequency = 81, Relative Frequency = 0.000407
# ('of', 'the', 'most'): Frequency = 58, Relative Frequency = 0.000291
# ('as', 'well', 'as'): Frequency = 52, Relative Frequency = 0.000261
# ('portion', 'of', 'the'): Frequency = 44, Relative Frequency = 0.000221
# ('would', 'have', 'been'): Frequency = 44, Relative Frequency = 0.000221
# ('that', 'of', 'the'): Frequency = 43, Relative Frequency = 0.000216
# ('might', 'have', 'been'): Frequency = 42, Relative Frequency = 0.000211
# ('which', 'I', 'had'): Frequency = 36, Relative Frequency = 0.000181
# ('I', 'had', 'been'): Frequency = 35, Relative Frequency = 0.000176
# ('part', 'of', 'the'): Frequency = 34, Relative Frequency = 0.000171
# ('that', 'it', 'was'): Frequency = 34, Relative Frequency = 0.000171
# ('in', 'regard', 'to'): Frequency = 33, Relative Frequency = 0.000166
# ('that', 'he', 'had'): Frequency = 32, Relative Frequency = 0.000161
# ('of', 'the', 'water'): Frequency = 32, Relative Frequency = 0.000161
# ('to', 'the', 'southward'): Frequency = 32, Relative Frequency = 0.000161
# ('on', 'account', 'of'): Frequency = 31, Relative Frequency = 0.000156
# ('by', 'means', 'of'): Frequency = 31, Relative Frequency = 0.000156
# ('to', 'and', 'fro'): Frequency = 31, Relative Frequency = 0.000156
# ('appeared', 'to', 'be'): Frequency = 30, Relative Frequency = 0.000151
# ('that', 'he', 'was'): Frequency = 30, Relative Frequency = 0.000151
# ('seemed', 'to', 'be'): Frequency = 30, Relative Frequency = 0.000151
# ('so', 'as', 'to'): Frequency = 29, Relative Frequency = 0.000146
# ('of', 'which', 'I'): Frequency = 29, Relative Frequency = 0.000146
# ('and', 'in', 'the'): Frequency = 29, Relative Frequency = 0.000146

# %%
most_common_3grams_Poe_df.to_csv('most_common_3grams.csv', index=False)

# %%
most_common_ngrams_Poe = find_ngrams(preprocessed_text_Poe, 4)
print("Most frequent {}-grams:".format(4))
for gram, freq, relative_freq in most_common_ngrams_Poe:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_4grams_Poe_df = pd.DataFrame(most_common_ngrams_Poe, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 4-grams:
# ('on', 'the', 'part', 'of'): Frequency = 24, Relative Frequency = 0.000120
# ('for', 'the', 'purpose', 'of'): Frequency = 20, Relative Frequency = 0.000100
# ('that', 'is', 'to', 'say'): Frequency = 18, Relative Frequency = 0.000090
# ('on', 'account', 'of', 'the'): Frequency = 17, Relative Frequency = 0.000085
# ('ugh', 'ugh', 'ugh', 'ugh'): Frequency = 17, Relative Frequency = 0.000085
# ('I', 'could', 'not', 'help'): Frequency = 16, Relative Frequency = 0.000080
# ('in', 'regard', 'to', 'the'): Frequency = 16, Relative Frequency = 0.000080
# ('the', 'Barrière', 'du', 'Roule'): Frequency = 16, Relative Frequency = 0.000080
# ('by', 'means', 'of', 'a'): Frequency = 15, Relative Frequency = 0.000075
# ('the', 'vicinity', 'of', 'the'): Frequency = 15, Relative Frequency = 0.000075
# ('with', 'the', 'exception', 'of'): Frequency = 15, Relative Frequency = 0.000075
# ('the', 'head', 'of', 'the'): Frequency = 15, Relative Frequency = 0.000075
# ('the', 'middle', 'of', 'the'): Frequency = 13, Relative Frequency = 0.000065
# ('the', 'bottom', 'of', 'the'): Frequency = 13, Relative Frequency = 0.000065
# ('with', 'a', 'view', 'of'): Frequency = 13, Relative Frequency = 0.000065
# ('the', 'door', 'of', 'the'): Frequency = 12, Relative Frequency = 0.000060
# ('in', 'one', 'of', 'the'): Frequency = 12, Relative Frequency = 0.000060
# ('one', 'of', 'the', 'most'): Frequency = 12, Relative Frequency = 0.000060
# ('at', 'the', 'same', 'time'): Frequency = 11, Relative Frequency = 0.000055
# ('in', 'the', 'direction', 'of'): Frequency = 11, Relative Frequency = 0.000055
# ('the', 'direction', 'of', 'the'): Frequency = 11, Relative Frequency = 0.000055
# ('the', 'whole', 'of', 'the'): Frequency = 11, Relative Frequency = 0.000055
# ('in', 'the', 'vicinity', 'of'): Frequency = 10, Relative Frequency = 0.000050
# ('o', 'clock', 'in', 'the'): Frequency = 10, Relative Frequency = 0.000050
# ('of', 'one', 'of', 'the'): Frequency = 10, Relative Frequency = 0.000050

# %%
most_common_4grams_Poe_df
# Out:
#                         N-gram  Frequency  Relative Frequency
# 0          (on, the, part, of)         24            0.000120
# 1      (for, the, purpose, of)         20            0.000100
# 2          (that, is, to, say)         18            0.000090
# 3       (on, account, of, the)         17            0.000085
# 4         (ugh, ugh, ugh, ugh)         17            0.000085
# 5        (I, could, not, help)         16            0.000080
# 6        (in, regard, to, the)         16            0.000080
# 7   (the, Barrière, du, Roule)         16            0.000080
# 8           (by, means, of, a)         15            0.000075
# 9     (the, vicinity, of, the)         15            0.000075
# 10  (with, the, exception, of)         15            0.000075
# 11        (the, head, of, the)         15            0.000075
# 12      (the, middle, of, the)         13            0.000065
# 13      (the, bottom, of, the)         13            0.000065
# 14         (with, a, view, of)         13            0.000065
# 15        (the, door, of, the)         12            0.000060
# 16          (in, one, of, the)         12            0.000060
# 17        (one, of, the, most)         12            0.000060
# 18       (at, the, same, time)         11            0.000055
# 19    (in, the, direction, of)         11            0.000055
# 20   (the, direction, of, the)         11            0.000055
# 21       (the, whole, of, the)         11            0.000055
# 22     (in, the, vicinity, of)         10            0.000050
# 23         (o, clock, in, the)         10            0.000050
# 24          (of, one, of, the)         10            0.000050

# %%
most_common_4grams_Poe_df.to_csv('most_common_4grams.csv', index=False)

# %%
most_common_ngrams_Poe = find_ngrams(preprocessed_text_Poe, 5)
print("Most frequent {}-grams:".format(5))
for gram, freq, relative_freq in most_common_ngrams_Poe:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_5grams_Poe_df = pd.DataFrame(most_common_ngrams_Poe, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 5-grams:
# ('ugh', 'ugh', 'ugh', 'ugh', 'ugh'): Frequency = 15, Relative Frequency = 0.000075
# ('in', 'the', 'direction', 'of', 'the'): Frequency = 10, Relative Frequency = 0.000050
# ('in', 'the', 'vicinity', 'of', 'the'): Frequency = 9, Relative Frequency = 0.000045
# ('on', 'the', 'part', 'of', 'the'): Frequency = 9, Relative Frequency = 0.000045
# ('o', 'clock', 'in', 'the', 'morning'): Frequency = 8, Relative Frequency = 0.000040
# ('at', 'the', 'head', 'of', 'the'): Frequency = 7, Relative Frequency = 0.000035
# ('with', 'the', 'exception', 'of', 'the'): Frequency = 6, Relative Frequency = 0.000030
# ('in', 'the', 'bottom', 'of', 'the'): Frequency = 6, Relative Frequency = 0.000030
# ('the', 'bottom', 'of', 'the', 'boat'): Frequency = 6, Relative Frequency = 0.000030
# ('There', 'can', 'be', 'no', 'doubt'): Frequency = 5, Relative Frequency = 0.000025
# ('Madame', 'L', 'Espanaye', 'and', 'her'): Frequency = 5, Relative Frequency = 0.000025
# ('L', 'Espanaye', 'and', 'her', 'daughter'): Frequency = 5, Relative Frequency = 0.000025
# ('into', 'the', 'middle', 'of', 'the'): Frequency = 5, Relative Frequency = 0.000025
# ('three', 'o', 'clock', 'in', 'the'): Frequency = 5, Relative Frequency = 0.000025
# ('voice', 'was', 'that', 'of', 'a'): Frequency = 5, Relative Frequency = 0.000025
# ('of', 'the', 'Barrière', 'du', 'Roule'): Frequency = 5, Relative Frequency = 0.000025
# ('in', 'the', 'Rue', 'des', 'Drômes'): Frequency = 5, Relative Frequency = 0.000025
# ('folly', 'to', 'suppose', 'that', 'the'): Frequency = 5, Relative Frequency = 0.000025
# ('to', 'suppose', 'that', 'the', 'murder'): Frequency = 5, Relative Frequency = 0.000025
# ('thrown', 'into', 'the', 'water', 'immediately'): Frequency = 5, Relative Frequency = 0.000025
# ('into', 'the', 'water', 'immediately', 'after'): Frequency = 5, Relative Frequency = 0.000025
# ('the', 'water', 'immediately', 'after', 'death'): Frequency = 5, Relative Frequency = 0.000025
# ('water', 'immediately', 'after', 'death', 'by'): Frequency = 5, Relative Frequency = 0.000025
# ('immediately', 'after', 'death', 'by', 'violence'): Frequency = 5, Relative Frequency = 0.000025
# ('the', 'actions', 'of', 'the', 'man'): Frequency = 5, Relative Frequency = 0.000025

# %%
most_common_5grams_Poe_df.to_csv('most_common_5grams.csv', index=False)

# %% [markdown]
# # Sheridan Le Fanu

# %%
most_common_ngrams_Fanu = find_ngrams(preprocessed_text_Fanu, 3)
print("Most frequent {}-grams:".format(3), most_common_ngrams_Fanu)
# Out:
# Most frequent 3-grams: [(('I', 'don', 't'), 57), (('a', 'sort', 'of'), 39), (('that', 'he', 'was'), 38), (('said', 'Sir', 'Bale'), 37), (('out', 'of', 'the'), 36), (('I', 'could', 'not'), 35), (('side', 'of', 'the'), 33), (('there', 'was', 'a'), 32), (('I', 'can', 't'), 32), (('as', 'well', 'as'), 31), (('in', 'the', 'same'), 30), (('It', 'was', 'a'), 29), (('of', 'the', 'lake'), 29), (('Sir', 'Bale', 'Mardykes'), 29), (('which', 'he', 'had'), 28), (('and', 'with', 'a'), 28), (('of', 'the', 'house'), 28), (('of', 'the', 'old'), 28), (('two', 'or', 'three'), 27), (('one', 'of', 'the'), 27), (('for', 'a', 'moment'), 26), (('he', 'could', 'not'), 25), (('he', 'did', 'not'), 25), (('don', 't', 'know'), 25), (('Sir', 'Bale', 's'), 25)]

# %%
most_common_ngrams_Fanu = find_ngrams(preprocessed_text_Fanu, 3)
print("Most frequent {}-grams:".format(3))
for gram, freq, relative_freq in most_common_ngrams_Fanu:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_3grams_Fanu_df = pd.DataFrame(most_common_ngrams_Fanu, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 3-grams:
# ('I', 'don', 't'): Frequency = 57, Relative Frequency = 0.000376
# ('a', 'sort', 'of'): Frequency = 39, Relative Frequency = 0.000257
# ('that', 'he', 'was'): Frequency = 38, Relative Frequency = 0.000250
# ('said', 'Sir', 'Bale'): Frequency = 37, Relative Frequency = 0.000244
# ('out', 'of', 'the'): Frequency = 36, Relative Frequency = 0.000237
# ('I', 'could', 'not'): Frequency = 35, Relative Frequency = 0.000231
# ('side', 'of', 'the'): Frequency = 33, Relative Frequency = 0.000218
# ('there', 'was', 'a'): Frequency = 32, Relative Frequency = 0.000211
# ('I', 'can', 't'): Frequency = 32, Relative Frequency = 0.000211
# ('as', 'well', 'as'): Frequency = 31, Relative Frequency = 0.000204
# ('in', 'the', 'same'): Frequency = 30, Relative Frequency = 0.000198
# ('It', 'was', 'a'): Frequency = 29, Relative Frequency = 0.000191
# ('of', 'the', 'lake'): Frequency = 29, Relative Frequency = 0.000191
# ('Sir', 'Bale', 'Mardykes'): Frequency = 29, Relative Frequency = 0.000191
# ('which', 'he', 'had'): Frequency = 28, Relative Frequency = 0.000185
# ('and', 'with', 'a'): Frequency = 28, Relative Frequency = 0.000185
# ('of', 'the', 'house'): Frequency = 28, Relative Frequency = 0.000185
# ('of', 'the', 'old'): Frequency = 28, Relative Frequency = 0.000185
# ('two', 'or', 'three'): Frequency = 27, Relative Frequency = 0.000178
# ('one', 'of', 'the'): Frequency = 27, Relative Frequency = 0.000178
# ('for', 'a', 'moment'): Frequency = 26, Relative Frequency = 0.000171
# ('he', 'could', 'not'): Frequency = 25, Relative Frequency = 0.000165
# ('he', 'did', 'not'): Frequency = 25, Relative Frequency = 0.000165
# ('don', 't', 'know'): Frequency = 25, Relative Frequency = 0.000165
# ('Sir', 'Bale', 's'): Frequency = 25, Relative Frequency = 0.000165

# %%
most_common_3grams_Fanu_df.to_csv('most_common_3grams_Fanu.csv', index=False)

# %%
most_common_ngrams_Fanu = find_ngrams(preprocessed_text_Fanu, 4)
print("Most frequent {}-grams:".format(4))
for gram, freq, relative_freq in most_common_ngrams_Fanu:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_4grams_Fanu_df = pd.DataFrame(most_common_ngrams_Fanu, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 4-grams:
# ('I', 'don', 't', 'know'): Frequency = 22, Relative Frequency = 0.000145
# ('the', 'side', 'of', 'the'): Frequency = 15, Relative Frequency = 0.000099
# ('at', 'the', 'same', 'time'): Frequency = 15, Relative Frequency = 0.000099
# ('the', 'foot', 'of', 'the'): Frequency = 15, Relative Frequency = 0.000099
# ('the', 'George', 'and', 'Dragon'): Frequency = 14, Relative Frequency = 0.000092
# ('as', 'I', 'have', 'said'): Frequency = 13, Relative Frequency = 0.000086
# ('for', 'the', 'first', 'time'): Frequency = 12, Relative Frequency = 0.000079
# ('at', 'the', 'other', 'side'): Frequency = 12, Relative Frequency = 0.000079
# ('at', 'the', 'foot', 'of'): Frequency = 11, Relative Frequency = 0.000073
# ('in', 'a', 'state', 'of'): Frequency = 10, Relative Frequency = 0.000066
# ('the', 'door', 'of', 'the'): Frequency = 9, Relative Frequency = 0.000059
# ('for', 'a', 'long', 'time'): Frequency = 9, Relative Frequency = 0.000059
# ('I', 'can', 't', 'say'): Frequency = 9, Relative Frequency = 0.000059
# ('the', 'face', 'of', 'the'): Frequency = 8, Relative Frequency = 0.000053
# ('the', 'head', 'of', 'the'): Frequency = 8, Relative Frequency = 0.000053
# ('foot', 'of', 'the', 'bed'): Frequency = 8, Relative Frequency = 0.000053
# ('I', 'don', 't', 'think'): Frequency = 8, Relative Frequency = 0.000053
# ('the', 'corner', 'of', 'the'): Frequency = 8, Relative Frequency = 0.000053
# ('for', 'the', 'purpose', 'of'): Frequency = 8, Relative Frequency = 0.000053
# ('with', 'a', 'sort', 'of'): Frequency = 8, Relative Frequency = 0.000053
# ('the', 'margin', 'of', 'the'): Frequency = 8, Relative Frequency = 0.000053
# ('of', 'the', 'George', 'and'): Frequency = 8, Relative Frequency = 0.000053
# ('the', 'other', 'side', 'of'): Frequency = 8, Relative Frequency = 0.000053
# ('a', 'great', 'deal', 'of'): Frequency = 8, Relative Frequency = 0.000053
# ('in', 'the', 'name', 'of'): Frequency = 8, Relative Frequency = 0.000053

# %%
most_common_4grams_Fanu_df.to_csv('most_common_4grams_Fanu.csv', index=False)

# %%
most_common_ngrams_Fanu = find_ngrams(preprocessed_text_Fanu, 5)
print("Most frequent {}-grams:".format(5))
for gram, freq, relative_freq in most_common_ngrams_Fanu:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_5grams_Fanu_df = pd.DataFrame(most_common_ngrams_Fanu, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 5-grams:
# ('at', 'the', 'foot', 'of', 'the'): Frequency = 8, Relative Frequency = 0.000053
# ('the', 'foot', 'of', 'the', 'bed'): Frequency = 8, Relative Frequency = 0.000053
# ('the', 'margin', 'of', 'the', 'lake'): Frequency = 7, Relative Frequency = 0.000046
# ('of', 'the', 'George', 'and', 'Dragon'): Frequency = 7, Relative Frequency = 0.000046
# ('at', 'the', 'other', 'side', 'of'): Frequency = 7, Relative Frequency = 0.000046
# ('the', 'other', 'side', 'of', 'the'): Frequency = 7, Relative Frequency = 0.000046
# ('I', 'don', 't', 'know', 'what'): Frequency = 7, Relative Frequency = 0.000046
# ('and', 'at', 'the', 'same', 'time'): Frequency = 6, Relative Frequency = 0.000040
# ('made', 'up', 'his', 'mind', 'to'): Frequency = 6, Relative Frequency = 0.000040
# ('the', 'host', 'of', 'the', 'George'): Frequency = 5, Relative Frequency = 0.000033
# ('the', 'side', 'of', 'the', 'bed'): Frequency = 4, Relative Frequency = 0.000026
# ('in', 'the', 'direction', 'of', 'the'): Frequency = 4, Relative Frequency = 0.000026
# ('to', 'the', 'side', 'of', 'the'): Frequency = 4, Relative Frequency = 0.000026
# ('at', 'the', 'far', 'end', 'of'): Frequency = 4, Relative Frequency = 0.000026
# ('the', 'far', 'end', 'of', 'the'): Frequency = 4, Relative Frequency = 0.000026
# ('by', 'the', 'margin', 'of', 'the'): Frequency = 4, Relative Frequency = 0.000026
# ('I', 'don', 't', 'want', 'to'): Frequency = 4, Relative Frequency = 0.000026
# ('if', 'it', 'had', 'not', 'been'): Frequency = 4, Relative Frequency = 0.000026
# ('the', 'edge', 'of', 'the', 'lake'): Frequency = 4, Relative Frequency = 0.000026
# ('Sir', 'Bale', 'looked', 'at', 'him'): Frequency = 4, Relative Frequency = 0.000026
# ('the', 'front', 'of', 'the', 'house'): Frequency = 4, Relative Frequency = 0.000026
# ('your', 'honour', 'says', 'my', 'father'): Frequency = 4, Relative Frequency = 0.000026
# ('now', 'for', 'the', 'first', 'time'): Frequency = 3, Relative Frequency = 0.000020
# ('by', 'the', 'light', 'of', 'a'): Frequency = 3, Relative Frequency = 0.000020
# ('at', 'the', 'door', 'of', 'the'): Frequency = 3, Relative Frequency = 0.000020

# %%
most_common_5grams_Fanu_df.to_csv('most_common_5grams_Fanu.csv', index=False)

# %% [markdown]
# # Gothic corpus

# %%
most_common_ngrams_Gothic = find_ngrams(preprocessed_text_Gothic, 3)
print("Most frequent {}-grams:".format(3), most_common_ngrams_Gothic)
# Out:
# Most frequent 3-grams: [(('I', 'don', 't'), 1002), (('I', 'can', 'not'), 759), (('I', 'could', 'not'), 750), (('one', 'of', 'the'), 686), (('out', 'of', 'the'), 614), (('I', 'did', 'not'), 567), (('that', 'it', 'was'), 523), (('that', 'I', 'was'), 492), (('that', 'he', 'was'), 488), (('as', 'well', 'as'), 486), (('that', 'he', 'had'), 482), (('I', 'do', 'not'), 467), (('that', 'I', 'had'), 454), (('Sir', 'Francis', 'Varney'), 451), (('for', 'a', 'moment'), 437), (('I', 'am', 'not'), 406), (('which', 'I', 'had'), 389), (('part', 'of', 'the'), 385), (('there', 'was', 'a'), 383), (('don', 't', 'know'), 382), (('I', 'had', 'been'), 367), (('would', 'have', 'been'), 363), (('I', 'should', 'have'), 361), (('which', 'he', 'had'), 328), (('It', 'was', 'a'), 326)]

# %%
most_common_ngrams_Gothic = find_ngrams(preprocessed_text_Gothic, 3)
print("Most frequent {}-grams:".format(3))
for gram, freq, relative_freq in most_common_ngrams_Gothic:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_3grams_Gothic_df = pd.DataFrame(most_common_ngrams_Gothic, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 3-grams:
# ('I', 'don', 't'): Frequency = 1002, Relative Frequency = 0.000334
# ('I', 'can', 'not'): Frequency = 759, Relative Frequency = 0.000253
# ('I', 'could', 'not'): Frequency = 750, Relative Frequency = 0.000250
# ('one', 'of', 'the'): Frequency = 686, Relative Frequency = 0.000229
# ('out', 'of', 'the'): Frequency = 614, Relative Frequency = 0.000205
# ('I', 'did', 'not'): Frequency = 567, Relative Frequency = 0.000189
# ('that', 'it', 'was'): Frequency = 523, Relative Frequency = 0.000174
# ('that', 'I', 'was'): Frequency = 492, Relative Frequency = 0.000164
# ('that', 'he', 'was'): Frequency = 488, Relative Frequency = 0.000163
# ('as', 'well', 'as'): Frequency = 486, Relative Frequency = 0.000162
# ('that', 'he', 'had'): Frequency = 482, Relative Frequency = 0.000161
# ('I', 'do', 'not'): Frequency = 467, Relative Frequency = 0.000156
# ('that', 'I', 'had'): Frequency = 454, Relative Frequency = 0.000151
# ('Sir', 'Francis', 'Varney'): Frequency = 451, Relative Frequency = 0.000150
# ('for', 'a', 'moment'): Frequency = 437, Relative Frequency = 0.000146
# ('I', 'am', 'not'): Frequency = 406, Relative Frequency = 0.000135
# ('which', 'I', 'had'): Frequency = 389, Relative Frequency = 0.000130
# ('part', 'of', 'the'): Frequency = 385, Relative Frequency = 0.000128
# ('there', 'was', 'a'): Frequency = 383, Relative Frequency = 0.000128
# ('don', 't', 'know'): Frequency = 382, Relative Frequency = 0.000127
# ('I', 'had', 'been'): Frequency = 367, Relative Frequency = 0.000122
# ('would', 'have', 'been'): Frequency = 363, Relative Frequency = 0.000121
# ('I', 'should', 'have'): Frequency = 361, Relative Frequency = 0.000120
# ('which', 'he', 'had'): Frequency = 328, Relative Frequency = 0.000109
# ('It', 'was', 'a'): Frequency = 326, Relative Frequency = 0.000109

# %%
most_common_3grams_Gothic_df.to_csv('most_common_3grams_Gothic.csv', index=False)

# %%
most_common_ngrams_Gothic = find_ngrams(preprocessed_text_Gothic, 4)
print("Most frequent {}-grams:".format(4))
for gram, freq, relative_freq in most_common_ngrams_Gothic:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_4grams_Gothic_df = pd.DataFrame(most_common_ngrams_Gothic, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 4-grams:
# ('I', 'don', 't', 'know'): Frequency = 292, Relative Frequency = 0.000097
# ('at', 'the', 'same', 'time'): Frequency = 210, Relative Frequency = 0.000070
# ('for', 'the', 'first', 'time'): Frequency = 166, Relative Frequency = 0.000055
# ('the', 'door', 'of', 'the'): Frequency = 132, Relative Frequency = 0.000044
# ('at', 'the', 'end', 'of'): Frequency = 117, Relative Frequency = 0.000039
# ('the', 'end', 'of', 'the'): Frequency = 111, Relative Frequency = 0.000037
# ('in', 'the', 'midst', 'of'): Frequency = 107, Relative Frequency = 0.000036
# ('the', 'rest', 'of', 'the'): Frequency = 106, Relative Frequency = 0.000035
# ('I', 'do', 'not', 'know'): Frequency = 105, Relative Frequency = 0.000035
# ('in', 'a', 'state', 'of'): Frequency = 95, Relative Frequency = 0.000032
# ('I', 'don', 't', 'want'): Frequency = 94, Relative Frequency = 0.000031
# ('out', 'of', 'the', 'room'): Frequency = 92, Relative Frequency = 0.000031
# ('don', 't', 'know', 'what'): Frequency = 91, Relative Frequency = 0.000030
# ('as', 'if', 'he', 'had'): Frequency = 91, Relative Frequency = 0.000030
# ('in', 'the', 'course', 'of'): Frequency = 89, Relative Frequency = 0.000030
# ('from', 'time', 'to', 'time'): Frequency = 89, Relative Frequency = 0.000030
# ('the', 'top', 'of', 'the'): Frequency = 88, Relative Frequency = 0.000029
# ('I', 'should', 'like', 'to'): Frequency = 87, Relative Frequency = 0.000029
# ('in', 'the', 'middle', 'of'): Frequency = 87, Relative Frequency = 0.000029
# ('for', 'the', 'sake', 'of'): Frequency = 86, Relative Frequency = 0.000029
# ('I', 'don', 't', 'think'): Frequency = 85, Relative Frequency = 0.000028
# ('the', 'middle', 'of', 'the'): Frequency = 84, Relative Frequency = 0.000028
# ('I', 'am', 'going', 'to'): Frequency = 84, Relative Frequency = 0.000028
# ('as', 'if', 'he', 'were'): Frequency = 84, Relative Frequency = 0.000028
# ('as', 'if', 'I', 'had'): Frequency = 80, Relative Frequency = 0.000027

# %%
most_common_4grams_Gothic_df.to_csv('most_common_4grams_Gothic.csv', index=False)

# %%
most_common_ngrams_Gothic = find_ngrams(preprocessed_text_Gothic, 5)
print("Most frequent {}-grams:".format(5))
for gram, freq, relative_freq in most_common_ngrams_Gothic:
    print(f"{gram}: Frequency = {freq}, Relative Frequency = {relative_freq:.6f}")
    
most_common_5grams_Gothic_df = pd.DataFrame(most_common_ngrams_Gothic, columns=['N-gram', 'Frequency', 'Relative Frequency'])
# Out:
# Most frequent 5-grams:
# ('I', 'don', 't', 'know', 'what'): Frequency = 64, Relative Frequency = 0.000021
# ('at', 'the', 'end', 'of', 'the'): Frequency = 61, Relative Frequency = 0.000020
# ('in', 'the', 'middle', 'of', 'the'): Frequency = 55, Relative Frequency = 0.000018
# ('I', 'don', 't', 'want', 'to'): Frequency = 47, Relative Frequency = 0.000016
# ('a', 'quarter', 'of', 'an', 'hour'): Frequency = 44, Relative Frequency = 0.000015
# ('and', 'at', 'the', 'same', 'time'): Frequency = 41, Relative Frequency = 0.000014
# ('at', 'the', 'door', 'of', 'the'): Frequency = 39, Relative Frequency = 0.000013
# ('the', 'other', 'side', 'of', 'the'): Frequency = 37, Relative Frequency = 0.000012
# ('at', 'the', 'foot', 'of', 'the'): Frequency = 36, Relative Frequency = 0.000012
# ('as', 'if', 'it', 'had', 'been'): Frequency = 34, Relative Frequency = 0.000011
# ('was', 'on', 'the', 'point', 'of'): Frequency = 34, Relative Frequency = 0.000011
# ('as', 'if', 'he', 'had', 'been'): Frequency = 34, Relative Frequency = 0.000011
# ('the', 'other', 'end', 'of', 'the'): Frequency = 34, Relative Frequency = 0.000011
# ('at', 'the', 'bottom', 'of', 'the'): Frequency = 33, Relative Frequency = 0.000011
# ('on', 'the', 'other', 'side', 'of'): Frequency = 32, Relative Frequency = 0.000011
# ('in', 'the', 'direction', 'of', 'the'): Frequency = 32, Relative Frequency = 0.000011
# ('I', 'don', 't', 'know', 'how'): Frequency = 30, Relative Frequency = 0.000010
# ('as', 'if', 'I', 'had', 'been'): Frequency = 29, Relative Frequency = 0.000010
# ('in', 'the', 'midst', 'of', 'the'): Frequency = 29, Relative Frequency = 0.000010
# ('seemed', 'to', 'me', 'as', 'if'): Frequency = 28, Relative Frequency = 0.000009
# ('for', 'the', 'first', 'time', 'in'): Frequency = 26, Relative Frequency = 0.000009
# ('as', 'well', 'as', 'I', 'could'): Frequency = 25, Relative Frequency = 0.000008
# ('at', 'the', 'top', 'of', 'the'): Frequency = 24, Relative Frequency = 0.000008
# ('on', 'the', 'part', 'of', 'the'): Frequency = 24, Relative Frequency = 0.000008
# ('on', 'one', 'side', 'of', 'the'): Frequency = 23, Relative Frequency = 0.000008

# %%
most_common_5grams_Gothic_df.to_csv('most_common_5grams_Gothic.csv', index=False)

# %% [markdown]
#  # Occurance of 1 - 10 letter words

# %%
def count_words_by_length(document):
    # Initialize a dictionary to store counts for each word length
    word_lengths = {i: 0 for i in range(1, 11)}

    # Split the document into words
    words = document.split()

    # Iterate over each word and update the counts
    for word in words:
        length = len(word)
        if 1 <= length <= 10:
            word_lengths[length] += 1

    return word_lengths

# %% [markdown]
# # Allan Poe

# %%
word_counts_Poe = count_words_by_length(preprocessed_text_Poe)
print("Word counts by length:")
for length, count in word_counts_Poe.items():
    print(f"Length {length}: {count}")
# Out:
# Word counts by length:
# Length 1: 8447
# Length 2: 37194
# Length 3: 42986
# Length 4: 33037
# Length 5: 21292
# Length 6: 16257
# Length 7: 13748
# Length 8: 10111
# Length 9: 7311
# Length 10: 4745

# %%
def relative_frequency_words_by_length(document):
    # Initialize a dictionary to store counts for each word length
    word_lengths = {i: 0 for i in range(1, 11)}

    # Split the document into words
    words = document.split()
    total_words = len(words)

    # Iterate over each word and update the counts
    for word in words:
        length = len(word)
        if 1 <= length <= 10:
            word_lengths[length] += 1

    # Calculate the relative frequency of each word length occurrence
    relative_frequencies = {length: count / total_words for length, count in word_lengths.items()}

    return relative_frequencies

# %%
relative_frequencies_Poe = relative_frequency_words_by_length(preprocessed_text_Poe)
print("Relative frequencies of word counts by length:")
for length, frequency in relative_frequencies_Poe.items():
    print(f"Length {length}: {frequency:.4f}")
# Out:
# Relative frequencies of word counts by length:
# Length 1: 0.0423
# Length 2: 0.1862
# Length 3: 0.2152
# Length 4: 0.1654
# Length 5: 0.1066
# Length 6: 0.0814
# Length 7: 0.0688
# Length 8: 0.0506
# Length 9: 0.0366
# Length 10: 0.0238

# %%
import re

# Function to split text into sentences
def split_into_sentences(text):
    # Use regular expression to split text into sentences
    # Assumes sentences end with '.', '!', or '?' followed by a space or end of line
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences

# Function to count words by length in a subset of text
def count_words_by_length_subset(subset_text):
    # Initialize a dictionary to store counts for each word length
    word_lengths = {i: 0 for i in range(1, 11)}

    # Split the subset into words
    words = subset_text.split()

    # Iterate over each word and update the counts
    for word in words:
        length = len(word)
        if 1 <= length <= 10:
            word_lengths[length] += 1

    return word_lengths

# Split the text into sentences
sentences = split_into_sentences(text_Poe)
subset_size = len(sentences) // 5

# Find the number of words by length in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    word_lengths_subset = count_words_by_length_subset(subset_text)
    print(f"Word Lengths Frequency in Subset {i + 1}:")
    for length, count in word_lengths_subset.items():
        print(f"Length {length}: {count}")
# Out:
# Word Lengths Frequency in Subset 1:
# Length 1: 1046
# Length 2: 6703
# Length 3: 7655
# Length 4: 5685
# Length 5: 3842
# Length 6: 2898
# Length 7: 2475
# Length 8: 2049
# Length 9: 1507
# Length 10: 1063
# Word Lengths Frequency in Subset 2:
# Length 1: 1685
# Length 2: 6276
# Length 3: 7374
# Length 4: 5368
# Length 5: 3664
# Length 6: 2940
# Length 7: 2585
# Length 8: 2078
# Length 9: 1561
# Length 10: 1042
# Word Lengths Frequency in Subset 3:
# Length 1: 1824
# Length 2: 6593
# Length 3: 7289
# Length 4: 5366
# Length 5: 3840
# Length 6: 2924
# Length 7: 2535
# Length 8: 2157
# Length 9: 1552
# Length 10: 1049
# Word Lengths Frequency in Subset 4:
# Length 1: 1318
# Length 2: 8497
# Length 3: 9137
# Length 4: 7140
# Length 5: 5135
# Length 6: 3560
# Length 7: 3304
# Length 8: 2375
# Length 9: 1858
# Length 10: 1232
# Word Lengths Frequency in Subset 5:
# Length 1: 1496
# Length 2: 7155
# Length 3: 9076
# Length 4: 6391
# Length 5: 4538
# Length 6: 3545
# Length 7: 3102
# Length 8: 2331
# Length 9: 1735
# Length 10: 1265

# %% [markdown]
# # Le Fanu

# %%
relative_frequencies_Fanu = relative_frequency_words_by_length(preprocessed_text_Fanu)
print("Relative frequencies of word counts by length:")
for length, frequency in relative_frequencies_Fanu.items():
    print(f"Length {length}: {frequency:.4f}")
# Out:
# Relative frequencies of word counts by length:
# Length 1: 0.0510
# Length 2: 0.1676
# Length 3: 0.2481
# Length 4: 0.1831
# Length 5: 0.1086
# Length 6: 0.0810
# Length 7: 0.0631
# Length 8: 0.0401
# Length 9: 0.0270
# Length 10: 0.0158

# %%
# Split the text into sentences
sentences = split_into_sentences(text_Fanu)
subset_size = len(sentences) // 5

# Find the number of words by length in each subset
for i in range(5):
    subset_sentences = sentences[i * subset_size: (i + 1) * subset_size]
    subset_text = ' '.join(subset_sentences)
    word_lengths_subset = count_words_by_length_subset(subset_text)
    print(f"Word Lengths Frequency in Subset {i + 1}:")
    for length, count in word_lengths_subset.items():
        print(f"Length {length}: {count}")
# Out:
# Word Lengths Frequency in Subset 1:
# Length 1: 1278
# Length 2: 5348
# Length 3: 8108
# Length 4: 5574
# Length 5: 3971
# Length 6: 2925
# Length 7: 2375
# Length 8: 1746
# Length 9: 1222
# Length 10: 840
# Word Lengths Frequency in Subset 2:
# Length 1: 884
# Length 2: 3744
# Length 3: 6056
# Length 4: 4531
# Length 5: 2983
# Length 6: 2164
# Length 7: 1630
# Length 8: 1159
# Length 9: 764
# Length 10: 440
# Word Lengths Frequency in Subset 3:
# Length 1: 1020
# Length 2: 4310
# Length 3: 6738
# Length 4: 4974
# Length 5: 3235
# Length 6: 2422
# Length 7: 1922
# Length 8: 1332
# Length 9: 862
# Length 10: 554
# Word Lengths Frequency in Subset 4:
# Length 1: 1455
# Length 2: 5391
# Length 3: 7121
# Length 4: 5272
# Length 5: 3525
# Length 6: 2655
# Length 7: 2170
# Length 8: 1642
# Length 9: 1171
# Length 10: 768
# Word Lengths Frequency in Subset 5:
# Length 1: 1051
# Length 2: 4307
# Length 3: 6978
# Length 4: 4853
# Length 5: 3662
# Length 6: 2584
# Length 7: 1983
# Length 8: 1279
# Length 9: 874
# Length 10: 564

# %% [markdown]
# # Gothic corpus

# %%
relative_frequencies_Gothic = relative_frequency_words_by_length(preprocessed_text_Gothic)
print("Relative frequencies of word counts by length:")
for length, frequency in relative_frequencies_Gothic.items():
    print(f"Length {length}: {frequency:.4f}")
# Out:
# Relative frequencies of word counts by length:
# Length 1: 0.0537
# Length 2: 0.1834
# Length 3: 0.2320
# Length 4: 0.1787
# Length 5: 0.1045
# Length 6: 0.0773
# Length 7: 0.0644
# Length 8: 0.0422
# Length 9: 0.0300
# Length 10: 0.0175

# %%
#Poe vs Gothic
import random

# Function to select random sentences from the second corpus
def select_random_sentences(text, subset_size):
    sentences = split_into_sentences(text)
    random_subset = random.sample(sentences, subset_size)
    return ' '.join(random_subset)

# Define subset size based on the size of your first corpus
subset_size = 1568

# Find the number of words by length in each randomly selected subset
for i in range(25):
    subset_text = select_random_sentences(text_Gothic, subset_size)
    word_lengths_subset = count_words_by_length_subset(subset_text)
    print(f"Word Lengths Frequency in Subset {i + 1}:")
    for length, count in word_lengths_subset.items():
        print(f"Length {length}: {count}")
# Out:
# Word Lengths Frequency in Subset 1:
# Length 1: 1817
# Length 2: 7019
# Length 3: 8705
# Length 4: 6955
# Length 5: 4503
# Length 6: 3284
# Length 7: 2678
# Length 8: 1978
# Length 9: 1332
# Length 10: 887
# Word Lengths Frequency in Subset 2:
# Length 1: 1710
# Length 2: 6588
# Length 3: 8505
# Length 4: 6588
# Length 5: 4336
# Length 6: 3164
# Length 7: 2580
# Length 8: 1918
# Length 9: 1443
# Length 10: 908
# Word Lengths Frequency in Subset 3:
# Length 1: 1628
# Length 2: 6428
# Length 3: 8279
# Length 4: 6290
# Length 5: 4096
# Length 6: 3057
# Length 7: 2602
# Length 8: 1933
# Length 9: 1358
# Length 10: 852
# Word Lengths Frequency in Subset 4:
# Length 1: 1640
# Length 2: 6797
# Length 3: 8829
# Length 4: 6724
# Length 5: 4439
# Length 6: 3259
# Length 7: 2622
# Length 8: 1930
# Length 9: 1433
# Length 10: 981
# Word Lengths Frequency in Subset 5:
# Length 1: 1659
# Length 2: 6631
# Length 3: 8486
# Length 4: 6560
# Length 5: 4372
# Length 6: 3248
# Length 7: 2588
# Length 8: 2003
# Length 9: 1459
# Length 10: 938
# Word Lengths Frequency in Subset 6:
# Length 1: 1700
# Length 2: 6744
# Length 3: 8603
# Length 4: 6908
# Length 5: 4343
# Length 6: 3250
# Length 7: 2736
# Length 8: 1885
# Length 9: 1447
# Length 10: 892
# Word Lengths Frequency in Subset 7:
# Length 1: 1693
# Length 2: 6782
# Length 3: 8598
# Length 4: 6541
# Length 5: 4443
# Length 6: 3119
# Length 7: 2667
# Length 8: 2034
# Length 9: 1399
# Length 10: 938
# Word Lengths Frequency in Subset 8:
# Length 1: 1674
# Length 2: 6500
# Length 3: 8372
# Length 4: 6305
# Length 5: 4236
# Length 6: 3084
# Length 7: 2552
# Length 8: 1890
# Length 9: 1393
# Length 10: 900
# Word Lengths Frequency in Subset 9:
# Length 1: 1766
# Length 2: 6840
# Length 3: 8548
# Length 4: 6603
# Length 5: 4487
# Length 6: 3240
# Length 7: 2631
# Length 8: 1963
# Length 9: 1370
# Length 10: 957
# Word Lengths Frequency in Subset 10:
# Length 1: 1681
# Length 2: 6608
# Length 3: 8438
# Length 4: 6594
# Length 5: 4194
# Length 6: 3286
# Length 7: 2687
# Length 8: 1998
# Length 9: 1417
# Length 10: 929
# Word Lengths Frequency in Subset 11:
# Length 1: 1641
# Length 2: 6410
# Length 3: 8594
# Length 4: 6513
# Length 5: 4252
# Length 6: 3132
# Length 7: 2603
# Length 8: 1978
# Length 9: 1408
# Length 10: 907
# Word Lengths Frequency in Subset 12:
# Length 1: 1729
# Length 2: 6777
# Length 3: 8518
# Length 4: 6668
# Length 5: 4336
# Length 6: 3293
# Length 7: 2598
# Length 8: 2002
# Length 9: 1415
# Length 10: 953
# Word Lengths Frequency in Subset 13:
# Length 1: 1678
# Length 2: 6430
# Length 3: 8554
# Length 4: 6675
# Length 5: 4167
# Length 6: 3144
# Length 7: 2660
# Length 8: 1863
# Length 9: 1368
# Length 10: 927
# Word Lengths Frequency in Subset 14:
# Length 1: 1654
# Length 2: 6588
# Length 3: 8350
# Length 4: 6535
# Length 5: 4276
# Length 6: 3193
# Length 7: 2608
# Length 8: 1883
# Length 9: 1406
# Length 10: 856
# Word Lengths Frequency in Subset 15:
# Length 1: 1702
# Length 2: 6653
# Length 3: 8748
# Length 4: 6767
# Length 5: 4385
# Length 6: 3253
# Length 7: 2601
# Length 8: 1924
# Length 9: 1408
# Length 10: 912
# Word Lengths Frequency in Subset 16:
# Length 1: 1862
# Length 2: 7002
# Length 3: 9107
# Length 4: 6929
# Length 5: 4481
# Length 6: 3377
# Length 7: 2817
# Length 8: 2099
# Length 9: 1544
# Length 10: 917
# Word Lengths Frequency in Subset 17:
# Length 1: 1699
# Length 2: 6663
# Length 3: 8751
# Length 4: 6702
# Length 5: 4433
# Length 6: 3213
# Length 7: 2774
# Length 8: 1979
# Length 9: 1439
# Length 10: 928
# Word Lengths Frequency in Subset 18:
# Length 1: 1630
# Length 2: 6391
# Length 3: 8281
# Length 4: 6460
# Length 5: 4120
# Length 6: 3061
# Length 7: 2506
# Length 8: 1864
# Length 9: 1375
# Length 10: 881
# Word Lengths Frequency in Subset 19:
# Length 1: 1732
# Length 2: 6870
# Length 3: 8671
# Length 4: 6722
# Length 5: 4343
# Length 6: 3299
# Length 7: 2749
# Length 8: 2034
# Length 9: 1466
# Length 10: 930
# Word Lengths Frequency in Subset 20:
# Length 1: 1773
# Length 2: 6486
# Length 3: 8688
# Length 4: 6540
# Length 5: 4286
# Length 6: 3230
# Length 7: 2676
# Length 8: 1905
# Length 9: 1386
# Length 10: 899
# Word Lengths Frequency in Subset 21:
# Length 1: 1701
# Length 2: 6688
# Length 3: 8634
# Length 4: 6713
# Length 5: 4465
# Length 6: 3281
# Length 7: 2666
# Length 8: 2049
# Length 9: 1397
# Length 10: 896
# Word Lengths Frequency in Subset 22:
# Length 1: 1660
# Length 2: 6489
# Length 3: 8603
# Length 4: 6513
# Length 5: 4191
# Length 6: 3124
# Length 7: 2553
# Length 8: 1879
# Length 9: 1400
# Length 10: 931
# Word Lengths Frequency in Subset 23:
# Length 1: 1593
# Length 2: 6341
# Length 3: 8500
# Length 4: 6236
# Length 5: 4225
# Length 6: 3045
# Length 7: 2653
# Length 8: 1970
# Length 9: 1321
# Length 10: 887
# Word Lengths Frequency in Subset 24:
# Length 1: 1724
# Length 2: 6477
# Length 3: 8525
# Length 4: 6674
# Length 5: 4275
# Length 6: 3295
# Length 7: 2609
# Length 8: 1899
# Length 9: 1418
# Length 10: 892
# Word Lengths Frequency in Subset 25:
# Length 1: 1617
# Length 2: 6444
# Length 3: 8308
# Length 4: 6399
# Length 5: 4268
# Length 6: 3105
# Length 7: 2501
# Length 8: 1892
# Length 9: 1292
# Length 10: 894

# %%
#Fanu vs Gothic
import random

# Function to select random sentences from the second corpus
def select_random_sentences(text, subset_size):
    sentences = split_into_sentences(text)
    random_subset = random.sample(sentences, subset_size)
    return ' '.join(random_subset)

# Define subset size based on the size of your first corpus
subset_size = 1097

# Find the number of words by length in each randomly selected subset
for i in range(25):
    subset_text = select_random_sentences(text_Gothic, subset_size)
    word_lengths_subset = count_words_by_length_subset(subset_text)
    print(f"Word Lengths Frequency in Subset {i + 1}:")
    for length, count in word_lengths_subset.items():
        print(f"Length {length}: {count}")
# Out:
# Word Lengths Frequency in Subset 1:
# Length 1: 1163
# Length 2: 4806
# Length 3: 6195
# Length 4: 4744
# Length 5: 3084
# Length 6: 2338
# Length 7: 1933
# Length 8: 1429
# Length 9: 1026
# Length 10: 608
# Word Lengths Frequency in Subset 2:
# Length 1: 1189
# Length 2: 4900
# Length 3: 6208
# Length 4: 4775
# Length 5: 3209
# Length 6: 2325
# Length 7: 1953
# Length 8: 1399
# Length 9: 1002
# Length 10: 686
# Word Lengths Frequency in Subset 3:
# Length 1: 1149
# Length 2: 4635
# Length 3: 5866
# Length 4: 4626
# Length 5: 3026
# Length 6: 2292
# Length 7: 1794
# Length 8: 1371
# Length 9: 950
# Length 10: 638
# Word Lengths Frequency in Subset 4:
# Length 1: 1108
# Length 2: 4687
# Length 3: 5877
# Length 4: 4542
# Length 5: 2969
# Length 6: 2349
# Length 7: 1870
# Length 8: 1390
# Length 9: 1005
# Length 10: 630
# Word Lengths Frequency in Subset 5:
# Length 1: 1205
# Length 2: 4621
# Length 3: 5876
# Length 4: 4543
# Length 5: 3003
# Length 6: 2229
# Length 7: 1841
# Length 8: 1369
# Length 9: 948
# Length 10: 667
# Word Lengths Frequency in Subset 6:
# Length 1: 1106
# Length 2: 4338
# Length 3: 5639
# Length 4: 4395
# Length 5: 2782
# Length 6: 2150
# Length 7: 1783
# Length 8: 1300
# Length 9: 916
# Length 10: 563
# Word Lengths Frequency in Subset 7:
# Length 1: 1192
# Length 2: 4645
# Length 3: 5813
# Length 4: 4559
# Length 5: 3033
# Length 6: 2183
# Length 7: 1815
# Length 8: 1331
# Length 9: 957
# Length 10: 589
# Word Lengths Frequency in Subset 8:
# Length 1: 1136
# Length 2: 4617
# Length 3: 6045
# Length 4: 4644
# Length 5: 2984
# Length 6: 2332
# Length 7: 1856
# Length 8: 1373
# Length 9: 989
# Length 10: 640
# Word Lengths Frequency in Subset 9:
# Length 1: 1154
# Length 2: 4643
# Length 3: 5930
# Length 4: 4462
# Length 5: 2962
# Length 6: 2171
# Length 7: 1754
# Length 8: 1326
# Length 9: 989
# Length 10: 606
# Word Lengths Frequency in Subset 10:
# Length 1: 1188
# Length 2: 4582
# Length 3: 6308
# Length 4: 4707
# Length 5: 3196
# Length 6: 2253
# Length 7: 1900
# Length 8: 1385
# Length 9: 1017
# Length 10: 629
# Word Lengths Frequency in Subset 11:
# Length 1: 1091
# Length 2: 4606
# Length 3: 5938
# Length 4: 4511
# Length 5: 2961
# Length 6: 2276
# Length 7: 1766
# Length 8: 1409
# Length 9: 967
# Length 10: 653
# Word Lengths Frequency in Subset 12:
# Length 1: 1119
# Length 2: 4653
# Length 3: 5962
# Length 4: 4546
# Length 5: 2946
# Length 6: 2260
# Length 7: 1816
# Length 8: 1407
# Length 9: 981
# Length 10: 607
# Word Lengths Frequency in Subset 13:
# Length 1: 1194
# Length 2: 4714
# Length 3: 6092
# Length 4: 4657
# Length 5: 3067
# Length 6: 2263
# Length 7: 1885
# Length 8: 1390
# Length 9: 1079
# Length 10: 661
# Word Lengths Frequency in Subset 14:
# Length 1: 1180
# Length 2: 4689
# Length 3: 6098
# Length 4: 4711
# Length 5: 3033
# Length 6: 2306
# Length 7: 2008
# Length 8: 1352
# Length 9: 957
# Length 10: 610
# Word Lengths Frequency in Subset 15:
# Length 1: 1263
# Length 2: 4715
# Length 3: 6077
# Length 4: 4705
# Length 5: 3043
# Length 6: 2280
# Length 7: 1891
# Length 8: 1381
# Length 9: 1006
# Length 10: 655
# Word Lengths Frequency in Subset 16:
# Length 1: 1193
# Length 2: 4723
# Length 3: 6105
# Length 4: 4804
# Length 5: 3133
# Length 6: 2279
# Length 7: 1832
# Length 8: 1362
# Length 9: 985
# Length 10: 681
# Word Lengths Frequency in Subset 17:
# Length 1: 1122
# Length 2: 4613
# Length 3: 6021
# Length 4: 4580
# Length 5: 3119
# Length 6: 2258
# Length 7: 1805
# Length 8: 1365
# Length 9: 965
# Length 10: 608
# Word Lengths Frequency in Subset 18:
# Length 1: 1106
# Length 2: 4281
# Length 3: 5812
# Length 4: 4346
# Length 5: 2876
# Length 6: 2167
# Length 7: 1854
# Length 8: 1345
# Length 9: 963
# Length 10: 630
# Word Lengths Frequency in Subset 19:
# Length 1: 1180
# Length 2: 4476
# Length 3: 5663
# Length 4: 4531
# Length 5: 2955
# Length 6: 2196
# Length 7: 1826
# Length 8: 1322
# Length 9: 959
# Length 10: 636
# Word Lengths Frequency in Subset 20:
# Length 1: 1187
# Length 2: 4584
# Length 3: 6011
# Length 4: 4408
# Length 5: 3084
# Length 6: 2327
# Length 7: 1840
# Length 8: 1383
# Length 9: 1048
# Length 10: 645
# Word Lengths Frequency in Subset 21:
# Length 1: 1120
# Length 2: 4657
# Length 3: 5895
# Length 4: 4582
# Length 5: 2903
# Length 6: 2168
# Length 7: 1832
# Length 8: 1329
# Length 9: 958
# Length 10: 627
# Word Lengths Frequency in Subset 22:
# Length 1: 1217
# Length 2: 4600
# Length 3: 5980
# Length 4: 4683
# Length 5: 3069
# Length 6: 2335
# Length 7: 1891
# Length 8: 1405
# Length 9: 1020
# Length 10: 651
# Word Lengths Frequency in Subset 23:
# Length 1: 1113
# Length 2: 4526
# Length 3: 5778
# Length 4: 4432
# Length 5: 2883
# Length 6: 2166
# Length 7: 1846
# Length 8: 1303
# Length 9: 945
# Length 10: 578
# Word Lengths Frequency in Subset 24:
# Length 1: 1117
# Length 2: 4409
# Length 3: 5619
# Length 4: 4324
# Length 5: 2873
# Length 6: 2163
# Length 7: 1693
# Length 8: 1236
# Length 9: 936
# Length 10: 566
# Word Lengths Frequency in Subset 25:
# Length 1: 1145
# Length 2: 4768
# Length 3: 5963
# Length 4: 4503
# Length 5: 2970
# Length 6: 2187
# Length 7: 1785
# Length 8: 1404
# Length 9: 996
# Length 10: 634
